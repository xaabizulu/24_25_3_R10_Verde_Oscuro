# %% [markdown]
# <a href="https://colab.research.google.com/github/xaabizulu/24_25_3_R10_Verde_Oscuro/blob/main/02_Grafo_Colabs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import networkx as nx
from itertools import combinations
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random
import numpy as np
import plotly.graph_objects as go

# %%
#ESTO ES PARA EJECUTAR EN COLAB
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/GRAFO RETO/Datos/transformados/df_resultado.csv')
# df = pd.read_csv('Datos/transformados/df_resultado.csv')
df.pop('Unnamed: 0')
df.head()
# Out:
#                              id_variant                                    id  \
# 0  fbc2f719-e038-4243-892c-7bd2ca6e80b5  5f5c4a50-557a-4d53-9e81-cc72fdd18fbf
# 1  c85666c0-a8ba-42f4-a30f-17687ad51ff5  5f5c4a50-557a-4d53-9e81-cc72fdd18fbf
# 2  93db9797-3a66-4889-be9c-5d3522da96a1  5f5c4a50-557a-4d53-9e81-cc72fdd18fbf
# 3  0c1010aa-2f25-4c55-9f95-b9bc133f3307  6e6b4255-006a-4d13-b312-3b1426290d8e
# 4  215a323c-9721-4879-9aa6-5cf30b5b21f0  6549c1b1-989e-432a-bdc9-b603c438b310
#
#                     title  season hexadecimal  \
# 0  Onljade Cardigan knit        8      000000
# 1  Onljade Cardigan knit        8      DFC8B2
# 2  Onljade Cardigan knit        8      B94600
# 3       Poly Pant deeluxe       7      B11730
# 4     Onleden Sweater knt       9      FFFF00
#
#                               family_id  \
# 0  141f32d6-a5af-49bf-b019-fd28354977f1
# 1  141f32d6-a5af-49bf-b019-fd28354977f1
# 2  141f32d6-a5af-49bf-b019-fd28354977f1
# 3  6598b655-3e19-448c-8b4f-ff6a29447b34
# 4  1b93b30c-833f-45a8-ba69-c21d2e7f4824
#
#                                         id_hex weather  nivel formalidad  ...  \
# 0  5f5c4a50-557a-4d53-9e81-cc72fdd18fbf_000000    cold    3.0     Formal  ...
# 1  5f5c4a50-557a-4d53-9e81-cc72fdd18fbf_DFC8B2    cold    3.0     Formal  ...
# 2  5f5c4a50-557a-4d53-9e81-cc72fdd18fbf_B94600    cold    3.0     Formal  ...
# 3  6e6b4255-006a-4d13-b312-3b1426290d8e_B11730    warm    1.1     Formal  ...
# 4  6549c1b1-989e-432a-bdc9-b603c438b310_FFFF00    warm    3.0   Informal  ...
#
#   foulard_type size  skirt_type message hood back_neckline shoulders_pad  \
# 0          NaN  NaN         NaN     NaN  NaN           NaN           NaN
# 1          NaN  NaN         NaN     NaN  NaN           NaN           NaN
# 2          NaN  NaN         NaN     NaN  NaN           NaN           NaN
# 3          NaN  NaN         NaN     NaN  NaN           NaN           NaN
# 4          NaN  NaN         NaN     NaN  NaN           NaN           NaN
#
#   bag_type hips_volume chest_volume
# 0      NaN         NaN          NaN
# 1      NaN         NaN          NaN
# 2      NaN         NaN          NaN
# 3      NaN         NaN          NaN
# 4      NaN         NaN          NaN
#
# [5 rows x 57 columns]

# %%
color_combinations = pd.read_csv('/content/drive/My Drive/Colab Notebooks/GRAFO RETO/combinaciones_colores.csv')
# color_combinations = pd.read_csv('combinaciones_colores.csv')

# %%
df_s7 = df[df['season']==7]
df_s8 = df[df['season']==8]
df_s9 = df[df['season']==9]

# %% [markdown]
# **GRAFO**

# %% [markdown]
# - Eliminar columnas : top_type, finishing, closing, neck, detail, sleeve, sleeve_long, sizing, composition,  fabric, hip_contour, waist_contour, chest_contour, sleeve_long_cm, long_cm, gripper, basic, down_part_type, bottom, type_of_length, neckline, outside_type, cover, light, alerts, cut, rubber_waist, label, dress_type, foulard_type, size, skirt_type, message, hood, back_neckline, shoulders_pad, bag_type, hips_volume, chest_volume, shot, thickness

# %%
columnas_a_eliminar = [
    'top_type', 'finishing', 'closing', 'neck', 'detail', 'sleeve', 'sleeve_long', 'sizing',
    'composition', 'fabric', 'hip_contour', 'waist_contour', 'chest_contour', 'sleeve_long_cm',
    'long_cm', 'gripper', 'basic', 'down_part_type', 'bottom', 'type_of_length', 'neckline',
    'outside_type', 'cover', 'light', 'alerts', 'cut', 'rubber_waist', 'label', 'dress_type',
    'foulard_type', 'size', 'skirt_type', 'message', 'hood', 'back_neckline', 'shoulders_pad',
    'bag_type', 'hips_volume', 'chest_volume', 'shot', 'thicknees', 'weather.1', 'id_hex'
]

df_limpio = df.drop(columns=columnas_a_eliminar)

# %%
df_limpio.head()
# Out:
#                              id_variant                                    id  \
# 0  fbc2f719-e038-4243-892c-7bd2ca6e80b5  5f5c4a50-557a-4d53-9e81-cc72fdd18fbf
# 1  c85666c0-a8ba-42f4-a30f-17687ad51ff5  5f5c4a50-557a-4d53-9e81-cc72fdd18fbf
# 2  93db9797-3a66-4889-be9c-5d3522da96a1  5f5c4a50-557a-4d53-9e81-cc72fdd18fbf
# 3  0c1010aa-2f25-4c55-9f95-b9bc133f3307  6e6b4255-006a-4d13-b312-3b1426290d8e
# 4  215a323c-9721-4879-9aa6-5cf30b5b21f0  6549c1b1-989e-432a-bdc9-b603c438b310
#
#                     title  season hexadecimal  \
# 0  Onljade Cardigan knit        8      000000
# 1  Onljade Cardigan knit        8      DFC8B2
# 2  Onljade Cardigan knit        8      B94600
# 3       Poly Pant deeluxe       7      B11730
# 4     Onleden Sweater knt       9      FFFF00
#
#                               family_id weather  nivel formalidad  \
# 0  141f32d6-a5af-49bf-b019-fd28354977f1    cold    3.0     Formal
# 1  141f32d6-a5af-49bf-b019-fd28354977f1    cold    3.0     Formal
# 2  141f32d6-a5af-49bf-b019-fd28354977f1    cold    3.0     Formal
# 3  6598b655-3e19-448c-8b4f-ff6a29447b34    warm    1.1     Formal
# 4  1b93b30c-833f-45a8-ba69-c21d2e7f4824    warm    3.0   Informal
#
#    adventurous   print    style       fit application
# 0            1  smooth  classic  straight    freetime
# 1            1  smooth  classic  straight    freetime
# 2            1  smooth  classic  straight    freetime
# 3            1  smooth   street     tight    freetime
# 4            1  smooth     boho     loose    freetime

# %%
df_limpio['id_nodo'] = range(len(df))

G = nx.Graph()

for _, row in df_limpio.iterrows():
    G.add_node(row['id_nodo'], feature=[
        row['season'], row['hexadecimal'], row['weather'],
        row['nivel'], row['formalidad'], row['adventurous'], row['print'], row['style'],
        row['fit'], row['application']
    ], label=row['id_nodo'])


for node in G.nodes(data=True):
    print(node)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# (357, {'feature': [7, 'FFFFFF', 'warm', 1.2, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 357})
# (358, {'feature': [8, 'ECE9D6', 'cold', 2.0, 'Formal', 3, 'miniprint', 'street', 'straight', 'freetime'], 'label': 358})
# (359, {'feature': [9, '153668', 'cold', 3.2, 'Formal', 2, 'retro', 'classic', nan, 'freetime'], 'label': 359})
# (360, {'feature': [7, '000000', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 360})
# (361, {'feature': [7, '00008b', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 361})
# (362, {'feature': [8, 'B94600', 'warm', 1.2, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 362})
# (363, {'feature': [8, 'C7A2A2', 'cold', 3.0, 'Informal', 1, 'smooth', 'classic', 'straight', 'work'], 'label': 363})
# (364, {'feature': [8, 'FFFF00', 'cold', 3.0, 'Informal', 1, 'smooth', 'classic', 'straight', 'work'], 'label': 364})
# (365, {'feature': [8, '5F5E5E', 'cold', 3.0, 'Informal', 1, 'smooth', 'classic', 'straight', 'work'], 'label': 365})
# (366, {'feature': [8, '000000', 'cold', 1.1, 'Informal', 1, 'smooth', 'casual', 'straight', 'freetime'], 'label': 366})
# (367, {'feature': [8, '5F5E5E', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'work'], 'label': 367})
# (368, {'feature': [9, '008000', 'warm', 3.1, 'Formal', 2, 'sheets', 'boho', 'straight', 'freetime'], 'label': 368})
# (369, {'feature': [9, '000000', 'warm', 2.0, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 369})
# (370, {'feature': [9, 'FFFFFF', 'warm', 2.0, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 370})
# (371, {'feature': [9, 'ECE9D6', 'warm', 2.0, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 371})
# (372, {'feature': [9, 'D84936', 'warm', 2.0, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 372})
# (373, {'feature': [9, '666633', 'warm', 2.0, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 373})
# (374, {'feature': [9, 'ECE9D6', 'cold', 1.1, 'Formal', 2, 'floral', 'classic', 'straight', 'freetime'], 'label': 374})
# (375, {'feature': [9, '666633', 'cold', 1.1, 'Formal', 2, 'floral', 'classic', 'straight', 'freetime'], 'label': 375})
# (376, {'feature': [9, '00008b', 'cold', 3.0, 'Informal', 4, 'smooth', 'minimal', 'loose', 'freetime'], 'label': 376})
# (377, {'feature': [7, '808080', 'cold', 3.0, 'Informal', 4, 'smooth', 'minimal', 'loose', 'freetime'], 'label': 377})
# (378, {'feature': [7, '000000', 'cold', 3.0, 'Informal', 4, 'smooth', 'minimal', 'loose', 'freetime'], 'label': 378})
# (379, {'feature': [9, '000000', 'warm', 3.1, 'Informal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 379})
# (380, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Informal', 2, 'floral', 'boho', 'straight', 'freetime'], 'label': 380})
# (381, {'feature': [7, '808080', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'work'], 'label': 381})
# (382, {'feature': [7, '000000', 'warm', 3.1, 'Informal', 2, 'floral', 'street', 'loose', 'freetime'], 'label': 382})
# (383, {'feature': [7, 'C19A6B', 'cold', 2.0, 'Formal', 3, 'retro', 'classic', 'straight', 'work'], 'label': 383})
# (384, {'feature': [8, '808080', 'warm', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 384})
# (385, {'feature': [7, '87CEFA', 'warm', 2.0, 'Informal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 385})
# (386, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Informal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 386})
# (387, {'feature': [7, '000000', 'warm', 2.0, 'Informal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 387})
# (388, {'feature': [9, '000000', 'warm', 3.1, 'Formal', 2, 'ethnic', 'classic', 'straight', 'freetime'], 'label': 388})
# (389, {'feature': [9, '000000', 'cold', 1.1, 'Informal', 2, 'smooth', 'night', 'straight', 'freetime'], 'label': 389})
# (390, {'feature': [8, '000081', 'cold', 3.0, 'Formal', 1, 'smooth', 'classic', 'tight', 'freetime'], 'label': 390})
# (391, {'feature': [8, '000000', 'cold', 3.0, 'Formal', 1, 'smooth', 'classic', 'tight', 'freetime'], 'label': 391})
# (392, {'feature': [8, '164A0A', 'cold', 3.0, 'Formal', 1, 'smooth', 'classic', 'tight', 'freetime'], 'label': 392})
# (393, {'feature': [8, 'D84936', 'cold', 3.0, 'Formal', 1, 'smooth', 'classic', 'tight', 'freetime'], 'label': 393})
# (394, {'feature': [8, '5F5E5E', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 394})
# (395, {'feature': [8, '9A8176', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 395})
# (396, {'feature': [8, '000081', 'warm', 1.1, 'Informal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 396})
# (397, {'feature': [8, '800000', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 397})
# (398, {'feature': [8, 'DEB24C', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 398})
# (399, {'feature': [8, '164A0A', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 399})
# (400, {'feature': [8, '00008b', 'cold', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'work'], 'label': 400})
# (401, {'feature': [8, '000000', 'cold', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'work'], 'label': 401})
# (402, {'feature': [9, '9A8176', 'cold', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'work'], 'label': 402})
# (403, {'feature': [8, 'DFC8B2', 'cold', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'work'], 'label': 403})
# (404, {'feature': [8, '666633', 'cold', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'work'], 'label': 404})
# (405, {'feature': [9, '008000', 'cold', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'work'], 'label': 405})
# (406, {'feature': [9, '800000', 'cold', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'work'], 'label': 406})
# (407, {'feature': [9, 'ECE9D6', 'cold', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'work'], 'label': 407})
# (408, {'feature': [9, 'D84936', 'cold', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'work'], 'label': 408})
# (409, {'feature': [9, 'ECE9D6', 'warm', 2.0, 'Formal', 1, 'sheets', 'classic', 'tight', 'freetime'], 'label': 409})
# (410, {'feature': [8, '000000', 'cold', 1.1, 'Informal', 2, 'smooth', 'street', 'tight', 'night'], 'label': 410})
# (411, {'feature': [7, '000081', 'warm', 1.1, 'Formal', 4, 'smooth', 'classic', 'tight', 'freetime'], 'label': 411})
# (412, {'feature': [7, 'DFC8B2', 'warm', 1.1, 'Formal', 3, 'animal_print', 'classic', 'straight', 'freetime'], 'label': 412})
# (413, {'feature': [8, '800000', 'warm', 3.0, 'Formal', 2, 'smooth', 'classic', 'loose', 'work'], 'label': 413})
# (414, {'feature': [8, '000000', 'warm', 3.0, 'Formal', 2, 'smooth', 'classic', 'loose', 'work'], 'label': 414})
# (415, {'feature': [8, '462C0E', 'warm', 3.0, 'Formal', 2, 'smooth', 'classic', 'loose', 'work'], 'label': 415})
# (416, {'feature': [8, 'B94600', 'cold', 3.2, 'Informal', 1, 'checked', 'casual', nan, 'work'], 'label': 416})
# (417, {'feature': [9, 'FFFFFF', 'warm', 2.0, 'Informal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 417})
# (418, {'feature': [7, '666633', 'warm', 3.1, 'Informal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 418})
# (419, {'feature': [7, 'FFFFFF', 'warm', 3.1, 'Informal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 419})
# (420, {'feature': [9, 'FFFFFF', 'warm', 2.0, 'Formal', 1, nan, 'classic', 'tight', 'freetime'], 'label': 420})
# (421, {'feature': [9, 'FFC0CB', 'warm', 2.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 421})
# (422, {'feature': [9, 'BBA9E4', 'warm', 2.0, 'Informal', 2, 'floral', 'boho', 'loose', 'freetime'], 'label': 422})
# (423, {'feature': [7, '00008b', 'warm', 3.1, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 423})
# (424, {'feature': [7, '666633', 'warm', 3.1, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 424})
# (425, {'feature': [7, '666633', 'warm', 1.1, 'Formal', 1, 'pied_de_poule', 'classic', 'tight', 'freetime'], 'label': 425})
# (426, {'feature': [7, 'DFC8B2', 'warm', 1.1, 'Formal', 1, 'pied_de_poule', 'classic', 'tight', 'freetime'], 'label': 426})
# (427, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 427})
# (428, {'feature': [7, '0000FF', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 428})
# (429, {'feature': [7, '000000', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 429})
# (430, {'feature': [7, '164A0A', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 430})
# (431, {'feature': [7, '614051', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 431})
# (432, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 2, 'horizontal_stripes', 'boho', 'straight', 'freetime'], 'label': 432})
# (433, {'feature': [7, 'ECE9D6', 'warm', 1.2, 'Formal', 3, 'floral', 'boho', 'loose', 'freetime'], 'label': 433})
# (434, {'feature': [7, '87CEFA', 'warm', 1.1, 'Formal', 2, 'vertical_stripes', 'casual', 'tight', 'freetime'], 'label': 434})
# (435, {'feature': [7, 'FFFFFF', 'warm', 3.1, 'Formal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 435})
# (436, {'feature': [7, '00008b', 'warm', 3.1, 'Formal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 436})
# (437, {'feature': [8, '000000', 'cold', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 437})
# (438, {'feature': [8, '666633', 'cold', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 438})
# (439, {'feature': [8, '000000', 'warm', 1.1, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 439})
# (440, {'feature': [9, '000000', 'warm', 2.0, 'Informal', 2, 'animal_print', 'street', 'straight', 'freetime'], 'label': 440})
# (441, {'feature': [7, 'DFC8B2', 'cold', 3.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 441})
# (442, {'feature': [7, '008000', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 442})
# (443, {'feature': [7, '0000FF', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 443})
# (444, {'feature': [7, '008000', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 444})
# (445, {'feature': [7, '00008b', 'warm', 1.2, 'Formal', 1, 'floral', 'classic', 'loose', 'work'], 'label': 445})
# (446, {'feature': [7, 'B11730', 'warm', 1.2, 'Informal', 2, 'printed', 'street', 'tight', 'freetime'], 'label': 446})
# (447, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Informal', 2, 'printed', 'street', 'straight', 'freetime'], 'label': 447})
# (448, {'feature': [7, '000000', 'warm', 3.1, 'Formal', 2, 'floral', 'boho', 'loose', 'freetime'], 'label': 448})
# (449, {'feature': [8, '00008b', 'cold', 3.2, 'Informal', 2, 'printed', 'boho', nan, 'work'], 'label': 449})
# (450, {'feature': [8, 'B94600', 'cold', 3.2, 'Informal', 1, 'horizontal_stripes', 'boho', nan, 'work'], 'label': 450})
# (451, {'feature': [8, 'FFC0CB', 'cold', 3.2, 'Informal', 1, 'horizontal_stripes', 'boho', nan, 'work'], 'label': 451})
# (452, {'feature': [8, '462C0E', 'cold', 3.2, 'Formal', 2, 'smooth', 'classic', nan, 'freetime'], 'label': 452})
# (453, {'feature': [8, '00008b', 'warm', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 453})
# (454, {'feature': [9, '666633', 'cold', 3.1, 'Informal', 1, 'smooth', 'boho', 'straight', 'freetime'], 'label': 454})
# (455, {'feature': [9, 'ECE9D6', 'cold', 3.1, 'Informal', 1, 'smooth', 'boho', 'straight', 'freetime'], 'label': 455})
# (456, {'feature': [8, 'C9C9C9', 'cold', 3.2, 'Informal', 3, 'smooth', 'night', nan, 'freetime'], 'label': 456})
# (457, {'feature': [8, '000000', 'warm', 2.0, 'Formal', 1, 'smooth', 'classic', 'straight', 'work'], 'label': 457})
# (458, {'feature': [8, '000081', 'warm', 1.1, 'Informal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 458})
# (459, {'feature': [8, 'B94600', 'cold', 3.0, 'Informal', 1, 'smooth', 'boho', 'straight', 'freetime'], 'label': 459})
# (460, {'feature': [8, 'D3D3D3', 'cold', 3.0, 'Informal', 1, 'smooth', 'boho', 'straight', 'freetime'], 'label': 460})
# (461, {'feature': [8, '164A0A', 'cold', 3.0, 'Informal', 1, 'smooth', 'boho', 'straight', 'freetime'], 'label': 461})
# (462, {'feature': [9, 'A57E62', 'cold', 1.1, 'Formal', 1, 'smooth', 'classic', 'straight', 'working_girl'], 'label': 462})
# (463, {'feature': [8, '000000', 'cold', 1.1, 'Informal', 3, 'smooth', 'casual', 'tight', 'freetime'], 'label': 463})
# (464, {'feature': [7, 'FFC0CB', 'warm', 1.1, 'Formal', 3, 'floral', 'classic', 'loose', 'freetime'], 'label': 464})
# (465, {'feature': [7, '000081', 'warm', 1.1, 'Formal', 3, 'floral', 'classic', 'loose', 'freetime'], 'label': 465})
# (466, {'feature': [7, '87CEFA', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 466})
# (467, {'feature': [7, 'C19A6B', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 467})
# (468, {'feature': [9, '00008b', 'cold', 3.1, 'Formal', 1, 'smooth', 'classic', 'tight', 'working_girl'], 'label': 468})
# (469, {'feature': [9, 'DFC8B2', 'warm', 1.1, 'Informal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 469})
# (470, {'feature': [9, '000000', 'warm', 1.1, 'Informal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 470})
# (471, {'feature': [9, 'FFFFFF', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 471})
# (472, {'feature': [8, '87CEFA', 'cold', 3.2, 'Formal', 1, 'smooth', 'classic', nan, 'freetime'], 'label': 472})
# (473, {'feature': [8, '000000', 'cold', 3.2, 'Formal', 1, 'smooth', 'classic', nan, 'freetime'], 'label': 473})
# (474, {'feature': [8, 'B94600', 'cold', 3.2, 'Formal', 1, 'smooth', 'classic', nan, 'freetime'], 'label': 474})
# (475, {'feature': [8, 'DFC8B2', 'cold', 3.2, 'Formal', 1, 'smooth', 'classic', nan, 'freetime'], 'label': 475})
# (476, {'feature': [8, '800000', 'cold', 3.2, 'Formal', 1, 'smooth', 'classic', nan, 'freetime'], 'label': 476})
# (477, {'feature': [8, 'FFC0CB', 'cold', 3.2, 'Formal', 1, 'smooth', 'classic', nan, 'freetime'], 'label': 477})
# (478, {'feature': [8, '00008b', 'cold', 3.2, 'Formal', 1, 'smooth', 'classic', nan, 'freetime'], 'label': 478})
# (479, {'feature': [8, '9A8176', 'cold', 3.0, 'Informal', 1, 'smooth', 'minimal', 'straight', 'work'], 'label': 479})
# (480, {'feature': [8, '000000', 'cold', 3.0, 'Informal', 1, 'smooth', 'minimal', 'straight', 'work'], 'label': 480})
# (481, {'feature': [8, '000000', 'cold', 3.2, 'Informal', 1, 'checked', 'casual', nan, 'freetime'], 'label': 481})
# (482, {'feature': [8, 'B94600', 'cold', 3.2, 'Informal', 1, 'checked', 'casual', nan, 'freetime'], 'label': 482})
# (483, {'feature': [8, '9A8176', 'cold', 3.2, 'Informal', 1, 'checked', 'casual', nan, 'freetime'], 'label': 483})
# (484, {'feature': [9, 'BBA9E4', 'warm', 1.2, 'Formal', 3, 'vertical_stripes', 'classic', 'straight', 'freetime'], 'label': 484})
# (485, {'feature': [9, '000081', 'warm', 3.1, 'Informal', 1, 'smooth', 'street', 'straight', 'work'], 'label': 485})
# (486, {'feature': [8, '000000', 'warm', 1.2, 'Formal', 2, 'animal_print', 'classic', 'straight', 'work'], 'label': 486})
# (487, {'feature': [8, 'DFC8B2', 'cold', 3.0, 'Informal', 2, 'horizontal_stripes', 'casual', 'straight', 'freetime'], 'label': 487})
# (488, {'feature': [9, 'FFC0CB', 'warm', 3.2, 'Formal', 1, 'smooth', 'classic', nan, 'freetime'], 'label': 488})
# (489, {'feature': [8, '00008b', 'cold', 1.1, 'Formal', 2, 'smooth', 'boho', 'tight', 'freetime'], 'label': 489})
# (490, {'feature': [8, '00008b', 'cold', 3.2, 'Formal', 2, 'herringbone', 'classic', nan, 'freetime'], 'label': 490})
# (491, {'feature': [8, '800000', 'cold', 3.2, 'Formal', 2, 'herringbone', 'classic', nan, 'freetime'], 'label': 491})
# (492, {'feature': [8, '000000', 'cold', 3.0, 'Formal', 2, 'animal_print', 'classic', 'straight', 'freetime'], 'label': 492})
# (493, {'feature': [8, 'B94600', 'cold', 3.0, 'Formal', 4, 'smooth', 'classic', 'tight', 'freetime'], 'label': 493})
# (494, {'feature': [8, 'FFC0CB', 'cold', 3.0, 'Formal', 4, 'smooth', 'classic', 'tight', 'freetime'], 'label': 494})
# (495, {'feature': [8, '462C0E', 'cold', 3.0, 'Formal', 4, 'smooth', 'classic', 'tight', 'freetime'], 'label': 495})
# (496, {'feature': [8, '00008b', 'cold', 3.0, 'Formal', 4, 'smooth', 'classic', 'tight', 'freetime'], 'label': 496})
# (497, {'feature': [7, 'DEB24C', 'cold', 3.0, 'Informal', 4, 'smooth', 'casual', 'straight', 'freetime'], 'label': 497})
# (498, {'feature': [7, '0000FF', 'cold', 3.0, 'Informal', 4, 'smooth', 'casual', 'straight', 'freetime'], 'label': 498})
# (499, {'feature': [7, 'B11730', 'cold', 3.0, 'Informal', 4, 'smooth', 'casual', 'straight', 'freetime'], 'label': 499})
# (500, {'feature': [7, 'D3D3D3', 'cold', 3.0, 'Informal', 4, 'smooth', 'casual', 'straight', 'freetime'], 'label': 500})
# (501, {'feature': [7, '000000', 'cold', 3.0, 'Informal', 4, 'smooth', 'casual', 'straight', 'freetime'], 'label': 501})
# (502, {'feature': [7, 'FFFFFF', 'cold', 3.0, 'Informal', 4, 'smooth', 'casual', 'straight', 'freetime'], 'label': 502})
# (503, {'feature': [9, '000000', 'warm', 2.0, 'Informal', 2, 'printed', 'boho', 'straight', 'freetime'], 'label': 503})
# (504, {'feature': [7, 'D84936', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 504})
# (505, {'feature': [7, 'FFFF00', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 505})
# (506, {'feature': [7, '164A0A', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 506})
# (507, {'feature': [8, 'B11730', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 507})
# (508, {'feature': [8, '000000', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 508})
# (509, {'feature': [9, 'DEB24C', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 509})
# (510, {'feature': [9, 'BBE2AD', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 510})
# (511, {'feature': [7, 'DFC8B2', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 511})
# (512, {'feature': [8, '153668', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 512})
# (513, {'feature': [8, 'C7A2A2', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 513})
# (514, {'feature': [8, '462C0E', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 514})
# (515, {'feature': [7, 'DEB24C', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 515})
# (516, {'feature': [7, 'FFC0CB', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 516})
# (517, {'feature': [8, '666633', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 517})
# (518, {'feature': [8, '000081', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 518})
# (519, {'feature': [7, '00008b', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 519})
# (520, {'feature': [8, '614051', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 520})
# (521, {'feature': [8, '87CEFA', 'warm', 2.0, 'Formal', 2, 'floral', 'classic', 'loose', 'work'], 'label': 521})
# (522, {'feature': [8, '5F5E5E', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 522})
# (523, {'feature': [8, 'FFC0CB', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 523})
# (524, {'feature': [8, 'DFC8B2', 'cold', 3.2, 'Informal', 2, 'checked', 'casual', nan, 'freetime'], 'label': 524})
# (525, {'feature': [8, '00008b', 'cold', 3.2, 'Informal', 2, 'checked', 'casual', nan, 'freetime'], 'label': 525})
# (526, {'feature': [9, '87CEFA', 'cold', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 526})
# (527, {'feature': [9, 'DFC8B2', 'warm', 1.1, 'Informal', 2, 'smooth', 'street', 'loose', 'work'], 'label': 527})
# (528, {'feature': [7, '000081', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 528})
# (529, {'feature': [7, '000000', 'warm', 1.1, 'Formal', 4, 'smooth', 'classic', 'tight', 'freetime'], 'label': 529})
# (530, {'feature': [7, '000000', 'cold', 1.2, 'Informal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 530})
# (531, {'feature': [7, '164A0A', 'warm', 2.0, 'Informal', 1, 'smooth', 'boho', 'loose', 'freetime'], 'label': 531})
# (532, {'feature': [7, '666633', 'warm', 2.0, 'Informal', 1, 'smooth', 'boho', 'loose', 'freetime'], 'label': 532})
# (533, {'feature': [7, 'FFFFFF', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 533})
# (534, {'feature': [7, '00008b', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 534})
# (535, {'feature': [7, '000000', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 535})
# (536, {'feature': [9, '00008b', 'warm', 1.1, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 536})
# (537, {'feature': [9, '666633', 'warm', 1.1, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 537})
# (538, {'feature': [8, '000000', 'cold', 1.1, 'Informal', 3, 'smooth', 'street', 'loose', 'night'], 'label': 538})
# (539, {'feature': [9, '164A0A', 'cold', 1.1, 'Informal', 2, 'miniprint', 'boho', 'straight', 'freetime'], 'label': 539})
# (540, {'feature': [8, '000000', 'cold', 3.2, 'Informal', 2, 'checked', 'boho', nan, 'freetime'], 'label': 540})
# (541, {'feature': [8, '462C0E', 'cold', 3.2, 'Informal', 2, 'checked', 'boho', nan, 'freetime'], 'label': 541})
# (542, {'feature': [9, '00008b', 'warm', 1.2, 'Informal', 2, 'vertical_stripes', 'street', 'straight', 'freetime'], 'label': 542})
# (543, {'feature': [9, '8e1d03', 'warm', 1.2, 'Informal', 2, 'vertical_stripes', 'street', 'straight', 'freetime'], 'label': 543})
# (544, {'feature': [8, 'B11730', 'cold', 3.0, 'Informal', 2, 'horizontal_stripes', 'night', 'tight', 'night'], 'label': 544})
# (545, {'feature': [8, '5C2F83', 'cold', 3.0, 'Informal', 2, 'horizontal_stripes', 'night', 'tight', 'night'], 'label': 545})
# (546, {'feature': [8, '5F5E5E', 'cold', 3.0, 'Informal', 1, 'horizontal_stripes', 'casual', 'straight', 'freetime'], 'label': 546})
# (547, {'feature': [8, '000000', 'cold', 1.1, 'Formal', 2, 'smooth', 'night', 'tight', 'night'], 'label': 547})
# (548, {'feature': [8, '000000', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'straight', 'freetime'], 'label': 548})
# (549, {'feature': [9, '000000', 'warm', 1.1, 'Informal', 2, 'retro', 'boho', 'loose', 'freetime'], 'label': 549})
# (550, {'feature': [9, '164A0A', 'warm', 3.1, 'Formal', 2, 'floral', 'boho', 'straight', 'freetime'], 'label': 550})
# (551, {'feature': [9, '8e1d03', 'warm', 2.0, 'Formal', 1, 'floral', 'classic', 'loose', 'freetime'], 'label': 551})
# (552, {'feature': [7, '00008b', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 552})
# (553, {'feature': [7, 'DEB24C', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 553})
# (554, {'feature': [7, 'FFC0CB', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 554})
# (555, {'feature': [7, 'E65A5B', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 555})
# (556, {'feature': [7, '000000', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 556})
# (557, {'feature': [7, '800000', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 557})
# (558, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 558})
# (559, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 559})
# (560, {'feature': [7, '00008b', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 560})
# (561, {'feature': [7, '00008b', 'warm', 3.0, 'Informal', 3, 'smooth', 'street', 'straight', 'freetime'], 'label': 561})
# (562, {'feature': [7, 'DFC8B2', 'warm', 3.0, 'Informal', 3, 'smooth', 'street', 'straight', 'freetime'], 'label': 562})
# (563, {'feature': [7, 'B94600', 'warm', 3.0, 'Informal', 3, 'smooth', 'street', 'straight', 'freetime'], 'label': 563})
# (564, {'feature': [7, '462C0E', 'warm', 1.1, 'Informal', 2, 'bodoque', 'street', 'loose', 'freetime'], 'label': 564})
# (565, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 565})
# (566, {'feature': [7, '000000', 'warm', 1.2, 'Formal', 2, 'smooth', 'classic', 'loose', 'night'], 'label': 566})
# (567, {'feature': [8, '164A0A', 'warm', 1.2, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 567})
# (568, {'feature': [8, '000000', 'warm', 1.2, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 568})
# (569, {'feature': [7, '000081', 'warm', 1.1, 'Formal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 569})
# (570, {'feature': [7, 'FFFF00', 'cold', 3.0, 'Informal', 2, 'smooth', 'boho', 'loose', 'freetime'], 'label': 570})
# (571, {'feature': [7, '000000', 'cold', 1.1, 'Informal', 1, 'smooth', 'minimal', 'tight', 'working_girl'], 'label': 571})
# (572, {'feature': [9, '00008b', 'warm', 2.0, 'Informal', 1, 'horizontal_stripes', 'casual', 'loose', 'freetime'], 'label': 572})
# (573, {'feature': [7, '00008b', 'cold', 1.1, 'Informal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 573})
# (574, {'feature': [7, '000000', 'warm', 1.2, 'Formal', 2, 'miniprint', 'classic', 'tight', 'night'], 'label': 574})
# (575, {'feature': [7, '00008b', 'cold', 3.0, 'Informal', 2, nan, 'casual', 'oversize', 'freetime'], 'label': 575})
# (576, {'feature': [7, '000000', 'cold', 1.2, 'Formal', 2, 'floral', 'boho', 'straight', 'freetime'], 'label': 576})
# (577, {'feature': [7, '0000FF', 'cold', 3.0, 'Informal', 2, 'printed', 'boho', 'loose', 'freetime'], 'label': 577})
# (578, {'feature': [7, '00008b', 'warm', 1.1, 'Informal', 1, 'smooth', 'boho', 'tight', 'freetime'], 'label': 578})
# (579, {'feature': [9, 'C19A6B', 'warm', 1.1, 'Informal', 2, 'smooth', 'street', 'loose', 'freetime'], 'label': 579})
# (580, {'feature': [9, '164A0A', 'warm', 1.1, 'Informal', 2, 'smooth', 'street', 'loose', 'freetime'], 'label': 580})
# (581, {'feature': [9, '768597', 'cold', 3.2, 'Informal', 1, 'smooth', 'boho', nan, 'freetime'], 'label': 581})
# (582, {'feature': [9, 'D3D3D3', 'cold', 3.2, 'Informal', 1, 'smooth', 'boho', nan, 'freetime'], 'label': 582})
# (583, {'feature': [9, '9A8176', 'cold', 3.2, 'Informal', 1, 'smooth', 'boho', nan, 'freetime'], 'label': 583})
# (584, {'feature': [9, '00008b', 'cold', 3.2, 'Informal', 1, 'smooth', 'boho', nan, 'freetime'], 'label': 584})
# (585, {'feature': [7, 'DFC8B2', 'warm', 2.0, 'Informal', 2, 'floral', 'boho', 'straight', 'freetime'], 'label': 585})
# (586, {'feature': [7, '00008b', 'cold', 2.0, 'Informal', 2, 'geometric', 'boho', 'loose', 'work'], 'label': 586})
# (587, {'feature': [7, '666633', 'warm', 3.1, 'Informal', 3, 'smooth', 'casual', 'straight', 'freetime'], 'label': 587})
# (588, {'feature': [7, 'FFC0CB', 'warm', 1.1, 'Informal', 3, 'vertical_stripes', 'classic', 'straight', 'freetime'], 'label': 588})
# (589, {'feature': [7, '000081', 'warm', 1.1, 'Informal', 3, 'vertical_stripes', 'classic', 'straight', 'freetime'], 'label': 589})
# (590, {'feature': [7, 'FFFFFF', 'warm', 1.1, 'Informal', 3, 'vertical_stripes', 'boho', 'straight', 'freetime'], 'label': 590})
# (591, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 3, 'vertical_stripes', 'boho', 'straight', 'freetime'], 'label': 591})
# (592, {'feature': [7, '87CEFA', 'warm', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 592})
# (593, {'feature': [7, 'FFFFFF', 'warm', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 593})
# (594, {'feature': [7, '00008b', 'warm', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 594})
# (595, {'feature': [9, 'FFD200', 'warm', 2.0, 'Informal', 1, 'smooth', 'boho', 'loose', 'freetime'], 'label': 595})
# (596, {'feature': [7, 'DEB24C', 'warm', 3.2, 'Informal', 3, 'retro', 'boho', nan, 'work'], 'label': 596})
# (597, {'feature': [9, '000000', 'warm', 2.0, 'Informal', 2, 'smooth', 'boho', 'straight', 'night'], 'label': 597})
# (598, {'feature': [9, 'FFFFFF', 'warm', 2.0, 'Informal', 2, 'smooth', 'boho', 'straight', 'night'], 'label': 598})
# (599, {'feature': [9, '000000', 'cold', 3.2, 'Informal', 2, 'smooth', 'casual', nan, 'freetime'], 'label': 599})
# (600, {'feature': [7, 'D3D3D3', 'warm', 3.0, 'Informal', 1, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 600})
# (601, {'feature': [7, '00008b', 'warm', 3.0, 'Informal', 1, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 601})
# (602, {'feature': [7, '000000', 'warm', 3.0, 'Informal', 1, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 602})
# (603, {'feature': [7, 'DEB24C', 'warm', 3.1, 'Formal', 5, 'floral', 'boho', 'straight', 'freetime'], 'label': 603})
# (604, {'feature': [7, 'FFFF00', 'warm', 3.2, 'Informal', 3, 'other', 'casual', nan, 'freetime'], 'label': 604})
# (605, {'feature': [7, 'B11730', 'warm', 3.2, 'Informal', 3, 'other', 'casual', nan, 'freetime'], 'label': 605})
# (606, {'feature': [7, '40E0D0', 'warm', 3.2, 'Informal', 3, 'other', 'casual', nan, 'freetime'], 'label': 606})
# (607, {'feature': [7, '666633', 'warm', 1.1, 'Formal', 3, 'smooth', 'street', 'straight', 'freetime'], 'label': 607})
# (608, {'feature': [9, '164A0A', 'warm', 3.2, 'Informal', 1, 'smooth', 'boho', nan, 'freetime'], 'label': 608})
# (609, {'feature': [9, 'DFC8B2', 'warm', 3.2, 'Informal', 1, 'smooth', 'boho', nan, 'freetime'], 'label': 609})
# (610, {'feature': [9, 'FFFF00', 'warm', 3.2, 'Informal', 1, 'checked', 'boho', nan, 'freetime'], 'label': 610})
# (611, {'feature': [9, '9A8176', 'warm', 3.2, 'Informal', 1, 'checked', 'boho', nan, 'freetime'], 'label': 611})
# (612, {'feature': [9, '00008b', 'warm', 3.2, 'Informal', 1, 'checked', 'boho', nan, 'freetime'], 'label': 612})
# (613, {'feature': [8, '0000FF', 'cold', 3.0, 'Informal', 2, 'horizontal_stripes', 'street', 'tight', 'freetime'], 'label': 613})
# (614, {'feature': [8, '666633', 'cold', 3.1, 'Informal', 1, 'smooth', 'boho', 'straight', 'freetime'], 'label': 614})
# (615, {'feature': [8, 'B11730', 'cold', 3.1, 'Informal', 1, 'smooth', 'boho', 'straight', 'freetime'], 'label': 615})
# (616, {'feature': [8, 'DEB24C', 'cold', 3.0, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 616})
# (617, {'feature': [8, '800000', 'cold', 3.0, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 617})
# (618, {'feature': [8, 'FFFFFF', 'cold', 3.0, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 618})
# (619, {'feature': [8, 'B94600', 'cold', 3.0, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 619})
# (620, {'feature': [8, '000081', 'cold', 1.1, 'Informal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 620})
# (621, {'feature': [9, 'D3D3D3', 'cold', 3.2, 'Informal', 2, 'geometric', 'boho', nan, 'freetime'], 'label': 621})
# (622, {'feature': [9, 'FFC0CB', 'warm', 2.0, 'Informal', 1, 'smooth', 'casual', 'straight', 'freetime'], 'label': 622})
# (623, {'feature': [9, 'FFFFFF', 'warm', 2.0, 'Informal', 1, 'smooth', 'casual', 'straight', 'freetime'], 'label': 623})
# (624, {'feature': [9, 'FFFF00', 'warm', 1.2, 'Informal', 2, 'liberty', 'street', 'straight', 'freetime'], 'label': 624})
# (625, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Informal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 625})
# (626, {'feature': [8, '800000', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 626})
# (627, {'feature': [8, 'C19A6B', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 627})
# (628, {'feature': [8, 'BBE2AD', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 628})
# (629, {'feature': [8, '000000', 'cold', 1.1, 'Informal', 1, 'smooth', 'minimal', 'tight', 'work'], 'label': 629})
# (630, {'feature': [8, 'B94600', 'cold', 3.0, 'Informal', 1, 'smooth', 'minimal', 'tight', 'freetime'], 'label': 630})
# (631, {'feature': [8, 'DEB24C', 'cold', 3.0, 'Informal', 1, 'smooth', 'minimal', 'tight', 'freetime'], 'label': 631})
# (632, {'feature': [8, 'DFC8B2', 'cold', 3.0, 'Informal', 1, 'smooth', 'minimal', 'tight', 'freetime'], 'label': 632})
# (633, {'feature': [8, '808080', 'cold', 3.1, 'Informal', 1, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 633})
# (634, {'feature': [8, 'B94600', 'cold', 3.1, 'Informal', 1, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 634})
# (635, {'feature': [9, '000000', 'cold', 3.1, 'Informal', 1, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 635})
# (636, {'feature': [8, 'D3D3D3', 'cold', 3.1, 'Informal', 1, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 636})
# (637, {'feature': [8, '00008b', 'cold', 3.1, 'Informal', 1, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 637})
# (638, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Formal', 1, 'floral', 'classic', 'straight', 'freetime'], 'label': 638})
# (639, {'feature': [8, 'B94600', 'cold', 3.0, 'Informal', 2, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 639})
# (640, {'feature': [8, 'C19A6B', 'cold', 3.0, 'Informal', 2, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 640})
# (641, {'feature': [8, '614051', 'cold', 1.1, 'Informal', 1, 'smooth', 'minimal', 'straight', 'work'], 'label': 641})
# (642, {'feature': [8, 'F29985', 'cold', 3.1, 'Informal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 642})
# (643, {'feature': [8, 'DFC8B2', 'cold', 3.1, 'Informal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 643})
# (644, {'feature': [8, '00008b', 'cold', 3.1, 'Informal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 644})
# (645, {'feature': [7, '87CEFA', 'warm', 2.0, 'Informal', 2, 'polka_dot', 'classic', 'straight', 'freetime'], 'label': 645})
# (646, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 2, 'polka_dot', 'classic', 'straight', 'freetime'], 'label': 646})
# (647, {'feature': [7, 'B94600', 'warm', 2.0, 'Informal', 2, 'polka_dot', 'classic', 'straight', 'freetime'], 'label': 647})
# (648, {'feature': [7, 'D84936', 'warm', 2.0, 'Informal', 2, 'polka_dot', 'classic', 'straight', 'freetime'], 'label': 648})
# (649, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Informal', 2, 'printed', 'casual', 'straight', 'freetime'], 'label': 649})
# (650, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 2, 'printed', 'casual', 'straight', 'freetime'], 'label': 650})
# (651, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 2, 'printed', 'casual', 'straight', 'freetime'], 'label': 651})
# (652, {'feature': [7, '008000', 'warm', 2.0, 'Informal', 2, 'printed', 'casual', 'straight', 'freetime'], 'label': 652})
# (653, {'feature': [7, '87CEFA', 'warm', 2.0, 'Informal', 1, 'printed', 'casual', 'straight', 'freetime'], 'label': 653})
# (654, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Informal', 1, 'printed', 'casual', 'straight', 'freetime'], 'label': 654})
# (655, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 1, 'printed', 'casual', 'straight', 'freetime'], 'label': 655})
# (656, {'feature': [9, 'ECE9D6', 'warm', 2.0, 'Informal', 2, 'vertical_stripes', 'boho', 'straight', 'freetime'], 'label': 656})
# (657, {'feature': [8, '000000', 'cold', 1.1, 'Formal', 4, 'smooth', 'casual', 'tight', 'freetime'], 'label': 657})
# (658, {'feature': [7, '000000', 'cold', 1.1, 'Informal', 2, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 658})
# (659, {'feature': [7, '00008b', 'cold', 1.1, 'Informal', 2, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 659})
# (660, {'feature': [7, 'B94600', 'cold', 1.1, 'Informal', 2, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 660})
# (661, {'feature': [9, '153668', 'cold', 3.2, 'Formal', 1, 'geometric', 'classic', nan, 'work'], 'label': 661})
# (662, {'feature': [9, 'b3832e', 'warm', 3.2, 'Informal', 2, 'smooth', 'boho', nan, 'work'], 'label': 662})
# (663, {'feature': [9, 'E65A5B', 'warm', 3.2, 'Informal', 2, 'smooth', 'boho', nan, 'work'], 'label': 663})
# (664, {'feature': [9, '000000', 'warm', 3.2, 'Informal', 2, 'smooth', 'boho', nan, 'work'], 'label': 664})
# (665, {'feature': [9, '800000', 'warm', 3.2, 'Informal', 2, 'smooth', 'boho', nan, 'work'], 'label': 665})
# (666, {'feature': [9, '9A8176', 'cold', 3.2, 'Informal', 1, 'horizontal_stripes', 'boho', nan, 'freetime'], 'label': 666})
# (667, {'feature': [9, 'ECE9D6', 'cold', 3.2, 'Informal', 1, 'horizontal_stripes', 'boho', nan, 'freetime'], 'label': 667})
# (668, {'feature': [9, '768597', 'cold', 3.2, 'Informal', 1, 'horizontal_stripes', 'boho', nan, 'freetime'], 'label': 668})
# (669, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 2, 'mariniere', 'casual', 'straight', 'freetime'], 'label': 669})
# (670, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 2, 'mariniere', 'casual', 'straight', 'freetime'], 'label': 670})
# (671, {'feature': [7, 'FFA500', 'warm', 2.0, 'Informal', 2, 'mariniere', 'casual', 'straight', 'freetime'], 'label': 671})
# (672, {'feature': [7, '87CEFA', 'warm', 2.0, 'Informal', 2, 'mariniere', 'casual', 'straight', 'freetime'], 'label': 672})
# (673, {'feature': [7, '00008b', 'warm', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'work'], 'label': 673})
# (674, {'feature': [7, '000000', 'warm', 1.2, 'Informal', 1, 'smooth', 'minimal', 'tight', 'work'], 'label': 674})
# (675, {'feature': [8, 'DEB24C', 'cold', 3.0, 'Formal', 1, 'smooth', 'classic', 'loose', 'freetime'], 'label': 675})
# (676, {'feature': [8, '9A8176', 'cold', 3.0, 'Formal', 1, 'smooth', 'classic', 'loose', 'freetime'], 'label': 676})
# (677, {'feature': [8, 'DFC8B2', 'cold', 3.0, 'Formal', 1, 'smooth', 'classic', 'loose', 'freetime'], 'label': 677})
# (678, {'feature': [8, '462C0E', 'cold', 3.0, 'Formal', 1, 'smooth', 'classic', 'loose', 'freetime'], 'label': 678})
# (679, {'feature': [8, '5F5E5E', 'cold', 3.0, 'Formal', 1, 'smooth', 'classic', 'loose', 'freetime'], 'label': 679})
# (680, {'feature': [8, '164A0A', 'cold', 3.0, 'Formal', 1, 'smooth', 'classic', 'loose', 'freetime'], 'label': 680})
# (681, {'feature': [8, '462C0E', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'straight', 'work'], 'label': 681})
# (682, {'feature': [8, '164A0A', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'straight', 'work'], 'label': 682})
# (683, {'feature': [8, '9A8176', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'straight', 'work'], 'label': 683})
# (684, {'feature': [8, '5F5E5E', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'straight', 'work'], 'label': 684})
# (685, {'feature': [8, 'DEB24C', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'straight', 'work'], 'label': 685})
# (686, {'feature': [8, 'DFC8B2', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'straight', 'work'], 'label': 686})
# (687, {'feature': [8, '008000', 'warm', 3.1, 'Formal', 2, 'animal_print', 'street', 'straight', 'freetime'], 'label': 687})
# (688, {'feature': [7, 'FFA500', 'warm', 1.2, 'Formal', 3, 'retro', 'classic', 'straight', 'freetime'], 'label': 688})
# (689, {'feature': [7, '008000', 'cold', 2.0, 'Informal', 2, 'vertical_stripes', 'street', 'straight', 'freetime'], 'label': 689})
# (690, {'feature': [7, '00008b', 'cold', 2.0, 'Informal', 2, 'vertical_stripes', 'street', 'straight', 'freetime'], 'label': 690})
# (691, {'feature': [7, 'E65A5B', 'cold', 2.0, 'Informal', 2, 'vertical_stripes', 'street', 'straight', 'freetime'], 'label': 691})
# (692, {'feature': [8, 'FFFFFF', 'cold', 2.0, 'Formal', 1, 'printed', 'classic', 'straight', 'work'], 'label': 692})
# (693, {'feature': [7, '00008b', 'cold', 1.1, 'Formal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 693})
# (694, {'feature': [7, '87CEFA', 'cold', 1.1, 'Formal', 1, 'smooth', 'classic', 'tight', 'freetime'], 'label': 694})
# (695, {'feature': [9, '5F5E5E', 'warm', 1.1, 'Informal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 695})
# (696, {'feature': [9, '000081', 'warm', 1.1, 'Informal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 696})
# (697, {'feature': [7, 'D3D3D3', 'cold', 3.0, 'Informal', 2, 'smooth', 'street', 'loose', 'work'], 'label': 697})
# (698, {'feature': [7, '000000', 'cold', 2.0, 'Informal', 1, 'horizontal_stripes', 'minimal', 'tight', 'freetime'], 'label': 698})
# (699, {'feature': [7, 'B11730', 'warm', 2.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 699})
# (700, {'feature': [8, '000000', 'cold', 3.1, 'Informal', 1, 'smooth', 'night', 'straight', 'night'], 'label': 700})
# (701, {'feature': [7, '00008b', 'cold', 3.1, 'Informal', 1, 'smooth', 'night', 'straight', 'night'], 'label': 701})
# (702, {'feature': [8, '462C0E', 'cold', 3.1, 'Informal', 1, 'smooth', 'night', 'straight', 'night'], 'label': 702})
# (703, {'feature': [8, '666633', 'cold', 3.1, 'Informal', 1, 'smooth', 'night', 'straight', 'night'], 'label': 703})
# (704, {'feature': [7, '008000', 'warm', 3.1, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 704})
# (705, {'feature': [7, '614051', 'warm', 2.0, 'Informal', 2, 'vertical_stripes', 'boho', 'loose', 'freetime'], 'label': 705})
# (706, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 2, 'vertical_stripes', 'boho', 'loose', 'freetime'], 'label': 706})
# (707, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Informal', 2, 'vertical_stripes', 'boho', 'loose', 'freetime'], 'label': 707})
# (708, {'feature': [7, '5F5E5E', 'warm', 2.0, 'Informal', 2, 'vertical_stripes', 'boho', 'loose', 'freetime'], 'label': 708})
# (709, {'feature': [7, '808080', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'straight', 'freetime'], 'label': 709})
# (710, {'feature': [7, '87CEFA', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'straight', 'freetime'], 'label': 710})
# (711, {'feature': [7, '000000', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'straight', 'freetime'], 'label': 711})
# (712, {'feature': [7, 'FFFF00', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 712})
# (713, {'feature': [7, 'FFC0CB', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 713})
# (714, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 714})
# (715, {'feature': [7, '40E0D0', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 715})
# (716, {'feature': [7, 'ECE9D6', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 716})
# (717, {'feature': [7, 'E65A5B', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 717})
# (718, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 3, 'ethnic', 'boho', 'loose', 'freetime'], 'label': 718})
# (719, {'feature': [7, '000081', 'warm', 1.1, 'Formal', 2, 'smooth', 'boho', 'tight', 'freetime'], 'label': 719})
# (720, {'feature': [7, '00008b', 'cold', 2.0, 'Informal', 2, 'smooth', 'classic', 'straight', 'work'], 'label': 720})
# (721, {'feature': [7, 'D84936', 'cold', 2.0, 'Informal', 2, 'smooth', 'classic', 'straight', 'work'], 'label': 721})
# (722, {'feature': [7, '87CEFA', 'cold', 3.0, 'Informal', 2, 'smooth', 'minimal', 'loose', 'work'], 'label': 722})
# (723, {'feature': [7, '000000', 'warm', 1.2, 'Informal', 1, 'floral', 'boho', 'straight', 'freetime'], 'label': 723})
# (724, {'feature': [7, '462C0E', 'warm', 1.2, 'Formal', 1, 'vertical_stripes', 'classic', 'straight', 'freetime'], 'label': 724})
# (725, {'feature': [7, '000081', 'warm', 1.2, 'Formal', 1, 'vertical_stripes', 'classic', 'straight', 'freetime'], 'label': 725})
# (726, {'feature': [7, '87CEFA', 'warm', 3.1, 'Formal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 726})
# (727, {'feature': [9, '462C0E', 'cold', 1.1, 'Formal', 3, 'animal_print', 'street', 'straight', 'freetime'], 'label': 727})
# (728, {'feature': [8, '000081', 'warm', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 728})
# (729, {'feature': [7, '000081', 'warm', 1.1, 'Informal', 2, 'vertical_stripes', 'street', 'loose', 'freetime'], 'label': 729})
# (730, {'feature': [7, '00008b', 'warm', 2.0, 'Formal', 2, 'printed', 'classic', 'tight', 'freetime'], 'label': 730})
# (731, {'feature': [7, 'FFC0CB', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 731})
# (732, {'feature': [7, '666633', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 732})
# (733, {'feature': [7, 'FFFFFF', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 733})
# (734, {'feature': [7, '00008b', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 734})
# (735, {'feature': [7, 'FFFF00', 'warm', 2.0, 'Informal', 2, 'animal_print', 'street', 'straight', 'freetime'], 'label': 735})
# (736, {'feature': [7, 'FFFFFF', 'cold', 1.1, 'Formal', 2, 'miniprint', 'classic', 'tight', 'freetime'], 'label': 736})
# (737, {'feature': [7, '00008b', 'warm', 1.1, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 737})
# (738, {'feature': [7, 'DEB24C', 'warm', 1.1, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 738})
# (739, {'feature': [7, 'DFC8B2', 'cold', 1.1, 'Informal', 2, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 739})
# (740, {'feature': [7, 'F29985', 'cold', 1.1, 'Informal', 2, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 740})
# (741, {'feature': [7, '008000', 'cold', 1.1, 'Informal', 2, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 741})
# (742, {'feature': [9, '000000', 'warm', 1.2, 'Formal', 2, 'polka_dot', 'classic', 'straight', 'freetime'], 'label': 742})
# (743, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 1, 'herringbone', 'boho', 'tight', 'freetime'], 'label': 743})
# (744, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 1, 'smooth', 'minimal', 'tight', 'freetime'], 'label': 744})
# (745, {'feature': [7, '00008b', 'warm', 1.1, 'Informal', 1, 'smooth', 'minimal', 'tight', 'freetime'], 'label': 745})
# (746, {'feature': [7, '00008b', 'warm', 1.1, 'Informal', 2, 'miniprint', 'minimal', 'tight', 'freetime'], 'label': 746})
# (747, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 2, 'miniprint', 'minimal', 'tight', 'freetime'], 'label': 747})
# (748, {'feature': [7, '008000', 'warm', 2.0, 'Formal', 1, 'vertical_stripes', 'classic', 'oversize', 'freetime'], 'label': 748})
# (749, {'feature': [7, '000000', 'warm', 2.0, 'Formal', 1, 'vertical_stripes', 'classic', 'oversize', 'freetime'], 'label': 749})
# (750, {'feature': [7, 'DEB24C', 'warm', 3.1, 'Formal', 3, 'vertical_stripes', 'minimal', 'straight', 'working_girl'], 'label': 750})
# (751, {'feature': [7, 'ECE9D6', 'warm', 1.2, 'Informal', 2, 'vertical_stripes', 'minimal', 'straight', 'work'], 'label': 751})
# (752, {'feature': [7, '000081', 'cold', 2.0, 'Informal', 2, 'horizontal_stripes', 'casual', 'tight', 'freetime'], 'label': 752})
# (753, {'feature': [7, 'FFA500', 'cold', 2.0, 'Informal', 2, 'horizontal_stripes', 'casual', 'tight', 'freetime'], 'label': 753})
# (754, {'feature': [8, 'DFC8B2', 'cold', 1.1, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 754})
# (755, {'feature': [8, '00008b', 'cold', 1.1, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 755})
# (756, {'feature': [9, 'DFC8B2', 'cold', 3.0, 'Formal', 2, 'floral', 'classic', 'straight', 'freetime'], 'label': 756})
# (757, {'feature': [9, '000000', 'cold', 3.0, 'Formal', 2, 'floral', 'classic', 'straight', 'freetime'], 'label': 757})
# (758, {'feature': [9, '000000', 'cold', 3.2, 'Formal', 1, 'smooth', 'classic', 'tight', 'freetime'], 'label': 758})
# (759, {'feature': [9, '666633', 'cold', 3.2, 'Formal', 1, 'smooth', 'classic', 'tight', 'freetime'], 'label': 759})
# (760, {'feature': [9, '00008b', 'warm', 1.1, 'Informal', 2, 'floral', 'boho', 'loose', 'work'], 'label': 760})
# (761, {'feature': [9, '000000', 'warm', 1.1, 'Informal', 2, 'checked', 'boho', 'loose', 'freetime'], 'label': 761})
# (762, {'feature': [9, '8e1d03', 'warm', 1.1, 'Informal', 2, 'checked', 'boho', 'loose', 'freetime'], 'label': 762})
# ...
# (5225, {'feature': [9, '000000', 'warm', 2.0, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 5225})
# (5226, {'feature': [9, 'FFA500', 'warm', 2.0, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 5226})
# (5227, {'feature': [9, 'FFFFFF', 'warm', 2.0, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 5227})
# (5228, {'feature': [8, '000000', 'cold', 1.1, 'Informal', 2, 'prince_of_wales', 'street', 'straight', 'work'], 'label': 5228})
# (5229, {'feature': [8, 'FFA500', 'cold', 1.1, 'Informal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 5229})
# (5230, {'feature': [8, '000000', 'cold', 1.1, 'Informal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 5230})
# (5231, {'feature': [8, '00008b', 'cold', 1.1, 'Formal', 1, 'smooth', 'classic', 'tight', 'freetime'], 'label': 5231})
# (5232, {'feature': [8, '000000', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 5232})
# (5233, {'feature': [8, '808080', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 5233})
# (5234, {'feature': [8, '000000', 'cold', 1.1, 'Formal', 5, 'smooth', 'night', 'tight', 'night'], 'label': 5234})
# (5235, {'feature': [8, '00008b', 'cold', 1.1, 'Formal', 3, 'animal_print', 'street', 'tight', 'night'], 'label': 5235})
# (5236, {'feature': [8, '000000', 'cold', 1.1, 'Formal', 3, 'animal_print', 'street', 'tight', 'night'], 'label': 5236})
# (5237, {'feature': [8, '000000', 'warm', 2.0, 'Formal', 2, 'animal_print', 'classic', 'straight', 'freetime'], 'label': 5237})
# (5238, {'feature': [8, '000000', 'cold', 1.2, 'Formal', 2, 'sheets', 'classic', 'straight', 'freetime'], 'label': 5238})
# (5239, {'feature': [8, '000000', 'cold', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 5239})
# (5240, {'feature': [9, 'FFFFFF', 'cold', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 5240})
# (5241, {'feature': [8, '000000', 'cold', 3.0, 'Informal', 2, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 5241})
# (5242, {'feature': [8, '00008b', 'cold', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'night'], 'label': 5242})
# (5243, {'feature': [8, '000000', 'warm', 2.0, 'Informal', 2, 'smooth', 'minimal', 'loose', 'working_girl'], 'label': 5243})
# (5244, {'feature': [8, 'B94600', 'warm', 2.0, 'Informal', 2, 'smooth', 'minimal', 'loose', 'working_girl'], 'label': 5244})
# (5245, {'feature': [8, 'ECE9D6', 'warm', 2.0, 'Informal', 2, 'animal_print', 'street', 'straight', 'freetime'], 'label': 5245})
# (5246, {'feature': [8, '164A0A', 'cold', 3.1, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 5246})
# (5247, {'feature': [8, 'D3D3D3', 'cold', 3.0, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 5247})
# (5248, {'feature': [9, '00008b', 'cold', 3.1, 'Formal', 1, 'smooth', 'classic', 'straight', 'working_girl'], 'label': 5248})
# (5249, {'feature': [9, '000000', 'cold', 1.1, 'Informal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 5249})
# (5250, {'feature': [9, 'BBE2AD', 'warm', 1.1, 'Informal', 3, 'two_tone', 'boho', 'loose', 'freetime'], 'label': 5250})
# (5251, {'feature': [9, 'ECE9D6', 'cold', 3.1, 'Formal', 2, 'two_tone', 'minimal', 'tight', 'special_occasion'], 'label': 5251})
# (5252, {'feature': [9, 'DFC8B2', 'warm', 2.0, 'Informal', 2, 'vertical_stripes', 'street', 'loose', 'freetime'], 'label': 5252})
# (5253, {'feature': [9, 'FFFFFF', 'cold', 1.1, 'Formal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 5253})
# (5254, {'feature': [9, '00008b', 'cold', 1.2, 'Formal', 1, 'smooth', 'classic', 'tight', 'night'], 'label': 5254})
# (5255, {'feature': [9, '008000', 'cold', 2.0, 'Informal', 1, 'miniprint', 'street', 'straight', 'freetime'], 'label': 5255})
# (5256, {'feature': [9, '000000', 'cold', 2.0, 'Informal', 1, 'miniprint', 'street', 'straight', 'freetime'], 'label': 5256})
# (5257, {'feature': [9, '000000', 'warm', 1.2, 'Formal', 2, 'polka_dot', 'street', 'straight', 'freetime'], 'label': 5257})
# (5258, {'feature': [8, '000000', 'cold', 1.2, 'Informal', 3, 'smooth', 'street', 'straight', 'night'], 'label': 5258})
# (5259, {'feature': [8, '000000', 'warm', 3.1, 'Informal', 2, 'animal_print', 'street', 'loose', 'freetime'], 'label': 5259})
# (5260, {'feature': [9, '808080', 'cold', 3.0, 'Informal', 1, 'smooth', 'street', 'straight', 'freetime'], 'label': 5260})
# (5261, {'feature': [9, '000000', 'cold', 1.2, 'Informal', 2, 'floral', 'boho', 'loose', 'freetime'], 'label': 5261})
# (5262, {'feature': [9, '164A0A', 'warm', 1.1, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 5262})
# (5263, {'feature': [9, '666633', 'warm', 1.1, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 5263})
# (5264, {'feature': [9, '00008b', 'warm', 1.1, 'Informal', 3, 'floral', 'boho', 'straight', 'freetime'], 'label': 5264})
# (5265, {'feature': [8, '000000', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 5265})
# (5266, {'feature': [8, 'DFC8B2', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 5266})
# (5267, {'feature': [8, 'F29985', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 5267})
# (5268, {'feature': [8, '008000', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 5268})
# (5269, {'feature': [8, 'B94600', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 5269})
# (5270, {'feature': [8, '000000', 'cold', 3.1, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 5270})
# (5271, {'feature': [9, '87CEFA', 'warm', 1.1, 'Formal', 2, 'smooth', 'boho', 'tight', 'freetime'], 'label': 5271})
# (5272, {'feature': [9, '000000', 'warm', 2.0, 'Informal', 4, 'smooth', 'classic', 'straight', 'freetime'], 'label': 5272})
# (5273, {'feature': [9, '666633', 'warm', 2.0, 'Informal', 4, 'smooth', 'classic', 'straight', 'freetime'], 'label': 5273})
# (5274, {'feature': [9, 'ECE9D6', 'warm', 2.0, 'Informal', 4, 'smooth', 'classic', 'straight', 'freetime'], 'label': 5274})
# (5275, {'feature': [9, 'A57E62', 'cold', 3.1, 'Informal', 5, 'smooth', 'night', 'tight', 'night'], 'label': 5275})
# (5276, {'feature': [9, '5C2F83', 'cold', 3.1, 'Informal', 5, 'smooth', 'night', 'tight', 'night'], 'label': 5276})
# (5277, {'feature': [9, '00008b', 'cold', 3.1, 'Informal', 1, 'smooth', 'classic', 'tight', 'freetime'], 'label': 5277})
# (5278, {'feature': [9, 'FFFF00', 'cold', 3.1, 'Informal', 1, 'smooth', 'classic', 'tight', 'freetime'], 'label': 5278})
# (5279, {'feature': [9, 'D3D3D3', 'cold', 3.1, 'Informal', 1, 'smooth', 'classic', 'tight', 'freetime'], 'label': 5279})
# (5280, {'feature': [9, '008000', 'cold', 3.0, 'Informal', 2, 'smooth', 'street', 'loose', 'freetime'], 'label': 5280})
# (5281, {'feature': [9, 'D3D3D3', 'cold', 3.0, 'Informal', 2, 'smooth', 'street', 'loose', 'freetime'], 'label': 5281})
# (5282, {'feature': [9, '00008b', 'cold', 1.1, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 5282})
# (5283, {'feature': [9, 'DFC8B2', 'cold', 1.1, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 5283})
# (5284, {'feature': [9, '008000', 'cold', 1.1, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 5284})
# (5285, {'feature': [9, '00008b', 'warm', 2.0, 'Informal', 1, 'horizontal_stripes', 'casual', 'straight', 'freetime'], 'label': 5285})
# (5286, {'feature': [9, 'FFFFFF', 'warm', 2.0, 'Informal', 1, 'horizontal_stripes', 'casual', 'straight', 'freetime'], 'label': 5286})
# (5287, {'feature': [9, '164A0A', 'cold', 1.1, 'Formal', 1, 'smooth', 'classic', 'loose', 'freetime'], 'label': 5287})
# (5288, {'feature': [9, '5F5E5E', 'cold', 3.0, 'Informal', 1, 'smooth', 'street', 'loose', 'freetime'], 'label': 5288})
# (5289, {'feature': [9, '462C0E', 'cold', 3.0, 'Informal', 2, 'smooth', 'boho', 'oversize', 'freetime'], 'label': 5289})
# (5290, {'feature': [9, 'ECE9D6', 'cold', 3.0, 'Informal', 2, 'smooth', 'boho', 'oversize', 'freetime'], 'label': 5290})
# (5291, {'feature': [9, '000000', 'cold', 1.1, 'Informal', 1, 'smooth', 'street', 'loose', 'freetime'], 'label': 5291})
# (5292, {'feature': [9, '87CEFA', 'warm', 3.0, 'Formal', 1, 'vertical_stripes', 'casual', 'straight', 'freetime'], 'label': 5292})
# (5293, {'feature': [9, 'FFC0CB', 'warm', 3.0, 'Formal', 1, 'vertical_stripes', 'casual', 'straight', 'freetime'], 'label': 5293})
# (5294, {'feature': [9, '87CEFA', 'warm', 2.0, 'Formal', 1, 'vertical_stripes', 'classic', 'straight', 'freetime'], 'label': 5294})
# (5295, {'feature': [9, '000000', 'warm', 2.0, 'Formal', 2, 'polka_dot', 'classic', 'tight', 'freetime'], 'label': 5295})
# (5296, {'feature': [8, '000000', 'cold', 1.1, 'Formal', 3, 'smooth', 'night', 'tight', 'night'], 'label': 5296})
# (5297, {'feature': [8, '000000', 'cold', 1.1, 'Informal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 5297})
# (5298, {'feature': [8, '5F5E5E', 'cold', 3.2, 'Informal', 1, 'army', 'boho', nan, 'freetime'], 'label': 5298})
# (5299, {'feature': [8, 'FFA500', 'cold', 3.2, 'Informal', 1, 'army', 'boho', nan, 'freetime'], 'label': 5299})
# (5300, {'feature': [9, '5F5E5E', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 5300})
# (5301, {'feature': [9, '000000', 'cold', 1.1, 'Formal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 5301})
# (5302, {'feature': [9, 'ECE9D6', 'cold', 2.0, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 5302})
# (5303, {'feature': [9, '000000', 'cold', 2.0, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 5303})
# (5304, {'feature': [9, '000000', 'cold', 3.1, 'Informal', 1, 'smooth', 'casual', 'straight', 'freetime'], 'label': 5304})
# (5305, {'feature': [9, 'C19A6B', 'cold', 3.1, 'Informal', 1, 'smooth', 'casual', 'straight', 'freetime'], 'label': 5305})
# (5306, {'feature': [9, '00008b', 'cold', 3.1, 'Informal', 1, 'smooth', 'casual', 'straight', 'freetime'], 'label': 5306})
# (5307, {'feature': [9, '164A0A', 'cold', 3.1, 'Informal', 1, 'smooth', 'casual', 'straight', 'freetime'], 'label': 5307})
# (5308, {'feature': [9, 'C19A6B', 'cold', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 5308})
# (5309, {'feature': [9, '00008b', 'cold', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 5309})
# (5310, {'feature': [9, '000000', 'cold', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 5310})
# (5311, {'feature': [9, '00008b', 'cold', 1.1, 'Informal', 4, 'smooth', 'minimal', 'tight', 'working_girl'], 'label': 5311})
# (5312, {'feature': [9, '000000', 'warm', 1.2, 'Informal', 1, 'smooth', 'street', 'straight', 'freetime'], 'label': 5312})
# (5313, {'feature': [9, '666633', 'warm', 1.2, 'Informal', 1, 'smooth', 'street', 'straight', 'freetime'], 'label': 5313})
# (5314, {'feature': [9, '00008b', 'warm', 1.2, 'Informal', 1, 'smooth', 'street', 'straight', 'freetime'], 'label': 5314})
# (5315, {'feature': [9, '00008b', 'warm', 3.1, 'Formal', 2, 'miniprint', 'street', 'straight', 'freetime'], 'label': 5315})
# (5316, {'feature': [9, '000000', 'warm', 1.2, 'Informal', 2, 'vertical_stripes', 'street', 'straight', 'freetime'], 'label': 5316})
# (5317, {'feature': [9, 'ECE9D6', 'warm', 1.2, 'Formal', 3, 'floral', 'classic', 'straight', 'freetime'], 'label': 5317})
# (5318, {'feature': [9, '87CEFA', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 5318})
# (5319, {'feature': [9, 'DFC8B2', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 5319})
# (5320, {'feature': [9, '666633', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 5320})
# (5321, {'feature': [9, '00008b', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 5321})
# (5322, {'feature': [9, '000000', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 5322})
# (5323, {'feature': [9, '00008b', 'cold', 1.1, 'Formal', 1, 'miniprint', 'classic', 'tight', 'freetime'], 'label': 5323})
# (5324, {'feature': [9, '164A0A', 'warm', 1.1, 'Informal', 2, 'camouflage', 'street', 'straight', 'freetime'], 'label': 5324})
# (5325, {'feature': [9, '000000', 'cold', 1.1, 'Formal', 4, 'smooth', 'street', 'tight', 'freetime'], 'label': 5325})
# (5326, {'feature': [9, '666633', 'cold', 1.1, 'Formal', 4, 'smooth', 'street', 'tight', 'freetime'], 'label': 5326})
# (5327, {'feature': [9, 'DFC8B2', 'cold', 1.1, 'Formal', 4, 'smooth', 'street', 'tight', 'freetime'], 'label': 5327})
# (5328, {'feature': [9, '000000', 'cold', 1.2, 'Informal', 2, 'floral', 'boho', 'straight', 'freetime'], 'label': 5328})
# (5329, {'feature': [9, '000081', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 5329})
# (5330, {'feature': [9, 'fdf7b2', 'cold', 1.1, 'Formal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 5330})
# (5331, {'feature': [9, '666633', 'warm', 1.1, 'Informal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 5331})
# (5332, {'feature': [9, 'B94600', 'warm', 1.1, 'Informal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 5332})
# (5333, {'feature': [9, '00008b', 'warm', 1.1, 'Informal', 2, 'sheets', 'boho', 'loose', 'freetime'], 'label': 5333})
# (5334, {'feature': [9, '00008b', 'cold', 1.2, 'Informal', 2, 'floral', 'boho', 'loose', 'freetime'], 'label': 5334})
# (5335, {'feature': [9, '00008b', 'warm', 3.1, 'Informal', 2, 'floral', 'boho', 'loose', 'freetime'], 'label': 5335})
# (5336, {'feature': [9, 'ECE9D6', 'cold', 3.1, 'Informal', 1, 'sheets', 'street', 'loose', 'freetime'], 'label': 5336})
# (5337, {'feature': [9, '00008b', 'cold', 3.0, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 5337})
# (5338, {'feature': [9, '000000', 'cold', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'work'], 'label': 5338})
# (5339, {'feature': [9, 'C7A2A2', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 5339})
# (5340, {'feature': [9, 'ECE9D6', 'cold', 3.0, 'Informal', 2, 'horizontal_stripes', 'casual', 'straight', 'freetime'], 'label': 5340})
# (5341, {'feature': [9, 'FFC0CB', 'cold', 3.0, 'Informal', 2, 'horizontal_stripes', 'casual', 'straight', 'freetime'], 'label': 5341})
# (5342, {'feature': [9, '000000', 'warm', 1.1, 'Informal', 1, 'miniprint', 'boho', 'straight', 'freetime'], 'label': 5342})
# (5343, {'feature': [9, 'DEB24C', 'warm', 2.0, 'Informal', 1, 'sheets', 'casual', 'loose', 'freetime'], 'label': 5343})
# (5344, {'feature': [9, 'FFA500', 'cold', 3.1, 'Formal', 2, 'floral', 'classic', 'tight', 'freetime'], 'label': 5344})
# (5345, {'feature': [9, '00008b', 'warm', 1.1, 'Informal', 1, 'smooth', 'minimal', 'loose', 'freetime'], 'label': 5345})
# (5346, {'feature': [9, '666633', 'cold', 1.1, 'Informal', 2, 'smooth', 'boho', 'tight', 'freetime'], 'label': 5346})
# (5347, {'feature': [9, 'A57E62', 'cold', 1.1, 'Informal', 2, 'smooth', 'boho', 'tight', 'freetime'], 'label': 5347})
# (5348, {'feature': [9, '000000', 'cold', 1.1, 'Informal', 2, 'smooth', 'boho', 'tight', 'freetime'], 'label': 5348})
# (5349, {'feature': [9, '000081', 'cold', 2.0, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 5349})
# (5350, {'feature': [9, '87CEFA', 'warm', 2.0, 'Informal', 1, 'vertical_stripes', 'boho', 'straight', 'work'], 'label': 5350})
# (5351, {'feature': [9, 'BBE2AD', 'warm', 2.0, 'Informal', 1, 'vertical_stripes', 'boho', 'straight', 'work'], 'label': 5351})
# (5352, {'feature': [9, 'FFFF00', 'warm', 2.0, 'Informal', 1, 'vertical_stripes', 'boho', 'straight', 'work'], 'label': 5352})
# (5353, {'feature': [9, 'FFC0CB', 'warm', 2.0, 'Informal', 1, 'vertical_stripes', 'boho', 'straight', 'work'], 'label': 5353})
# (5354, {'feature': [9, 'B11730', 'warm', 1.1, 'Informal', 2, 'floral', 'classic', 'straight', 'freetime'], 'label': 5354})
# (5355, {'feature': [9, '5C2F83', 'warm', 1.1, 'Informal', 2, 'floral', 'classic', 'straight', 'freetime'], 'label': 5355})
# (5356, {'feature': [7, '00008b', 'warm', 1.1, 'Informal', 1, 'smooth', 'boho', 'tight', 'freetime'], 'label': 5356})

# %%
# Comprobar que todos los nodos tienen el mismo número de features
feature_length = None
all_equal = True

for node, data in G.nodes(data=True):
    current_length = len(data['feature'])

    if feature_length is None:
        feature_length = current_length
    elif feature_length != current_length:
        all_equal = False
        break

if all_equal:
    print(f"Todos los nodos tienen el mismo número de features: {feature_length}")
else:
    print("No todos los nodos tienen el mismo número de features.")
# Out:
# Todos los nodos tienen el mismo número de features: 10

# %% [markdown]
# ___
# ## **SEASON7**
# ___

# %%
df_limpio_s7 = df_limpio[df_limpio['season']==7]

df_limpio_s7['id_nodo'] = range(len(df_limpio_s7))

G7 = nx.Graph()

for _, row in df_limpio_s7.iterrows():
    G7.add_node(row['id_nodo'], feature=[
        row['season'], row['hexadecimal'], row['weather'],
        row['nivel'], row['formalidad'], row['adventurous'], row['print'], row['style'],
        row['fit'], row['application']
    ], label=row['id_nodo'])


for node in G7.nodes(data=True):
    print(node)
# Out:
# <ipython-input-10-6c931b21a593>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio_s7['id_nodo'] = range(len(df_limpio_s7))
# (0, {'feature': [7, 'B11730', 'warm', 1.1, 'Formal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 0})
# (1, {'feature': [7, 'ECE9D6', 'warm', 3.0, 'Informal', 2, 'horizontal_stripes', 'classic', 'straight', 'work'], 'label': 1})
# (2, {'feature': [7, '5F5E5E', 'warm', 2.0, 'Informal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 2})
# (3, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 1, 'horizontal_stripes', 'casual', 'straight', 'freetime'], 'label': 3})
# (4, {'feature': [7, '000000', 'cold', 3.1, 'Informal', 3, 'sheets', 'casual', 'loose', 'freetime'], 'label': 4})
# (5, {'feature': [7, '00008b', 'cold', 3.1, 'Informal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 5})
# (6, {'feature': [7, '666633', 'cold', 3.1, 'Informal', 3, 'smooth', 'street', 'straight', 'freetime'], 'label': 6})
# (7, {'feature': [7, '00008b', 'cold', 3.1, 'Informal', 3, 'smooth', 'street', 'straight', 'freetime'], 'label': 7})
# (8, {'feature': [7, '008000', 'warm', 2.0, 'Informal', 1, 'vertical_stripes', 'boho', 'oversize', 'freetime'], 'label': 8})
# (9, {'feature': [7, '87CEFA', 'warm', 2.0, 'Informal', 1, 'vertical_stripes', 'boho', 'oversize', 'freetime'], 'label': 9})
# (10, {'feature': [7, 'D3D3D3', 'cold', 3.0, 'Informal', 2, 'horizontal_stripes', 'street', 'loose', 'freetime'], 'label': 10})
# (11, {'feature': [7, '000081', 'cold', 3.0, 'Informal', 2, 'horizontal_stripes', 'street', 'loose', 'freetime'], 'label': 11})
# (12, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 2, 'smooth', 'night', 'straight', 'freetime'], 'label': 12})
# (13, {'feature': [7, '008000', 'warm', 2.0, 'Informal', 2, 'smooth', 'night', 'straight', 'freetime'], 'label': 13})
# (14, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Informal', 2, 'smooth', 'night', 'straight', 'freetime'], 'label': 14})
# (15, {'feature': [7, '000000', 'warm', 2.0, 'Informal', 2, 'smooth', 'night', 'straight', 'freetime'], 'label': 15})
# (16, {'feature': [7, 'FFA500', 'warm', 2.0, 'Informal', 2, 'smooth', 'night', 'straight', 'freetime'], 'label': 16})
# (17, {'feature': [7, '000000', 'cold', 3.0, 'Informal', 1, 'smooth', 'boho', 'straight', 'freetime'], 'label': 17})
# (18, {'feature': [7, 'B11730', 'cold', 3.0, 'Informal', 1, 'smooth', 'boho', 'straight', 'freetime'], 'label': 18})
# (19, {'feature': [7, 'FFFFFF', 'cold', 3.0, 'Informal', 1, 'smooth', 'boho', 'straight', 'freetime'], 'label': 19})
# (20, {'feature': [7, 'DEB24C', 'cold', 3.0, 'Informal', 1, 'smooth', 'boho', 'straight', 'freetime'], 'label': 20})
# (21, {'feature': [7, '00008b', 'warm', 3.1, 'Informal', 1, 'smooth', 'street', 'straight', 'freetime'], 'label': 21})
# (22, {'feature': [7, '000000', 'cold', 1.1, 'Formal', 2, 'herringbone', 'classic', 'tight', 'working_girl'], 'label': 22})
# (23, {'feature': [7, 'FFFFFF', 'warm', 1.2, 'Formal', 2, 'floral', 'classic', 'loose', 'freetime'], 'label': 23})
# (24, {'feature': [7, '00008b', 'warm', 1.2, 'Formal', 2, 'floral', 'classic', 'loose', 'freetime'], 'label': 24})
# (25, {'feature': [7, 'F29985', 'warm', 2.0, 'Informal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 25})
# (26, {'feature': [7, 'BBE2AD', 'warm', 2.0, 'Informal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 26})
# (27, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Informal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 27})
# (28, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 28})
# (29, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Informal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 29})
# (30, {'feature': [7, '000000', 'warm', 2.0, 'Informal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 30})
# (31, {'feature': [7, '666633', 'warm', 1.1, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 31})
# (32, {'feature': [7, 'ECE9D6', 'warm', 1.1, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 32})
# (33, {'feature': [7, '008000', 'warm', 2.0, 'Formal', 2, 'floral', 'classic', 'straight', 'work'], 'label': 33})
# (34, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Formal', 2, 'floral', 'classic', 'straight', 'freetime'], 'label': 34})
# (35, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 35})
# (36, {'feature': [7, 'B94600', 'warm', 1.1, 'Formal', 3, 'retro', 'classic', 'straight', 'special_occasion'], 'label': 36})
# (37, {'feature': [7, '000081', 'cold', 1.1, 'Informal', 3, 'smooth', 'boho', 'straight', 'freetime'], 'label': 37})
# (38, {'feature': [7, 'FFC0CB', 'cold', 1.1, 'Informal', 3, 'smooth', 'boho', 'straight', 'freetime'], 'label': 38})
# (39, {'feature': [7, 'DEB24C', 'cold', 1.1, 'Informal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 39})
# (40, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 2, 'polka_dot', 'boho', 'straight', 'freetime'], 'label': 40})
# (41, {'feature': [7, 'F29985', 'warm', 2.0, 'Informal', 2, 'vertical_stripes', 'boho', 'straight', 'work'], 'label': 41})
# (42, {'feature': [7, '87CEFA', 'cold', 1.1, 'Formal', 2, 'smooth', 'classic', 'straight', 'work'], 'label': 42})
# (43, {'feature': [7, '00008b', 'cold', 1.1, 'Formal', 2, 'smooth', 'classic', 'straight', 'work'], 'label': 43})
# (44, {'feature': [7, '00008b', 'warm', 1.1, 'Informal', 2, 'smooth', 'minimal', 'tight', 'freetime'], 'label': 44})
# (45, {'feature': [7, '87CEFA', 'warm', 2.0, 'Formal', 2, 'printed', 'classic', 'loose', 'freetime'], 'label': 45})
# (46, {'feature': [7, 'FFA500', 'warm', 2.0, 'Informal', 2, 'sheets', 'boho', 'straight', 'freetime'], 'label': 46})
# (47, {'feature': [7, '5F5E5E', 'warm', 3.1, 'Informal', 2, 'smooth', 'minimal', 'loose', 'work'], 'label': 47})
# (48, {'feature': [7, 'FFC0CB', 'warm', 3.1, 'Informal', 2, 'smooth', 'minimal', 'loose', 'work'], 'label': 48})
# (49, {'feature': [7, '666633', 'warm', 3.1, 'Informal', 2, 'smooth', 'minimal', 'loose', 'work'], 'label': 49})
# (50, {'feature': [7, 'ECE9D6', 'warm', 3.0, 'Informal', 3, 'animal_print', 'casual', 'straight', 'freetime'], 'label': 50})
# (51, {'feature': [7, 'FFFFFF', 'warm', 1.1, 'Informal', 1, 'smooth', 'boho', 'tight', 'freetime'], 'label': 51})
# (52, {'feature': [7, 'ECE9D6', 'warm', 3.1, 'Informal', 3, 'floral', 'street', 'loose', 'freetime'], 'label': 52})
# (53, {'feature': [7, 'FFFF00', 'cold', 3.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 53})
# (54, {'feature': [7, '666633', 'warm', 2.0, 'Informal', 1, 'smooth', 'boho', 'loose', 'freetime'], 'label': 54})
# (55, {'feature': [7, '000000', 'warm', 2.0, 'Informal', 1, 'smooth', 'boho', 'loose', 'freetime'], 'label': 55})
# (56, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Informal', 2, 'smooth', 'boho', 'loose', 'freetime'], 'label': 56})
# (57, {'feature': [7, '000000', 'warm', 2.0, 'Informal', 2, 'smooth', 'boho', 'loose', 'freetime'], 'label': 57})
# (58, {'feature': [7, '000000', 'warm', 1.1, 'Formal', 2, 'smooth', 'classic', 'tight', 'freetime'], 'label': 58})
# (59, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Informal', 2, 'horizontal_stripes', 'street', 'loose', 'freetime'], 'label': 59})
# (60, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Informal', 2, 'horizontal_stripes', 'street', 'loose', 'freetime'], 'label': 60})
# (61, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 61})
# (62, {'feature': [7, '00008b', 'cold', 2.0, 'Informal', 1, 'horizontal_stripes', 'street', 'straight', 'freetime'], 'label': 62})
# (63, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 3, 'printed', 'street', 'straight', 'freetime'], 'label': 63})
# (64, {'feature': [7, '614051', 'warm', 3.2, 'Formal', 3, 'floral', 'classic', nan, 'freetime'], 'label': 64})
# (65, {'feature': [7, '008000', 'warm', 3.2, 'Formal', 3, 'floral', 'classic', nan, 'freetime'], 'label': 65})
# (66, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Formal', 2, 'floral', 'classic', 'straight', 'freetime'], 'label': 66})
# (67, {'feature': [7, '00008b', 'cold', 3.0, 'Informal', 1, 'printed', 'casual', 'straight', 'freetime'], 'label': 67})
# (68, {'feature': [7, '800000', 'warm', 3.2, 'Informal', 1, 'smooth', 'casual', nan, 'freetime'], 'label': 68})
# (69, {'feature': [7, '808080', 'warm', 3.2, 'Informal', 1, 'smooth', 'casual', nan, 'freetime'], 'label': 69})
# (70, {'feature': [7, '00008b', 'warm', 3.2, 'Informal', 1, 'smooth', 'casual', nan, 'freetime'], 'label': 70})
# (71, {'feature': [7, '000081', 'warm', 1.2, 'Informal', 3, 'floral', 'boho', 'straight', 'freetime'], 'label': 71})
# (72, {'feature': [7, '00008b', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 72})
# (73, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 73})
# (74, {'feature': [7, 'DFC8B2', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 74})
# (75, {'feature': [7, '000000', 'warm', 1.2, 'Informal', 3, 'floral', 'boho', 'straight', 'freetime'], 'label': 75})
# (76, {'feature': [7, '000000', 'warm', 3.0, 'Formal', 2, 'floral', 'boho', 'loose', 'freetime'], 'label': 76})
# (77, {'feature': [7, 'BBE2AD', 'warm', 2.0, 'Informal', 3, 'smooth', 'casual', 'straight', 'freetime'], 'label': 77})
# (78, {'feature': [7, '5F5E5E', 'warm', 2.0, 'Informal', 3, 'smooth', 'casual', 'straight', 'freetime'], 'label': 78})
# (79, {'feature': [7, '5F5E5E', 'warm', 2.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 79})
# (80, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 80})
# (81, {'feature': [7, '000000', 'warm', 3.1, 'Informal', 3, 'floral', 'street', 'loose', 'night'], 'label': 81})
# (82, {'feature': [7, 'FFFFFF', 'warm', 3.0, 'Informal', 3, 'horizontal_stripes', 'street', 'straight', 'freetime'], 'label': 82})
# (83, {'feature': [7, '000081', 'warm', 3.2, 'Informal', 1, 'horizontal_stripes', 'casual', nan, 'work'], 'label': 83})
# (84, {'feature': [7, 'FFC0CB', 'warm', 3.2, 'Informal', 1, 'horizontal_stripes', 'casual', nan, 'work'], 'label': 84})
# (85, {'feature': [7, '462C0E', 'warm', 1.1, 'Formal', 2, 'polka_dot', 'classic', 'loose', 'freetime'], 'label': 85})
# (86, {'feature': [7, '000000', 'warm', 1.1, 'Formal', 2, 'polka_dot', 'classic', 'loose', 'freetime'], 'label': 86})
# (87, {'feature': [7, '000081', 'cold', 1.1, 'Formal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 87})
# (88, {'feature': [7, '164A0A', 'cold', 3.1, 'Informal', 1, 'smooth', 'minimal', 'tight', 'work'], 'label': 88})
# (89, {'feature': [7, 'DFC8B2', 'warm', 1.1, 'Informal', 2, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 89})
# (90, {'feature': [7, 'DEB24C', 'warm', 3.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 90})
# (91, {'feature': [7, '800000', 'warm', 3.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 91})
# (92, {'feature': [7, '87CEFA', 'warm', 3.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 92})
# (93, {'feature': [7, 'FFA500', 'warm', 3.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 93})
# (94, {'feature': [7, '00008b', 'warm', 3.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 94})
# (95, {'feature': [7, '666633', 'warm', 3.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 95})
# (96, {'feature': [7, 'ECE9D6', 'warm', 3.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 96})
# (97, {'feature': [7, '000081', 'warm', 2.0, 'Informal', 1, 'horizontal_stripes', 'street', 'loose', 'freetime'], 'label': 97})
# (98, {'feature': [7, 'FFFF00', 'warm', 2.0, 'Informal', 1, 'horizontal_stripes', 'street', 'loose', 'freetime'], 'label': 98})
# (99, {'feature': [7, '000000', 'warm', 2.0, 'Informal', 1, 'horizontal_stripes', 'street', 'loose', 'freetime'], 'label': 99})
# (100, {'feature': [7, '000000', 'warm', 1.2, 'Informal', 2, 'ethnic', 'boho', 'straight', 'freetime'], 'label': 100})
# (101, {'feature': [7, 'B11730', 'warm', 1.2, 'Informal', 2, 'ethnic', 'boho', 'straight', 'freetime'], 'label': 101})
# (102, {'feature': [7, '000000', 'warm', 3.0, 'Formal', 2, 'floral', 'boho', 'loose', 'freetime'], 'label': 102})
# (103, {'feature': [7, 'FFFF00', 'warm', 2.0, 'Informal', 1, 'printed', 'classic', 'straight', 'freetime'], 'label': 103})
# (104, {'feature': [7, 'D84936', 'warm', 2.0, 'Informal', 1, 'printed', 'classic', 'straight', 'freetime'], 'label': 104})
# (105, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 1, 'printed', 'classic', 'straight', 'freetime'], 'label': 105})
# (106, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 1, 'printed', 'classic', 'straight', 'freetime'], 'label': 106})
# (107, {'feature': [7, '008000', 'warm', 2.0, 'Informal', 1, 'smooth', 'street', 'straight', 'work'], 'label': 107})
# (108, {'feature': [7, '666633', 'warm', 2.0, 'Informal', 1, 'smooth', 'street', 'straight', 'work'], 'label': 108})
# (109, {'feature': [7, 'DFC8B2', 'warm', 3.2, 'Informal', 3, 'smooth', 'casual', nan, 'freetime'], 'label': 109})
# (110, {'feature': [7, '800000', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 110})
# (111, {'feature': [7, 'FFC0CB', 'warm', 1.1, 'Informal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 111})
# (112, {'feature': [7, '008000', 'warm', 1.1, 'Informal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 112})
# (113, {'feature': [7, '164A0A', 'warm', 1.1, 'Informal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 113})
# (114, {'feature': [7, 'ECE9D6', 'warm', 1.1, 'Informal', 3, 'floral', 'boho', 'loose', 'freetime'], 'label': 114})
# (115, {'feature': [7, 'C19A6B', 'warm', 1.1, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 115})
# (116, {'feature': [7, 'B94600', 'warm', 1.1, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 116})
# (117, {'feature': [7, '000000', 'warm', 1.1, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 117})
# (118, {'feature': [7, '164A0A', 'warm', 1.1, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 118})
# (119, {'feature': [7, '164A0A', 'warm', 1.2, 'Formal', 2, 'retro', 'classic', 'loose', 'work'], 'label': 119})
# (120, {'feature': [7, '00008b', 'warm', 1.2, 'Formal', 1, 'floral', 'classic', 'straight', 'freetime'], 'label': 120})
# (121, {'feature': [7, 'D84936', 'warm', 1.2, 'Formal', 1, 'floral', 'classic', 'straight', 'freetime'], 'label': 121})
# (122, {'feature': [7, '008000', 'warm', 1.1, 'Informal', 2, 'floral', 'street', 'straight', 'freetime'], 'label': 122})
# (123, {'feature': [7, 'D84936', 'warm', 1.2, 'Informal', 2, 'smooth', 'minimal', 'straight', 'work'], 'label': 123})
# (124, {'feature': [7, '462C0E', 'warm', 3.2, 'Formal', 3, 'smooth', 'classic', nan, 'freetime'], 'label': 124})
# (125, {'feature': [7, 'A57E62', 'warm', 1.1, 'Informal', 3, 'vertical_stripes', 'casual', 'straight', 'freetime'], 'label': 125})
# (126, {'feature': [7, 'BBA9E4', 'warm', 3.0, 'Formal', 1, 'cachemere', 'boho', 'loose', 'freetime'], 'label': 126})
# (127, {'feature': [7, 'DFC8B2', 'warm', 2.0, 'Informal', 2, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 127})
# (128, {'feature': [7, 'B94600', 'warm', 2.0, 'Informal', 2, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 128})
# (129, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Informal', 2, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 129})
# (130, {'feature': [7, '000000', 'warm', 3.0, 'Formal', 2, 'smooth', 'classic', 'oversize', 'freetime'], 'label': 130})
# (131, {'feature': [7, 'ECE9D6', 'warm', 3.0, 'Formal', 2, 'smooth', 'classic', 'oversize', 'freetime'], 'label': 131})
# (132, {'feature': [7, '00008b', 'warm', 1.2, 'Formal', 2, 'retro', 'boho', 'straight', 'work'], 'label': 132})
# (133, {'feature': [7, '164A0A', 'warm', 1.2, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 133})
# (134, {'feature': [7, 'D84936', 'warm', 3.1, 'Formal', 2, 'smooth', 'minimal', 'tight', 'special_occasion'], 'label': 134})
# (135, {'feature': [7, '00008b', 'cold', 3.1, 'Informal', 3, 'floral', 'boho', 'loose', 'freetime'], 'label': 135})
# (136, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 136})
# (137, {'feature': [7, 'C19A6B', 'warm', 2.0, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 137})
# (138, {'feature': [7, '87CEFA', 'cold', 2.0, 'Informal', 1, 'smooth', 'casual', 'straight', 'freetime'], 'label': 138})
# (139, {'feature': [7, '00008b', 'warm', 1.1, 'Informal', 1, 'horizontal_stripes', 'casual', 'straight', 'freetime'], 'label': 139})
# (140, {'feature': [7, '008000', 'warm', 1.1, 'Informal', 1, 'horizontal_stripes', 'casual', 'straight', 'freetime'], 'label': 140})
# (141, {'feature': [7, '000000', 'warm', 1.2, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 141})
# (142, {'feature': [7, 'FFFFFF', 'warm', 1.2, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 142})
# (143, {'feature': [7, '000000', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 143})
# (144, {'feature': [7, '00008b', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 144})
# (145, {'feature': [7, '808080', 'cold', 3.0, 'Informal', 4, 'smooth', 'minimal', 'loose', 'freetime'], 'label': 145})
# (146, {'feature': [7, '000000', 'cold', 3.0, 'Informal', 4, 'smooth', 'minimal', 'loose', 'freetime'], 'label': 146})
# (147, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Informal', 2, 'floral', 'boho', 'straight', 'freetime'], 'label': 147})
# (148, {'feature': [7, '808080', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'work'], 'label': 148})
# (149, {'feature': [7, '000000', 'warm', 3.1, 'Informal', 2, 'floral', 'street', 'loose', 'freetime'], 'label': 149})
# (150, {'feature': [7, 'C19A6B', 'cold', 2.0, 'Formal', 3, 'retro', 'classic', 'straight', 'work'], 'label': 150})
# (151, {'feature': [7, '87CEFA', 'warm', 2.0, 'Informal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 151})
# (152, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Informal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 152})
# (153, {'feature': [7, '000000', 'warm', 2.0, 'Informal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 153})
# (154, {'feature': [7, '000081', 'warm', 1.1, 'Formal', 4, 'smooth', 'classic', 'tight', 'freetime'], 'label': 154})
# (155, {'feature': [7, 'DFC8B2', 'warm', 1.1, 'Formal', 3, 'animal_print', 'classic', 'straight', 'freetime'], 'label': 155})
# (156, {'feature': [7, '666633', 'warm', 3.1, 'Informal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 156})
# (157, {'feature': [7, 'FFFFFF', 'warm', 3.1, 'Informal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 157})
# (158, {'feature': [7, '00008b', 'warm', 3.1, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 158})
# (159, {'feature': [7, '666633', 'warm', 3.1, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 159})
# (160, {'feature': [7, '666633', 'warm', 1.1, 'Formal', 1, 'pied_de_poule', 'classic', 'tight', 'freetime'], 'label': 160})
# (161, {'feature': [7, 'DFC8B2', 'warm', 1.1, 'Formal', 1, 'pied_de_poule', 'classic', 'tight', 'freetime'], 'label': 161})
# (162, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 162})
# (163, {'feature': [7, '0000FF', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 163})
# (164, {'feature': [7, '000000', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 164})
# (165, {'feature': [7, '164A0A', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 165})
# (166, {'feature': [7, '614051', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 166})
# (167, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 2, 'horizontal_stripes', 'boho', 'straight', 'freetime'], 'label': 167})
# (168, {'feature': [7, 'ECE9D6', 'warm', 1.2, 'Formal', 3, 'floral', 'boho', 'loose', 'freetime'], 'label': 168})
# (169, {'feature': [7, '87CEFA', 'warm', 1.1, 'Formal', 2, 'vertical_stripes', 'casual', 'tight', 'freetime'], 'label': 169})
# (170, {'feature': [7, 'FFFFFF', 'warm', 3.1, 'Formal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 170})
# (171, {'feature': [7, '00008b', 'warm', 3.1, 'Formal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 171})
# (172, {'feature': [7, 'DFC8B2', 'cold', 3.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 172})
# (173, {'feature': [7, '008000', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 173})
# (174, {'feature': [7, '0000FF', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 174})
# (175, {'feature': [7, '008000', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 175})
# (176, {'feature': [7, '00008b', 'warm', 1.2, 'Formal', 1, 'floral', 'classic', 'loose', 'work'], 'label': 176})
# (177, {'feature': [7, 'B11730', 'warm', 1.2, 'Informal', 2, 'printed', 'street', 'tight', 'freetime'], 'label': 177})
# (178, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Informal', 2, 'printed', 'street', 'straight', 'freetime'], 'label': 178})
# (179, {'feature': [7, '000000', 'warm', 3.1, 'Formal', 2, 'floral', 'boho', 'loose', 'freetime'], 'label': 179})
# (180, {'feature': [7, 'FFC0CB', 'warm', 1.1, 'Formal', 3, 'floral', 'classic', 'loose', 'freetime'], 'label': 180})
# (181, {'feature': [7, '000081', 'warm', 1.1, 'Formal', 3, 'floral', 'classic', 'loose', 'freetime'], 'label': 181})
# (182, {'feature': [7, '87CEFA', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 182})
# (183, {'feature': [7, 'C19A6B', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 183})
# (184, {'feature': [7, 'DEB24C', 'cold', 3.0, 'Informal', 4, 'smooth', 'casual', 'straight', 'freetime'], 'label': 184})
# (185, {'feature': [7, '0000FF', 'cold', 3.0, 'Informal', 4, 'smooth', 'casual', 'straight', 'freetime'], 'label': 185})
# (186, {'feature': [7, 'B11730', 'cold', 3.0, 'Informal', 4, 'smooth', 'casual', 'straight', 'freetime'], 'label': 186})
# (187, {'feature': [7, 'D3D3D3', 'cold', 3.0, 'Informal', 4, 'smooth', 'casual', 'straight', 'freetime'], 'label': 187})
# (188, {'feature': [7, '000000', 'cold', 3.0, 'Informal', 4, 'smooth', 'casual', 'straight', 'freetime'], 'label': 188})
# (189, {'feature': [7, 'FFFFFF', 'cold', 3.0, 'Informal', 4, 'smooth', 'casual', 'straight', 'freetime'], 'label': 189})
# (190, {'feature': [7, 'D84936', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 190})
# (191, {'feature': [7, 'FFFF00', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 191})
# (192, {'feature': [7, '164A0A', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 192})
# (193, {'feature': [7, 'DFC8B2', 'cold', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 193})
# (194, {'feature': [7, 'DEB24C', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 194})
# (195, {'feature': [7, 'FFC0CB', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 195})
# (196, {'feature': [7, '00008b', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 196})
# (197, {'feature': [7, '000081', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 197})
# (198, {'feature': [7, '000000', 'warm', 1.1, 'Formal', 4, 'smooth', 'classic', 'tight', 'freetime'], 'label': 198})
# (199, {'feature': [7, '000000', 'cold', 1.2, 'Informal', 1, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 199})
# (200, {'feature': [7, '164A0A', 'warm', 2.0, 'Informal', 1, 'smooth', 'boho', 'loose', 'freetime'], 'label': 200})
# (201, {'feature': [7, '666633', 'warm', 2.0, 'Informal', 1, 'smooth', 'boho', 'loose', 'freetime'], 'label': 201})
# (202, {'feature': [7, 'FFFFFF', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 202})
# (203, {'feature': [7, '00008b', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 203})
# (204, {'feature': [7, '000000', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 204})
# (205, {'feature': [7, '00008b', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 205})
# (206, {'feature': [7, 'DEB24C', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 206})
# (207, {'feature': [7, 'FFC0CB', 'cold', 3.0, 'Informal', 1, 'smooth', 'casual', 'loose', 'freetime'], 'label': 207})
# (208, {'feature': [7, 'E65A5B', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 208})
# (209, {'feature': [7, '000000', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 209})
# (210, {'feature': [7, '800000', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 210})
# (211, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 211})
# (212, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 212})
# (213, {'feature': [7, '00008b', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'night'], 'label': 213})
# (214, {'feature': [7, '00008b', 'warm', 3.0, 'Informal', 3, 'smooth', 'street', 'straight', 'freetime'], 'label': 214})
# (215, {'feature': [7, 'DFC8B2', 'warm', 3.0, 'Informal', 3, 'smooth', 'street', 'straight', 'freetime'], 'label': 215})
# (216, {'feature': [7, 'B94600', 'warm', 3.0, 'Informal', 3, 'smooth', 'street', 'straight', 'freetime'], 'label': 216})
# (217, {'feature': [7, '462C0E', 'warm', 1.1, 'Informal', 2, 'bodoque', 'street', 'loose', 'freetime'], 'label': 217})
# (218, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 218})
# (219, {'feature': [7, '000000', 'warm', 1.2, 'Formal', 2, 'smooth', 'classic', 'loose', 'night'], 'label': 219})
# (220, {'feature': [7, '000081', 'warm', 1.1, 'Formal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 220})
# (221, {'feature': [7, 'FFFF00', 'cold', 3.0, 'Informal', 2, 'smooth', 'boho', 'loose', 'freetime'], 'label': 221})
# (222, {'feature': [7, '000000', 'cold', 1.1, 'Informal', 1, 'smooth', 'minimal', 'tight', 'working_girl'], 'label': 222})
# (223, {'feature': [7, '00008b', 'cold', 1.1, 'Informal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 223})
# (224, {'feature': [7, '000000', 'warm', 1.2, 'Formal', 2, 'miniprint', 'classic', 'tight', 'night'], 'label': 224})
# (225, {'feature': [7, '00008b', 'cold', 3.0, 'Informal', 2, nan, 'casual', 'oversize', 'freetime'], 'label': 225})
# (226, {'feature': [7, '000000', 'cold', 1.2, 'Formal', 2, 'floral', 'boho', 'straight', 'freetime'], 'label': 226})
# (227, {'feature': [7, '0000FF', 'cold', 3.0, 'Informal', 2, 'printed', 'boho', 'loose', 'freetime'], 'label': 227})
# (228, {'feature': [7, '00008b', 'warm', 1.1, 'Informal', 1, 'smooth', 'boho', 'tight', 'freetime'], 'label': 228})
# (229, {'feature': [7, 'DFC8B2', 'warm', 2.0, 'Informal', 2, 'floral', 'boho', 'straight', 'freetime'], 'label': 229})
# (230, {'feature': [7, '00008b', 'cold', 2.0, 'Informal', 2, 'geometric', 'boho', 'loose', 'work'], 'label': 230})
# (231, {'feature': [7, '666633', 'warm', 3.1, 'Informal', 3, 'smooth', 'casual', 'straight', 'freetime'], 'label': 231})
# (232, {'feature': [7, 'FFC0CB', 'warm', 1.1, 'Informal', 3, 'vertical_stripes', 'classic', 'straight', 'freetime'], 'label': 232})
# (233, {'feature': [7, '000081', 'warm', 1.1, 'Informal', 3, 'vertical_stripes', 'classic', 'straight', 'freetime'], 'label': 233})
# (234, {'feature': [7, 'FFFFFF', 'warm', 1.1, 'Informal', 3, 'vertical_stripes', 'boho', 'straight', 'freetime'], 'label': 234})
# (235, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 3, 'vertical_stripes', 'boho', 'straight', 'freetime'], 'label': 235})
# (236, {'feature': [7, '87CEFA', 'warm', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 236})
# (237, {'feature': [7, 'FFFFFF', 'warm', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 237})
# (238, {'feature': [7, '00008b', 'warm', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 238})
# (239, {'feature': [7, 'DEB24C', 'warm', 3.2, 'Informal', 3, 'retro', 'boho', nan, 'work'], 'label': 239})
# (240, {'feature': [7, 'D3D3D3', 'warm', 3.0, 'Informal', 1, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 240})
# (241, {'feature': [7, '00008b', 'warm', 3.0, 'Informal', 1, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 241})
# (242, {'feature': [7, '000000', 'warm', 3.0, 'Informal', 1, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 242})
# (243, {'feature': [7, 'DEB24C', 'warm', 3.1, 'Formal', 5, 'floral', 'boho', 'straight', 'freetime'], 'label': 243})
# (244, {'feature': [7, 'FFFF00', 'warm', 3.2, 'Informal', 3, 'other', 'casual', nan, 'freetime'], 'label': 244})
# (245, {'feature': [7, 'B11730', 'warm', 3.2, 'Informal', 3, 'other', 'casual', nan, 'freetime'], 'label': 245})
# (246, {'feature': [7, '40E0D0', 'warm', 3.2, 'Informal', 3, 'other', 'casual', nan, 'freetime'], 'label': 246})
# (247, {'feature': [7, '666633', 'warm', 1.1, 'Formal', 3, 'smooth', 'street', 'straight', 'freetime'], 'label': 247})
# (248, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Informal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 248})
# (249, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Formal', 1, 'floral', 'classic', 'straight', 'freetime'], 'label': 249})
# (250, {'feature': [7, '87CEFA', 'warm', 2.0, 'Informal', 2, 'polka_dot', 'classic', 'straight', 'freetime'], 'label': 250})
# (251, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 2, 'polka_dot', 'classic', 'straight', 'freetime'], 'label': 251})
# (252, {'feature': [7, 'B94600', 'warm', 2.0, 'Informal', 2, 'polka_dot', 'classic', 'straight', 'freetime'], 'label': 252})
# (253, {'feature': [7, 'D84936', 'warm', 2.0, 'Informal', 2, 'polka_dot', 'classic', 'straight', 'freetime'], 'label': 253})
# (254, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Informal', 2, 'printed', 'casual', 'straight', 'freetime'], 'label': 254})
# (255, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 2, 'printed', 'casual', 'straight', 'freetime'], 'label': 255})
# (256, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 2, 'printed', 'casual', 'straight', 'freetime'], 'label': 256})
# (257, {'feature': [7, '008000', 'warm', 2.0, 'Informal', 2, 'printed', 'casual', 'straight', 'freetime'], 'label': 257})
# (258, {'feature': [7, '87CEFA', 'warm', 2.0, 'Informal', 1, 'printed', 'casual', 'straight', 'freetime'], 'label': 258})
# (259, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Informal', 1, 'printed', 'casual', 'straight', 'freetime'], 'label': 259})
# (260, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 1, 'printed', 'casual', 'straight', 'freetime'], 'label': 260})
# (261, {'feature': [7, '000000', 'cold', 1.1, 'Informal', 2, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 261})
# (262, {'feature': [7, '00008b', 'cold', 1.1, 'Informal', 2, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 262})
# (263, {'feature': [7, 'B94600', 'cold', 1.1, 'Informal', 2, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 263})
# (264, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 2, 'mariniere', 'casual', 'straight', 'freetime'], 'label': 264})
# (265, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 2, 'mariniere', 'casual', 'straight', 'freetime'], 'label': 265})
# (266, {'feature': [7, 'FFA500', 'warm', 2.0, 'Informal', 2, 'mariniere', 'casual', 'straight', 'freetime'], 'label': 266})
# (267, {'feature': [7, '87CEFA', 'warm', 2.0, 'Informal', 2, 'mariniere', 'casual', 'straight', 'freetime'], 'label': 267})
# (268, {'feature': [7, '00008b', 'warm', 1.1, 'Formal', 2, 'smooth', 'casual', 'tight', 'work'], 'label': 268})
# (269, {'feature': [7, '000000', 'warm', 1.2, 'Informal', 1, 'smooth', 'minimal', 'tight', 'work'], 'label': 269})
# (270, {'feature': [7, 'FFA500', 'warm', 1.2, 'Formal', 3, 'retro', 'classic', 'straight', 'freetime'], 'label': 270})
# (271, {'feature': [7, '008000', 'cold', 2.0, 'Informal', 2, 'vertical_stripes', 'street', 'straight', 'freetime'], 'label': 271})
# (272, {'feature': [7, '00008b', 'cold', 2.0, 'Informal', 2, 'vertical_stripes', 'street', 'straight', 'freetime'], 'label': 272})
# (273, {'feature': [7, 'E65A5B', 'cold', 2.0, 'Informal', 2, 'vertical_stripes', 'street', 'straight', 'freetime'], 'label': 273})
# (274, {'feature': [7, '00008b', 'cold', 1.1, 'Formal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 274})
# (275, {'feature': [7, '87CEFA', 'cold', 1.1, 'Formal', 1, 'smooth', 'classic', 'tight', 'freetime'], 'label': 275})
# (276, {'feature': [7, 'D3D3D3', 'cold', 3.0, 'Informal', 2, 'smooth', 'street', 'loose', 'work'], 'label': 276})
# (277, {'feature': [7, '000000', 'cold', 2.0, 'Informal', 1, 'horizontal_stripes', 'minimal', 'tight', 'freetime'], 'label': 277})
# (278, {'feature': [7, 'B11730', 'warm', 2.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 278})
# (279, {'feature': [7, '00008b', 'cold', 3.1, 'Informal', 1, 'smooth', 'night', 'straight', 'night'], 'label': 279})
# (280, {'feature': [7, '008000', 'warm', 3.1, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 280})
# (281, {'feature': [7, '614051', 'warm', 2.0, 'Informal', 2, 'vertical_stripes', 'boho', 'loose', 'freetime'], 'label': 281})
# (282, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 2, 'vertical_stripes', 'boho', 'loose', 'freetime'], 'label': 282})
# (283, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Informal', 2, 'vertical_stripes', 'boho', 'loose', 'freetime'], 'label': 283})
# (284, {'feature': [7, '5F5E5E', 'warm', 2.0, 'Informal', 2, 'vertical_stripes', 'boho', 'loose', 'freetime'], 'label': 284})
# (285, {'feature': [7, '808080', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'straight', 'freetime'], 'label': 285})
# (286, {'feature': [7, '87CEFA', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'straight', 'freetime'], 'label': 286})
# (287, {'feature': [7, '000000', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'straight', 'freetime'], 'label': 287})
# (288, {'feature': [7, 'FFFF00', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 288})
# (289, {'feature': [7, 'FFC0CB', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 289})
# (290, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 290})
# (291, {'feature': [7, '40E0D0', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 291})
# (292, {'feature': [7, 'ECE9D6', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 292})
# (293, {'feature': [7, 'E65A5B', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'tight', 'freetime'], 'label': 293})
# (294, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 3, 'ethnic', 'boho', 'loose', 'freetime'], 'label': 294})
# (295, {'feature': [7, '000081', 'warm', 1.1, 'Formal', 2, 'smooth', 'boho', 'tight', 'freetime'], 'label': 295})
# (296, {'feature': [7, '00008b', 'cold', 2.0, 'Informal', 2, 'smooth', 'classic', 'straight', 'work'], 'label': 296})
# (297, {'feature': [7, 'D84936', 'cold', 2.0, 'Informal', 2, 'smooth', 'classic', 'straight', 'work'], 'label': 297})
# (298, {'feature': [7, '87CEFA', 'cold', 3.0, 'Informal', 2, 'smooth', 'minimal', 'loose', 'work'], 'label': 298})
# (299, {'feature': [7, '000000', 'warm', 1.2, 'Informal', 1, 'floral', 'boho', 'straight', 'freetime'], 'label': 299})
# (300, {'feature': [7, '462C0E', 'warm', 1.2, 'Formal', 1, 'vertical_stripes', 'classic', 'straight', 'freetime'], 'label': 300})
# (301, {'feature': [7, '000081', 'warm', 1.2, 'Formal', 1, 'vertical_stripes', 'classic', 'straight', 'freetime'], 'label': 301})
# (302, {'feature': [7, '87CEFA', 'warm', 3.1, 'Formal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 302})
# (303, {'feature': [7, '000081', 'warm', 1.1, 'Informal', 2, 'vertical_stripes', 'street', 'loose', 'freetime'], 'label': 303})
# (304, {'feature': [7, '00008b', 'warm', 2.0, 'Formal', 2, 'printed', 'classic', 'tight', 'freetime'], 'label': 304})
# (305, {'feature': [7, 'FFC0CB', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 305})
# (306, {'feature': [7, '666633', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 306})
# (307, {'feature': [7, 'FFFFFF', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 307})
# (308, {'feature': [7, '00008b', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 308})
# (309, {'feature': [7, 'FFFF00', 'warm', 2.0, 'Informal', 2, 'animal_print', 'street', 'straight', 'freetime'], 'label': 309})
# (310, {'feature': [7, 'FFFFFF', 'cold', 1.1, 'Formal', 2, 'miniprint', 'classic', 'tight', 'freetime'], 'label': 310})
# (311, {'feature': [7, '00008b', 'warm', 1.1, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 311})
# (312, {'feature': [7, 'DEB24C', 'warm', 1.1, 'Formal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 312})
# (313, {'feature': [7, 'DFC8B2', 'cold', 1.1, 'Informal', 2, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 313})
# (314, {'feature': [7, 'F29985', 'cold', 1.1, 'Informal', 2, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 314})
# (315, {'feature': [7, '008000', 'cold', 1.1, 'Informal', 2, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 315})
# (316, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 1, 'herringbone', 'boho', 'tight', 'freetime'], 'label': 316})
# (317, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 1, 'smooth', 'minimal', 'tight', 'freetime'], 'label': 317})
# (318, {'feature': [7, '00008b', 'warm', 1.1, 'Informal', 1, 'smooth', 'minimal', 'tight', 'freetime'], 'label': 318})
# (319, {'feature': [7, '00008b', 'warm', 1.1, 'Informal', 2, 'miniprint', 'minimal', 'tight', 'freetime'], 'label': 319})
# (320, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 2, 'miniprint', 'minimal', 'tight', 'freetime'], 'label': 320})
# (321, {'feature': [7, '008000', 'warm', 2.0, 'Formal', 1, 'vertical_stripes', 'classic', 'oversize', 'freetime'], 'label': 321})
# (322, {'feature': [7, '000000', 'warm', 2.0, 'Formal', 1, 'vertical_stripes', 'classic', 'oversize', 'freetime'], 'label': 322})
# (323, {'feature': [7, 'DEB24C', 'warm', 3.1, 'Formal', 3, 'vertical_stripes', 'minimal', 'straight', 'working_girl'], 'label': 323})
# (324, {'feature': [7, 'ECE9D6', 'warm', 1.2, 'Informal', 2, 'vertical_stripes', 'minimal', 'straight', 'work'], 'label': 324})
# (325, {'feature': [7, '000081', 'cold', 2.0, 'Informal', 2, 'horizontal_stripes', 'casual', 'tight', 'freetime'], 'label': 325})
# (326, {'feature': [7, 'FFA500', 'cold', 2.0, 'Informal', 2, 'horizontal_stripes', 'casual', 'tight', 'freetime'], 'label': 326})
# (327, {'feature': [7, 'A57E62', 'cold', 1.2, 'Informal', 2, 'animal_print', 'street', 'straight', 'freetime'], 'label': 327})
# (328, {'feature': [7, 'FFFF00', 'warm', 3.0, 'Formal', 2, 'geometric', 'classic', 'straight', 'freetime'], 'label': 328})
# (329, {'feature': [7, '00008b', 'warm', 2.0, 'Formal', 2, 'floral', 'classic', 'straight', 'freetime'], 'label': 329})
# (330, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Formal', 2, 'floral', 'classic', 'straight', 'freetime'], 'label': 330})
# (331, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Formal', 2, 'floral', 'classic', 'straight', 'freetime'], 'label': 331})
# (332, {'feature': [7, '000081', 'warm', 2.0, 'Formal', 2, 'floral', 'classic', 'straight', 'freetime'], 'label': 332})
# (333, {'feature': [7, 'DFC8B2', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 333})
# (334, {'feature': [7, '666633', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 334})
# (335, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 335})
# (336, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 336})
# (337, {'feature': [7, 'B94600', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 337})
# (338, {'feature': [7, 'DEB24C', 'cold', 2.0, 'Informal', 3, 'ethnic', 'boho', 'straight', 'work'], 'label': 338})
# (339, {'feature': [7, 'FFC0CB', 'cold', 2.0, 'Informal', 3, 'ethnic', 'boho', 'straight', 'work'], 'label': 339})
# (340, {'feature': [7, 'DEB24C', 'cold', 2.0, 'Formal', 3, 'retro', 'classic', 'straight', 'work'], 'label': 340})
# (341, {'feature': [7, 'ECE9D6', 'cold', 2.0, 'Formal', 3, 'retro', 'classic', 'straight', 'work'], 'label': 341})
# (342, {'feature': [7, 'FFC0CB', 'warm', 3.0, 'Informal', 2, 'floral', 'casual', 'loose', 'freetime'], 'label': 342})
# (343, {'feature': [7, '00008b', 'warm', 3.0, 'Informal', 1, 'floral', 'casual', 'loose', 'freetime'], 'label': 343})
# (344, {'feature': [7, 'FF00A8', 'warm', 3.1, 'Informal', 3, 'smooth', 'street', 'straight', 'freetime'], 'label': 344})
# (345, {'feature': [7, 'DEB24C', 'cold', 3.0, 'Informal', 2, 'smooth', 'boho', 'oversize', 'freetime'], 'label': 345})
# (346, {'feature': [7, '164A0A', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 346})
# (347, {'feature': [7, 'FFA500', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 347})
# (348, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 348})
# (349, {'feature': [7, '008000', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 349})
# (350, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 350})
# (351, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 351})
# (352, {'feature': [7, 'FFC0CB', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 352})
# (353, {'feature': [7, '462C0E', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 353})
# (354, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 354})
# (355, {'feature': [7, '000000', 'cold', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 355})
# (356, {'feature': [7, '00008b', 'cold', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 356})
# (357, {'feature': [7, '87CEFA', 'cold', 3.0, 'Informal', 2, 'horizontal_stripes', 'casual', 'loose', 'freetime'], 'label': 357})
# (358, {'feature': [7, 'FFFFFF', 'cold', 2.0, 'Informal', 4, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 358})
# (359, {'feature': [7, 'E65A5B', 'cold', 2.0, 'Informal', 4, 'smooth', 'minimal', 'straight', 'working_girl'], 'label': 359})
# (360, {'feature': [7, '000000', 'warm', 2.0, 'Informal', 2, 'smooth', 'boho', 'tight', 'night'], 'label': 360})
# (361, {'feature': [7, '000081', 'warm', 1.1, 'Informal', 3, 'smooth', 'boho', 'straight', 'freetime'], 'label': 361})
# (362, {'feature': [7, '00008b', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 362})
# (363, {'feature': [7, '800000', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 363})
# (364, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 364})
# (365, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Informal', 1, 'floral', 'boho', 'loose', 'freetime'], 'label': 365})
# (366, {'feature': [7, '00008b', 'warm', 3.0, 'Formal', 3, 'smooth', 'classic', 'tight', 'night'], 'label': 366})
# (367, {'feature': [7, 'B94600', 'warm', 3.0, 'Formal', 3, 'smooth', 'classic', 'tight', 'night'], 'label': 367})
# (368, {'feature': [7, '164A0A', 'warm', 3.0, 'Formal', 3, 'smooth', 'classic', 'tight', 'night'], 'label': 368})
# (369, {'feature': [7, 'B11730', 'warm', 3.0, 'Formal', 3, 'smooth', 'classic', 'tight', 'night'], 'label': 369})
# (370, {'feature': [7, 'DFC8B2', 'warm', 3.1, 'Informal', 3, 'animal_print', 'street', 'loose', 'freetime'], 'label': 370})
# (371, {'feature': [7, '164A0A', 'warm', 3.1, 'Formal', 1, 'smooth', 'classic', 'loose', 'work'], 'label': 371})
# (372, {'feature': [7, '00008b', 'cold', 1.1, 'Formal', 4, 'smooth', 'classic', 'straight', 'freetime'], 'label': 372})
# (373, {'feature': [7, '9A8176', 'cold', 1.1, 'Formal', 4, 'smooth', 'classic', 'straight', 'freetime'], 'label': 373})
# (374, {'feature': [7, 'FFC0CB', 'cold', 1.1, 'Formal', 4, 'smooth', 'classic', 'straight', 'freetime'], 'label': 374})
# (375, {'feature': [7, '000000', 'cold', 1.1, 'Formal', 4, 'smooth', 'classic', 'straight', 'freetime'], 'label': 375})
# (376, {'feature': [7, 'FFA500', 'warm', 1.1, 'Formal', 3, 'smooth', 'classic', 'straight', 'freetime'], 'label': 376})
# (377, {'feature': [7, 'DEB24C', 'warm', 1.1, 'Formal', 3, 'smooth', 'classic', 'straight', 'freetime'], 'label': 377})
# (378, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Informal', 5, 'smooth', 'boho', 'straight', 'night'], 'label': 378})
# (379, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Formal', 1, 'ethnic', 'classic', 'straight', 'freetime'], 'label': 379})
# (380, {'feature': [7, 'FFFFFF', 'cold', 2.0, 'Informal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 380})
# (381, {'feature': [7, '000000', 'cold', 2.0, 'Informal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 381})
# (382, {'feature': [7, '5F5E5E', 'cold', 2.0, 'Informal', 1, 'smooth', 'classic', 'straight', 'freetime'], 'label': 382})
# (383, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Informal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 383})
# (384, {'feature': [7, '000000', 'warm', 1.2, 'Formal', 2, 'vertical_stripes', 'classic', 'straight', 'freetime'], 'label': 384})
# (385, {'feature': [7, 'D3D3D3', 'cold', 3.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 385})
# (386, {'feature': [7, '87CEFA', 'warm', 1.1, 'Informal', 1, 'vertical_stripes', 'casual', 'straight', 'freetime'], 'label': 386})
# (387, {'feature': [7, '0000FF', 'cold', 3.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 387})
# (388, {'feature': [7, '666633', 'cold', 3.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 388})
# (389, {'feature': [7, 'FFC0CB', 'cold', 3.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 389})
# (390, {'feature': [7, '00008b', 'cold', 3.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 390})
# (391, {'feature': [7, 'FFFF00', 'cold', 3.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 391})
# (392, {'feature': [7, '0000FF', 'warm', 1.1, 'Informal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 392})
# (393, {'feature': [7, '5F5E5E', 'warm', 1.1, 'Informal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 393})
# (394, {'feature': [7, 'D3D3D3', 'warm', 1.1, 'Informal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 394})
# (395, {'feature': [7, 'B11730', 'warm', 1.1, 'Informal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 395})
# (396, {'feature': [7, '462C0E', 'warm', 1.1, 'Informal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 396})
# (397, {'feature': [7, '40E0D0', 'warm', 1.1, 'Informal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 397})
# (398, {'feature': [7, 'FFFFFF', 'warm', 1.1, 'Informal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 398})
# (399, {'feature': [7, 'C7A2A2', 'warm', 1.1, 'Informal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 399})
# ...
# (1790, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 1, 'smooth', 'casual', 'straight', 'freetime'], 'label': 1790})
# (1791, {'feature': [7, 'B11730', 'warm', 1.1, 'Formal', 2, 'other', 'classic', 'loose', 'freetime'], 'label': 1791})
# (1792, {'feature': [7, 'ECE9D6', 'warm', 1.2, 'Formal', 3, 'printed', 'classic', 'straight', 'freetime'], 'label': 1792})
# (1793, {'feature': [7, 'FFC0CB', 'warm', 2.0, 'Informal', 1, 'horizontal_stripes', 'street', 'loose', 'freetime'], 'label': 1793})
# (1794, {'feature': [7, '00008b', 'warm', 3.0, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 1794})
# (1795, {'feature': [7, '00008b', 'warm', 1.2, 'Informal', 3, 'smooth', 'street', 'tight', 'night'], 'label': 1795})
# (1796, {'feature': [7, '5F5E5E', 'warm', 1.1, 'Formal', 1, 'smooth', 'casual', 'tight', 'freetime'], 'label': 1796})
# (1797, {'feature': [7, 'DFC8B2', 'warm', 1.1, 'Informal', 2, 'smooth', 'minimal', 'tight', 'work'], 'label': 1797})
# (1798, {'feature': [7, '00008b', 'warm', 1.1, 'Informal', 2, 'smooth', 'minimal', 'tight', 'work'], 'label': 1798})
# (1799, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 2, 'smooth', 'minimal', 'tight', 'work'], 'label': 1799})
# (1800, {'feature': [7, '808080', 'warm', 1.2, 'Informal', 2, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 1800})
# (1801, {'feature': [7, '00008b', 'warm', 3.0, 'Informal', 2, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 1801})
# (1802, {'feature': [7, 'B11730', 'warm', 3.0, 'Informal', 2, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 1802})
# (1803, {'feature': [7, 'DFC8B2', 'warm', 1.1, 'Informal', 3, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 1803})
# (1804, {'feature': [7, '87CEFA', 'warm', 1.1, 'Informal', 3, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 1804})
# (1805, {'feature': [7, '008000', 'warm', 1.1, 'Informal', 3, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 1805})
# (1806, {'feature': [7, '0000FF', 'warm', 1.1, 'Informal', 3, 'smooth', 'minimal', 'straight', 'freetime'], 'label': 1806})
# (1807, {'feature': [7, '000081', 'warm', 3.2, 'Informal', 2, 'ethnic', 'boho', nan, 'work'], 'label': 1807})
# (1808, {'feature': [7, 'B94600', 'warm', 3.2, 'Informal', 2, 'ethnic', 'boho', nan, 'work'], 'label': 1808})
# (1809, {'feature': [7, '008000', 'warm', 1.2, 'Formal', 1, 'floral', 'classic', 'straight', 'freetime'], 'label': 1809})
# (1810, {'feature': [7, 'FFA500', 'warm', 1.2, 'Formal', 1, 'floral', 'classic', 'straight', 'freetime'], 'label': 1810})
# (1811, {'feature': [7, '9A8176', 'warm', 2.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 1811})
# (1812, {'feature': [7, 'FFFF00', 'warm', 2.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 1812})
# (1813, {'feature': [7, 'D3D3D3', 'warm', 2.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 1813})
# (1814, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 1814})
# (1815, {'feature': [7, 'E65A5B', 'warm', 2.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 1815})
# (1816, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 1816})
# (1817, {'feature': [7, '00008b', 'cold', 3.1, 'Informal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 1817})
# (1818, {'feature': [7, '000000', 'cold', 3.1, 'Informal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 1818})
# (1819, {'feature': [7, '666633', 'warm', 3.1, 'Formal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 1819})
# (1820, {'feature': [7, '00008b', 'warm', 3.1, 'Formal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 1820})
# (1821, {'feature': [7, 'D84936', 'warm', 1.1, 'Formal', 2, 'smooth', 'classic', 'tight', 'freetime'], 'label': 1821})
# (1822, {'feature': [7, '00008b', 'warm', 1.1, 'Formal', 1, 'smooth', 'classic', 'tight', 'freetime'], 'label': 1822})
# (1823, {'feature': [7, '00008b', 'warm', 1.2, 'Informal', 2, 'smooth', 'minimal', 'straight', 'night'], 'label': 1823})
# (1824, {'feature': [7, '000000', 'cold', 1.2, 'Informal', 2, 'other', 'minimal', 'straight', 'freetime'], 'label': 1824})
# (1825, {'feature': [7, '000000', 'cold', 1.1, 'Formal', 2, 'floral', 'classic', 'tight', 'work'], 'label': 1825})
# (1826, {'feature': [7, '666633', 'warm', 3.1, 'Formal', 1, 'smooth', 'classic', 'tight', 'freetime'], 'label': 1826})
# (1827, {'feature': [7, '666633', 'warm', 1.1, 'Informal', 2, 'floral', 'street', 'tight', 'freetime'], 'label': 1827})
# (1828, {'feature': [7, 'ECE9D6', 'warm', 3.2, 'Informal', 2, 'ethnic', 'boho', nan, 'freetime'], 'label': 1828})
# (1829, {'feature': [7, 'DEB24C', 'cold', 3.1, 'Formal', 2, 'sheets', 'classic', 'straight', 'freetime'], 'label': 1829})
# (1830, {'feature': [7, '008000', 'warm', 3.1, 'Formal', 2, 'sheets', 'classic', 'straight', 'freetime'], 'label': 1830})
# (1831, {'feature': [7, 'DEB24C', 'warm', 3.1, 'Formal', 2, 'sheets', 'classic', 'straight', 'freetime'], 'label': 1831})
# (1832, {'feature': [7, '000000', 'warm', 3.2, 'Informal', 1, 'geometric', 'boho', nan, 'freetime'], 'label': 1832})
# (1833, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 1, 'smooth', 'street', 'tight', 'work'], 'label': 1833})
# (1834, {'feature': [7, '462C0E', 'warm', 2.0, 'Informal', 2, 'vertical_stripes', 'boho', 'oversize', 'freetime'], 'label': 1834})
# (1835, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 2, 'vertical_stripes', 'boho', 'oversize', 'freetime'], 'label': 1835})
# (1836, {'feature': [7, 'E65A5B', 'warm', 3.1, 'Informal', 2, 'smooth', 'casual', 'straight', 'freetime'], 'label': 1836})
# (1837, {'feature': [7, 'ECE9D6', 'cold', 2.0, 'Formal', 2, 'smooth', 'classic', 'tight', 'night'], 'label': 1837})
# (1838, {'feature': [7, 'FFFF00', 'cold', 3.0, 'Formal', 2, 'miniprint', 'classic', 'straight', 'work'], 'label': 1838})
# (1839, {'feature': [7, 'FFFFFF', 'cold', 3.0, 'Formal', 2, 'miniprint', 'classic', 'straight', 'work'], 'label': 1839})
# (1840, {'feature': [7, '00008b', 'cold', 3.0, 'Formal', 2, 'miniprint', 'classic', 'straight', 'work'], 'label': 1840})
# (1841, {'feature': [7, '5F5E5E', 'warm', 2.0, 'Informal', 1, 'smooth', 'boho', 'straight', 'freetime'], 'label': 1841})
# (1842, {'feature': [7, '40E0D0', 'cold', 3.0, 'Formal', 2, 'animal_print', 'street', 'loose', 'freetime'], 'label': 1842})
# (1843, {'feature': [7, '000000', 'cold', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 1843})
# (1844, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Informal', 1, 'horizontal_stripes', 'casual', 'straight', 'work'], 'label': 1844})
# (1845, {'feature': [7, 'ECE9D6', 'cold', 3.1, 'Formal', 2, 'miniprint', 'classic', 'tight', 'freetime'], 'label': 1845})
# (1846, {'feature': [7, '00008b', 'cold', 3.1, 'Formal', 2, 'floral', 'classic', 'tight', 'work'], 'label': 1846})
# (1847, {'feature': [7, 'BBE2AD', 'warm', 1.1, 'Informal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 1847})
# (1848, {'feature': [7, 'FFFFFF', 'warm', 1.1, 'Informal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 1848})
# (1849, {'feature': [7, 'E65A5B', 'warm', 1.1, 'Informal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 1849})
# (1850, {'feature': [7, 'DEB24C', 'warm', 1.1, 'Informal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 1850})
# (1851, {'feature': [7, '000081', 'warm', 1.1, 'Informal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 1851})
# (1852, {'feature': [7, 'DFC8B2', 'warm', 1.1, 'Informal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 1852})
# (1853, {'feature': [7, 'FFC0CB', 'warm', 1.1, 'Informal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 1853})
# (1854, {'feature': [7, '00008b', 'warm', 1.1, 'Informal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 1854})
# (1855, {'feature': [7, '00008b', 'cold', 3.1, 'Informal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 1855})
# (1856, {'feature': [7, 'B11730', 'cold', 3.1, 'Informal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 1856})
# (1857, {'feature': [7, 'DFC8B2', 'cold', 3.1, 'Informal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 1857})
# (1858, {'feature': [7, 'FFFF00', 'cold', 3.1, 'Informal', 1, 'smooth', 'street', 'tight', 'freetime'], 'label': 1858})
# (1859, {'feature': [7, '666633', 'warm', 2.0, 'Informal', 2, 'horizontal_stripes', 'boho', 'loose', 'freetime'], 'label': 1859})
# (1860, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 2, 'horizontal_stripes', 'boho', 'loose', 'freetime'], 'label': 1860})
# (1861, {'feature': [7, '666633', 'cold', 3.1, 'Formal', 3, 'smooth', 'classic', 'straight', 'freetime'], 'label': 1861})
# (1862, {'feature': [7, 'DFC8B2', 'cold', 3.1, 'Formal', 3, 'smooth', 'classic', 'straight', 'freetime'], 'label': 1862})
# (1863, {'feature': [7, 'FFFF00', 'warm', 3.2, 'Formal', 3, 'polka_dot', 'classic', nan, 'freetime'], 'label': 1863})
# (1864, {'feature': [7, '614051', 'warm', 3.2, 'Formal', 3, 'polka_dot', 'classic', nan, 'freetime'], 'label': 1864})
# (1865, {'feature': [7, '87CEFA', 'warm', 3.1, 'Informal', 1, 'smooth', 'casual', 'straight', 'freetime'], 'label': 1865})
# (1866, {'feature': [7, '00008b', 'warm', 1.2, 'Informal', 2, 'smooth', 'boho', 'straight', 'night'], 'label': 1866})
# (1867, {'feature': [7, 'D84936', 'warm', 1.2, 'Informal', 2, 'smooth', 'boho', 'straight', 'night'], 'label': 1867})
# (1868, {'feature': [7, 'B94600', 'warm', 1.2, 'Informal', 2, 'smooth', 'boho', 'straight', 'night'], 'label': 1868})
# (1869, {'feature': [7, '164A0A', 'warm', 1.2, 'Informal', 2, 'smooth', 'boho', 'straight', 'night'], 'label': 1869})
# (1870, {'feature': [7, '000000', 'warm', 1.2, 'Informal', 2, 'smooth', 'boho', 'straight', 'night'], 'label': 1870})
# (1871, {'feature': [7, '00008b', 'warm', 3.1, 'Formal', 3, 'geometric', 'classic', 'straight', 'freetime'], 'label': 1871})
# (1872, {'feature': [7, 'DEB24C', 'warm', 3.1, 'Formal', 3, 'geometric', 'classic', 'straight', 'freetime'], 'label': 1872})
# (1873, {'feature': [7, '164A0A', 'warm', 3.1, 'Formal', 3, 'geometric', 'classic', 'straight', 'freetime'], 'label': 1873})
# (1874, {'feature': [7, '800000', 'warm', 3.1, 'Formal', 3, 'geometric', 'classic', 'straight', 'freetime'], 'label': 1874})
# (1875, {'feature': [7, '808080', 'warm', 1.1, 'Formal', 2, 'vertical_stripes', 'boho', 'straight', 'freetime'], 'label': 1875})
# (1876, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Informal', 1, 'smooth', 'classic', 'straight', 'work'], 'label': 1876})
# (1877, {'feature': [7, 'DFC8B2', 'warm', 2.0, 'Formal', 3, 'floral', 'classic', 'straight', 'work'], 'label': 1877})
# (1878, {'feature': [7, 'FFFF00', 'warm', 2.0, 'Formal', 3, 'floral', 'classic', 'straight', 'work'], 'label': 1878})
# (1879, {'feature': [7, 'FFFFFF', 'warm', 2.0, 'Formal', 2, 'smooth', 'classic', 'straight', 'freetime'], 'label': 1879})
# (1880, {'feature': [7, '800000', 'warm', 3.0, 'Formal', 2, 'retro', 'classic', 'loose', 'work'], 'label': 1880})
# (1881, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Formal', 3, 'polka_dot', 'classic', 'straight', 'work'], 'label': 1881})
# (1882, {'feature': [7, 'B94600', 'warm', 2.0, 'Formal', 3, 'polka_dot', 'classic', 'straight', 'work'], 'label': 1882})
# (1883, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Formal', 3, 'polka_dot', 'classic', 'straight', 'work'], 'label': 1883})
# (1884, {'feature': [7, 'BBE2AD', 'warm', 1.1, 'Informal', 1, 'vertical_stripes', 'classic', 'straight', 'freetime'], 'label': 1884})
# (1885, {'feature': [7, 'DFC8B2', 'warm', 1.1, 'Informal', 1, 'vertical_stripes', 'classic', 'straight', 'freetime'], 'label': 1885})
# (1886, {'feature': [7, 'E65A5B', 'warm', 1.1, 'Informal', 1, 'vertical_stripes', 'classic', 'straight', 'freetime'], 'label': 1886})
# (1887, {'feature': [7, '000000', 'warm', 1.1, 'Informal', 1, 'vertical_stripes', 'classic', 'straight', 'freetime'], 'label': 1887})
# (1888, {'feature': [7, 'B11730', 'warm', 2.0, 'Formal', 2, 'floral', 'classic', 'straight', 'work'], 'label': 1888})
# (1889, {'feature': [7, '0000FF', 'warm', 3.0, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 1889})
# (1890, {'feature': [7, 'DEB24C', 'warm', 3.0, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 1890})
# (1891, {'feature': [7, '000081', 'warm', 3.1, 'Informal', 3, 'smooth', 'boho', 'loose', 'freetime'], 'label': 1891})
# (1892, {'feature': [7, '00008b', 'warm', 2.0, 'Formal', 1, 'floral', 'classic', 'loose', 'work'], 'label': 1892})
# (1893, {'feature': [7, 'FFC0CB', 'warm', 2.0, 'Formal', 1, 'floral', 'classic', 'loose', 'work'], 'label': 1893})
# (1894, {'feature': [7, '00008b', 'warm', 2.0, 'Informal', 1, 'horizontal_stripes', 'casual', 'loose', 'freetime'], 'label': 1894})
# (1895, {'feature': [7, 'BBE2AD', 'warm', 2.0, 'Informal', 2, 'smooth', 'boho', 'straight', 'freetime'], 'label': 1895})
# (1896, {'feature': [7, '164A0A', 'warm', 3.1, 'Formal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 1896})
# (1897, {'feature': [7, '00008b', 'warm', 3.1, 'Formal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 1897})
# (1898, {'feature': [7, '000000', 'warm', 3.1, 'Formal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 1898})
# (1899, {'feature': [7, '666633', 'warm', 3.1, 'Formal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 1899})
# (1900, {'feature': [7, '800000', 'warm', 3.1, 'Formal', 2, 'smooth', 'street', 'straight', 'freetime'], 'label': 1900})
# (1901, {'feature': [7, 'C19A6B', 'warm', 3.2, 'Informal', 1, 'smooth', 'boho', nan, 'freetime'], 'label': 1901})
# (1902, {'feature': [7, '00008b', 'warm', 1.2, 'Informal', 2, 'polka_dot', 'boho', 'straight', 'freetime'], 'label': 1902})
# (1903, {'feature': [7, '000000', 'warm', 2.0, 'Formal', 1, 'smooth', 'classic', 'loose', 'freetime'], 'label': 1903})
# (1904, {'feature': [7, '000000', 'cold', 1.1, 'Formal', 1, 'smooth', 'street', 'tight', 'work'], 'label': 1904})
# (1905, {'feature': [7, '00008b', 'warm', 1.2, 'Formal', 2, 'sheets', 'classic', 'straight', 'freetime'], 'label': 1905})
# (1906, {'feature': [7, '00008b', 'warm', 1.1, 'Informal', 2, 'smooth', 'minimal', 'loose', 'freetime'], 'label': 1906})
# (1907, {'feature': [7, 'BBE2AD', 'warm', 1.1, 'Informal', 2, 'smooth', 'minimal', 'loose', 'freetime'], 'label': 1907})
# (1908, {'feature': [7, '00008b', 'warm', 1.1, 'Formal', 2, 'smooth', 'street', 'tight', 'freetime'], 'label': 1908})
# (1909, {'feature': [7, '40E0D0', 'warm', 2.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 1909})
# (1910, {'feature': [7, '5F5E5E', 'warm', 2.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 1910})
# (1911, {'feature': [7, 'FFC0CB', 'warm', 2.0, 'Informal', 2, 'smooth', 'casual', 'loose', 'freetime'], 'label': 1911})
# (1912, {'feature': [7, 'A57E62', 'warm', 3.1, 'Formal', 2, 'smooth', 'minimal', 'loose', 'work'], 'label': 1912})
# (1913, {'feature': [7, 'ECE9D6', 'warm', 3.1, 'Formal', 2, 'smooth', 'minimal', 'loose', 'work'], 'label': 1913})
# (1914, {'feature': [7, '000000', 'warm', 1.2, 'Informal', 2, 'floral', 'boho', 'straight', 'freetime'], 'label': 1914})
# (1915, {'feature': [7, 'FFFFFF', 'warm', 1.2, 'Informal', 2, 'floral', 'boho', 'straight', 'freetime'], 'label': 1915})
# (1916, {'feature': [7, 'DEB24C', 'warm', 2.0, 'Informal', 1, 'miniprint', 'classic', 'straight', 'freetime'], 'label': 1916})
# (1917, {'feature': [7, '00008b', 'warm', 3.1, 'Informal', 2, 'floral', 'boho', 'straight', 'freetime'], 'label': 1917})
# (1918, {'feature': [7, 'C7A2A2', 'warm', 3.1, 'Informal', 2, 'floral', 'boho', 'straight', 'freetime'], 'label': 1918})
# (1919, {'feature': [7, '666633', 'warm', 2.0, 'Informal', 3, 'smooth', 'street', 'straight', 'night'], 'label': 1919})
# (1920, {'feature': [7, 'FFC0CB', 'warm', 2.0, 'Informal', 3, 'smooth', 'street', 'straight', 'night'], 'label': 1920})
# (1921, {'feature': [7, 'ECE9D6', 'warm', 2.0, 'Informal', 1, 'smooth', 'casual', 'straight', 'freetime'], 'label': 1921})
# (1922, {'feature': [7, '00008b', 'warm', 1.1, 'Informal', 1, 'smooth', 'boho', 'tight', 'freetime'], 'label': 1922})

# %% [markdown]
# **ARISTAS**

# %% [markdown]
# Si una prenda es de nivel 1.2, no puede combinarse con una prenda de nivel 2.
# En los demás casos, las prendas no pueden combinarse si tienen niveles principales iguales, excepto si ambos son del nivel 3.
# Separación de la lógica para el caso especial de 1.2: Permitir que las prendas de nivel 3.x se combinen con otras de nivel 3.x siempre que tengan subniveles diferentes.

# %%
# muestra = 100 SI SE QUIERE HACER MUESTRA DESCOMENTAR ESTO
import itertools

# %%
#FUNCION PESOS

# Diccionarios de penalización
estilo_penalizaciones = {
    ("classic", "street"): 0.6, ("classic", "boho"): 0.5, ("classic", "minimal"): 1,
    ("classic", "casual"): 0.8, ("classic", "night"): 0.9, ("street", "boho"): 0.6,
    ("street", "minimal"): 0.8, ("street", "casual"): 0.9, ("street", "night"): 0.6,
    ("boho", "minimal"): 0.8, ("boho", "casual"): 0.9, ("boho", "night"): 0.6,
    ("minimal", "casual"): 1, ("minimal", "night"): 0.8, ("casual", "night"): 0.9,
    ("classic", "classic"): 1,  ("street", "street"): 1, ("boho", "boho"): 1,
    ("minimal", "minimal"): 1, ("casual", "casual"): 1, ("night", "night"): 1
}

fit_penalizaciones = {
    ("straight", "tight"): 1, ("straight", "loose"): 0.9, ("straight", "oversize"): 0.9,
    ("tight", "loose"): 0.8, ("tight", "oversize"): 0.9, ("loose", "oversize"): 0.7,
    ("loose", "loose"): 0.7, ("tight", "tight"): 1, ("straight", "straight"): 1,
    ("oversize", "oversize"): 0.7
}

uso_penalizaciones = {
    ("freetime", "work"): 0.9, ("freetime", "working_girl"): 0.9, ("freetime", "night"): 0.6,
    ("freetime", "special_occasion"): 0.5, ("work", "working_girl"): 1,
    ("work", "night"): 0.8, ("work", "special_occasion"): 0.9,
    ("working_girl", "night"): 0.8, ("working_girl", "special_occasion"): 0.9,
    ("night", "special_occasion"): 1, ("freetime", "freetime"): 1,
    ("work", "work"): 1, ("working_girl", "working_girl"): 1,
    ("night", "night"): 1, ("special_occasion", "special_occasion"):1
}

# Función para calcular el peso de las aristas
def calcular_peso(row1, row2):
    peso = 1  # Peso inicial

    # Extraer los atributos relevantes de las características (feature)
    estilo1 = row1.feature[7]
    estilo2 = row2.feature[7]
    fit1 = str(row1.feature[8])
    fit2 = str(row2.feature[8])
    uso1 = row1.feature[9]
    uso2 = row2.feature[9]
    tipo1 = row1.feature[4]
    tipo2 = row2.feature[4]
    estampado1 = row1.feature[6]
    estampado2 = row2.feature[6]
    color1 = row1.feature[1]
    color2 = row2.feature[1]


    # Penalizar combinaciones de estilo
    estilo_pair = tuple(sorted([estilo1, estilo2]))
    if estilo_pair in estilo_penalizaciones:
        peso *= estilo_penalizaciones[estilo_pair]

    # Penalizar combinaciones de fit
    fit_pair = tuple(sorted([fit1, fit2]))
    if fit_pair in fit_penalizaciones:
        peso *= fit_penalizaciones[fit_pair]

    # Penalizar combinaciones de uso
    uso_pair = tuple(sorted([uso1, uso2]))
    if uso_pair in uso_penalizaciones:
        peso *= uso_penalizaciones[uso_pair]

    # Penalizar combinaciones de temperatura diferente (columna 2)
    temperatura1 = row1.feature[2]
    temperatura2 = row2.feature[2]
    if temperatura1 != temperatura2:
        peso *= 0.7

    # Penalizar combinaciones de adventurous diferente (columna 5)
    adventurous1 = row1.feature[5]
    adventurous2 = row2.feature[5]
    adventurous_diff = abs(adventurous1 - adventurous2)
    if adventurous_diff > 1:
        peso *= 0.8  # Ajustar según lo necesario

    # Penalizar si uno es formal y el otro informal
    if tipo1 != tipo2:
        peso *= 0.7

    # Penalizar combinaciones de estampados según las nuevas reglas
    if estampado1 != 'none' and estampado2 != 'none':
        if estampado1 == 'horizontal_stripes' and estampado2 == 'vertical_stripes':
            peso *= 0.5  # Penalizar la combinación de rayas horizontales y verticales

        # Verificar si los estampados son diferentes y no son del mismo color
        estampados = [estampado1, estampado2]
        colores_estampado = [color1, color2]
        if len(set(estampados)) > 1 and len(set(colores_estampado)) > 1:
             peso *= 0.6  # Penalizar combinación de más de dos estampados diferentes con colores diferentes

    return peso

# %%
def generar_aristas_optimizado(grafo, color_comb_df):
    # Extraer nodos y características
    nodes_data = pd.DataFrame(
        [(node, data['feature']) for node, data in grafo.nodes(data=True)],
        columns=["node", "feature"]
    )

    # Convertir características a columnas separadas
    features_df = pd.DataFrame(nodes_data['feature'].tolist(), columns=[
        "temporada", "color", "temperatura", "nivel_prenda",
        "tipo", "adventurous", "textura", "estilo", "corte", "uso"
    ])
    nodes_data = pd.concat([nodes_data, features_df], axis=1)

    # Convertir adventurous a valores numéricos
    nodes_data['adventurous'] = pd.to_numeric(nodes_data['adventurous'], errors='coerce')
    node_combinations = itertools.combinations(nodes_data.itertuples(index=False), 2)


    # Crear una matriz de combinaciones de nodos
    idx_combinations = np.triu_indices(len(nodes_data), k=1)
    node1_indices = idx_combinations[0]
    node2_indices = idx_combinations[1]

    verificar_nivel = lambda row1, row2: not (
    # Combinaciones no válidas
    (row1.nivel_prenda == 1.1 and row2.nivel_prenda in [1.1, 1.2]) or
    (row2.nivel_prenda == 1.1 and row1.nivel_prenda in [1.1, 1.2]) or

    (row1.nivel_prenda == 1.2 and row2.nivel_prenda in [1.1, 1.2, 2.]) or
    (row2.nivel_prenda == 1.2 and row1.nivel_prenda in [1.1, 1.2, 2.]) or

    (row1.nivel_prenda == 2. and row2.nivel_prenda in [1.2, 2.]) or
    (row2.nivel_prenda == 2. and row1.nivel_prenda in [1.2, 2.]) or

    (row1.nivel_prenda in [3., 3.1, 3.2] and row2.nivel_prenda == row1.nivel_prenda)
    )

    # Diccionario de combinaciones de color válidas
    valid_color_combinations = dict(zip(
        zip(color_comb_df['color1'], color_comb_df['color2']),
        color_comb_df['combination']
    ))

    # Función para verificar otras reglas
    verificar_otros = lambda row1, row2: all([
        valid_color_combinations.get((row1.color, row2.color), 0) == 1,
        row1.temporada == row2.temporada,
        row1.color != row2.color,
        abs(row1.adventurous - row2.adventurous) <= 1
    ])


    # Filtrar combinaciones válidas
    def es_valida(pair):
        row1, row2 = pair
        return verificar_otros(row1, row2) and verificar_nivel(row1, row2)

    valid_edges = list(filter(es_valida, node_combinations))

    # Convertir a lista de tuplas (node1, node2)
    valid_edges = [(row1.node, row2.node) for row1, row2 in valid_edges]

    # Verificar nodos aislados
    connected_nodes = set([node for edge in valid_edges for node in edge])
    isolated_nodes = set(nodes_data['node']) - connected_nodes

    if isolated_nodes:
    # Calcular similitud entre nodos (en función de características como adventurous, temperatura, etc.)
      def calcular_similitud(node1, node2):
        row1 = nodes_data[nodes_data['node'] == node1].iloc[0]
        row2 = nodes_data[nodes_data['node'] == node2].iloc[0]

        # Convertir 'temperatura' a valores numéricos
        temperatura_map = {'cold': 0, 'warm': 1}
        temperatura_diff = temperatura_map.get(row1.temperatura, -1) - temperatura_map.get(row2.temperatura, -1)

        # Similitud como distancia euclidiana inversa (se puede ajustar según el criterio)
        feature_diff = np.array([
            row1.adventurous - row2.adventurous,
            temperatura_diff,
            row1.color == row2.color,  # Coincidencia de color
            row1.tipo == row2.tipo  # Coincidencia de tipo de prenda
        ])
        return 1 / (1 + np.linalg.norm(feature_diff))

    # Asignar aristas del nodo más parecido con aristas
      for isolated_node in isolated_nodes:
        # Encontrar el nodo más cercano
        similarities = {
            node: calcular_similitud(isolated_node, node)
            for node in connected_nodes
        }
        most_similar_node = max(similarities, key=similarities.get)

        # Obtener las aristas del nodo más similar
        similar_edges = [edge for edge in valid_edges if most_similar_node in edge]

        # Asignar las mismas aristas al nodo aislado
        for edge in similar_edges:
            if edge[0] == most_similar_node:
                valid_edges.append((isolated_node, edge[1]))
            elif edge[1] == most_similar_node:
                valid_edges.append((edge[0], isolated_node))

      # Llamar a la función de pesos para cada arista
    aristas_con_pesos = []
    for edge in valid_edges:
        node1, node2 = edge
        row1 = nodes_data[nodes_data['node'] == node1].iloc[0]
        row2 = nodes_data[nodes_data['node'] == node2].iloc[0]
        peso = calcular_peso(row1, row2)  # Calcular el peso para la arista
        aristas_con_pesos.append((node1, node2, peso))

    # Imprimir el número de aristas generadas
    print(f"\nNúmero total de aristas generadas: {len(valid_edges)} combinaciones válidas.")

    return aristas_con_pesos, nodes_data['node'].tolist()

    # print(f"\nNúmero total de aristas generadas: {len(valid_edges)} combinaciones válidas.")
    # return valid_edges, nodes_data['node'].tolist()

# %%
aristas = generar_aristas_optimizado(G7, color_combinations)
# Out:
# Número total de aristas generadas: 207056 combinaciones válidas.

# %%
print(f"Total de aristas generadas: {len(aristas[0])}")
# Out:
# Total de aristas generadas: 207056

# %%
# # Añadir las aristas generadas con su peso al grafo
for arista in aristas[0]:
    nodo1, nodo2 = arista[:2]  # Nodos de la arista
    peso = arista[2]  # Peso de la arista (ya calculado previamente)
    G7.add_edge(nodo1, nodo2, weight=peso)  # Añadir la arista con su peso

# Confirmar el número de aristas en el grafo actualizado
print(f"El grafo ahora tiene {G7.number_of_edges()} aristas.")
# Out:
# El grafo ahora tiene 207056 aristas.

# %%
import numpy as np

def umbralizacion(graph):
    """
    Normaliza los pesos de las aristas para calcular un umbral basado en el percentil 25
    de los pesos normalizados, y elimina las aristas originales cuyos pesos normalizados
    no superen este umbral. Además, asegura que no queden nodos aislados manteniendo
    al menos 10 conexiones de mayor peso por nodo.

    Parameters:
        graph (nx.Graph): Grafo ponderado (modificado en su lugar).

    Returns:
        None: Modifica el grafo original en su lugar.
    """
    pesos_normalizados = []

    for node in graph.nodes():
        # Obtener las aristas y sus pesos asociados al nodo
        edges = [(min(node, nodo2), max(node, nodo2), data['weight']) for nodo2, data in graph[node].items()]
        # Calcular el peso máximo de las aristas del nodo
        peso_maximo = max(weight for _, _, weight in edges)

        # Normalizar los pesos y acumularlos
        for _, _, peso in edges:
            peso_normalizado = peso / peso_maximo
            pesos_normalizados.append(peso_normalizado)

    # Calcular el percentil 25 de los pesos normalizados
    threshold = np.percentile(pesos_normalizados, 25)
    # Identificar las aristas que no cumplen con el umbral
    conexiones_a_eliminar = set()
    for node in graph.nodes():
        edges = [(min(node, nodo2), max(node, nodo2), data['weight']) for nodo2, data in graph[node].items()]
        peso_maximo = max(weight for _, _, weight in edges)
        conexiones_a_mantener = []

        for nodo1, nodo2, peso in edges:
            peso_normalizado = peso / peso_maximo
            if peso_normalizado < threshold:
                conexiones_a_eliminar.add((nodo1, nodo2))
            else:
                conexiones_a_mantener.append((nodo1, nodo2))

        # Si menos de 10 conexiones cumplen el umbral, mantener las 10 de mayor peso
        if len(conexiones_a_mantener) < 10:
            sorted_edges = sorted(edges, key=lambda x: x[2], reverse=True)  # Ordenar por peso descendente
            top_edges = sorted_edges[:10]  # Seleccionar las 10 de mayor peso
            for edge in top_edges:
                if (edge[0], edge[1]) in conexiones_a_eliminar:
                    conexiones_a_eliminar.discard((edge[0], edge[1]))  # Asegurar que no se eliminen

    # Eliminar las aristas originales que no cumplen con el umbral
    graph.remove_edges_from(conexiones_a_eliminar)

# %%
umbralizacion(G7)

# %%
print(f"El grafo ahora tiene {G7.number_of_edges()} aristas.")
# Out:
# El grafo ahora tiene 150028 aristas.

# %%
# Obtener las componentes conexas del grafo
componentes_conexas = list(nx.connected_components(G7))

# Filtrar la componente de tamaño 2 (la más pequeña)
componente_a_eliminar = [componente for componente in componentes_conexas if len(componente) == 2]

# Eliminar la componente de tamaño 2
nodos_a_eliminar = componente_a_eliminar[0] if componente_a_eliminar else []
G7.remove_nodes_from(nodos_a_eliminar)

# Verificar los resultados
print(f"Número de nodos después de eliminar la componente de tamaño 2: {len(G7.nodes())}")
print(f"Número de aristas después de eliminar la componente de tamaño 2: {len(G7.edges())}")
print(f"Nodos eliminados: {nodos_a_eliminar}")
# Out:
# Número de nodos después de eliminar la componente de tamaño 2: 1923
# Número de aristas después de eliminar la componente de tamaño 2: 150028
# Nodos eliminados: []

# %% [markdown]
# VISUALIZACIÓN: No es necesario cargar (tarda mucho)

# %%
# import plotly.graph_objects as go
# import networkx as nx
# import numpy as np
# import random

# # Obtener las posiciones de los nodos en 3D (puedes ajustar si ya tienes las posiciones de nodos)
# pos = nx.spring_layout(G7, dim=3, seed=42)  # Ajusta esto si ya tienes las posiciones

# # Extraer las posiciones de los nodos para el gráfico
# x_vals = [pos[node][0] for node in G7.nodes()]
# y_vals = [pos[node][1] for node in G7.nodes()]
# z_vals = [pos[node][2] for node in G7.nodes()]

# # Extraer las conexiones (aristas) en la muestra
# edges = G7.edges()

# # Crear las coordenadas de las aristas
# edge_x = []
# edge_y = []
# edge_z = []
# for edge in edges:
#     node1, node2 = edge
#     edge_x += [pos[node1][0], pos[node2][0], None]
#     edge_y += [pos[node1][1], pos[node2][1], None]
#     edge_z += [pos[node1][2], pos[node2][2], None]

# # Crear el gráfico 3D con Plotly
# fig = go.Figure()

# # Dibujar las aristas (líneas) entre los nodos (sin color y más finas)
# fig.add_trace(go.Scatter3d(
#     x=edge_x, y=edge_y, z=edge_z,
#     mode='lines',
#     line=dict(width=0.5, color='gray'),  # Aristas más finas y sin color
# ))

# # Dibujar los nodos
# fig.add_trace(go.Scatter3d(
#     x=x_vals, y=y_vals, z=z_vals,
#     mode='markers+text',
#     marker=dict(size=6, color='red'),  # Nodos de color rojo
#     text=[str(node) for node in G7.nodes()],
#     textposition="top center",
#     showlegend=False
# ))

# # Añadir título y etiquetas a los ejes
# fig.update_layout(
#     title='Gráfico 3D interactivode G7',
#     scene=dict(
#         xaxis_title='X',
#         yaxis_title='Y',
#         zaxis_title='Z'
#     ),
#     showlegend=False,
#     plot_bgcolor='white',  # Fondo blanco
#     paper_bgcolor='white',  # Fondo blanco fuera de la gráfica
# )

# # Mostrar el gráfico
# fig.show()

# %%
# Filtrar solo las aristas con pesos numéricos y que sean tuplas
aristas_validas = []
for arista in aristas[0]:
    # Verificar si la arista es una tupla y tiene 3 elementos (nodo1, nodo2, peso)
    if isinstance(arista, tuple) and len(arista) == 3:
        nodo1, nodo2, peso = arista
        # Verificar si el peso es un valor numérico (int o float)
        if isinstance(peso, (int, float)):
            aristas_validas.append(arista)

# Ordenar todas las aristas por peso de forma descendente (mayor peso primero)
aristas_mayor_peso = sorted(aristas_validas, key=lambda x: x[2], reverse=True)[:10]

# Ordenar todas las aristas por peso de forma ascendente (menor peso primero)
aristas_menor_peso = sorted(aristas_validas, key=lambda x: x[2])[:10]

# Imprimir las 10 aristas con mayor peso
print("Las 10 conexiones con mayor peso:")
for arista in aristas_mayor_peso:
    print(f"{arista[0]} - {arista[1]} con peso: {arista[2]}")

# Imprimir las 10 aristas con menor peso
print("\nLas 10 conexiones con menor peso:")
for arista in aristas_menor_peso:
    print(f"{arista[0]} - {arista[1]} con peso: {arista[2]}")
# Out:
# Las 10 conexiones con mayor peso:
# 0 - 1900 con peso: 1
# 1 - 83 con peso: 1
# 2 - 593 con peso: 1
# 2 - 759 con peso: 1
# 2 - 1333 con peso: 1
# 2 - 1653 con peso: 1
# 2 - 1659 con peso: 1
# 2 - 1704 con peso: 1
# 2 - 1709 con peso: 1
# 2 - 1890 con peso: 1
#
# Las 10 conexiones con menor peso:
# 59 - 1453 con peso: 0.05292
# 60 - 1453 con peso: 0.05292
# 1070 - 1453 con peso: 0.05292
# 10 - 1155 con peso: 0.06173999999999999
# 99 - 1178 con peso: 0.06173999999999999
# 81 - 497 con peso: 0.07408799999999999
# 81 - 1069 con peso: 0.07408799999999999
# 81 - 1178 con peso: 0.07408799999999999
# 86 - 992 con peso: 0.07408799999999999
# 98 - 1256 con peso: 0.07408799999999999

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Obtener los pesos de las aristas
pesos = [data.get('weight', 1) for u, v, data in G7.edges(data=True)]

# Configurar el estilo de Seaborn para un fondo limpio sin líneas
sns.set(style="white", palette="muted")

n_bins = 10

# Crear figura y ejes
plt.figure(figsize=(12, 6))

# Graficar el histograma con KDE superpuesto para una mejor visualización
sns.histplot(pesos, bins=n_bins, kde=True, color='indianred', edgecolor='black', stat="density", linewidth=1.5)

# Títulos y etiquetas con tamaños personalizados
plt.title('Distribución de Pesos de las Aristas', fontsize=18, fontweight='bold')
plt.xlabel('Peso de la Arista', fontsize=15)
plt.ylabel('Densidad', fontsize=15)

# Agregar una línea de referencia para la media con un estilo más notorio
mean_weight = np.mean(pesos)
plt.axvline(mean_weight, color='darkred', linestyle='--', linewidth=2, label=f'Media: {mean_weight:.2f}')

# Mejorar la visibilidad de la leyenda
plt.legend(loc='upper right', fontsize=12)

# Mejorar la visualización y ajustarla a la figura
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
# Contar cuántas conexiones tienen peso 1 en todas las aristas
conexiones_peso_1_total = sum(1 for arista in aristas_validas if arista[2] == 1)

# Imprimir el resultado
print(f"Cantidad total de conexiones con peso 1 en todas las aristas: {conexiones_peso_1_total}")
# Out:
# Cantidad total de conexiones con peso 1 en todas las aristas: 10817

# %%
# Crear un diccionario que mapea el id_nodo a los nombres de las prendas, colores y niveles
id_a_prenda_color_nivel = dict(zip(df_limpio_s7['id_nodo'], zip(df_limpio_s7['title'], df_limpio_s7['hexadecimal'], df_limpio_s7['nivel'])))

# Ahora, mapeamos las aristas de mayor y menor peso con nombres, colores y niveles de las prendas

# Obtener los nombres, colores y niveles de las prendas asociadas a cada arista de mayor peso
aristas_mayor_peso_con_nombres_colores_niveles = [
    (id_a_prenda_color_nivel.get(arista[0], (arista[0], 'Desconocido', 'Desconocido'))[0],
     id_a_prenda_color_nivel.get(arista[1], (arista[1], 'Desconocido', 'Desconocido'))[0],
     id_a_prenda_color_nivel.get(arista[0], (arista[0], 'Desconocido', 'Desconocido'))[1],
     id_a_prenda_color_nivel.get(arista[1], (arista[1], 'Desconocido', 'Desconocido'))[1],
     id_a_prenda_color_nivel.get(arista[0], (arista[0], 'Desconocido', 'Desconocido'))[2],
     id_a_prenda_color_nivel.get(arista[1], (arista[1], 'Desconocido', 'Desconocido'))[2],
     arista[2])
    for arista in aristas_mayor_peso
]

# Obtener los nombres, colores y niveles de las prendas asociadas a cada arista de menor peso
aristas_menor_peso_con_nombres_colores_niveles = [
    (id_a_prenda_color_nivel.get(arista[0], (arista[0], 'Desconocido', 'Desconocido'))[0],
     id_a_prenda_color_nivel.get(arista[1], (arista[1], 'Desconocido', 'Desconocido'))[0],
     id_a_prenda_color_nivel.get(arista[0], (arista[0], 'Desconocido', 'Desconocido'))[1],
     id_a_prenda_color_nivel.get(arista[1], (arista[1], 'Desconocido', 'Desconocido'))[1],
     id_a_prenda_color_nivel.get(arista[0], (arista[0], 'Desconocido', 'Desconocido'))[2],
     id_a_prenda_color_nivel.get(arista[1], (arista[1], 'Desconocido', 'Desconocido'))[2],
     arista[2])
    for arista in aristas_menor_peso
]

# Imprimir las aristas con nombres, colores y niveles de prendas
print("Las 10 conexiones con mayor peso y sus nombres de prendas, colores y niveles:")
for arista in aristas_mayor_peso_con_nombres_colores_niveles:
    print(f"{arista[0]} ({arista[2]}, {arista[4]}) - {arista[1]} ({arista[3]}, {arista[5]}) con peso: {arista[6]}")

print("\nLas 10 conexiones con menor peso y sus nombres de prendas, colores y niveles:")
for arista in aristas_menor_peso_con_nombres_colores_niveles:
    print(f"{arista[0]} ({arista[2]}, {arista[4]}) - {arista[1]} ({arista[3]}, {arista[5]}) con peso: {arista[6]}")
# Out:
# Las 10 conexiones con mayor peso y sus nombres de prendas, colores y niveles:
# Poly Pant deeluxe (B11730, 1.1) - Cerise Jumpsuit solid  (800000, 3.1) con peso: 1
# Long Tshirt stripe (ECE9D6, 3.0) - Limbo Scarf stola (000081, 3.2) con peso: 1
# Turna Top flounce  (5F5E5E, 2.0) - Parastoo Pant comfort (DEB24C, 1.1) con peso: 1
# Turna Top flounce  (5F5E5E, 2.0) - Kara Foulard closet (DEB24C, 3.2) con peso: 1
# Turna Top flounce  (5F5E5E, 2.0) - Cooler Pant ycoo  (DEB24C, 1.1) con peso: 1
# Turna Top flounce  (5F5E5E, 2.0) - Tess Bag cahier  (DEB24C, 3.2) con peso: 1
# Turna Top flounce  (5F5E5E, 2.0) - Syna Bag cahier  (DEB24C, 3.2) con peso: 1
# Turna Top flounce  (5F5E5E, 2.0) - Radia Pant five  (DEB24C, 1.1) con peso: 1
# Turna Top flounce  (5F5E5E, 2.0) - Sarah Pant short  (DEB24C, 1.1) con peso: 1
# Turna Top flounce  (5F5E5E, 2.0) - Nadia Sweater neck  (DEB24C, 3.0) con peso: 1
#
# Las 10 conexiones con menor peso y sus nombres de prendas, colores y niveles:
# Masha Tshirt tee (ECE9D6, 2.0) - Gilet Cardigan lurex (BBA9E4, 3.0) con peso: 0.05292
# Masha Tshirt mid (ECE9D6, 2.0) - Gilet Cardigan lurex (BBA9E4, 3.0) con peso: 0.05292
# Bowie Tshirt cat (FFFFFF, 2.0) - Gilet Cardigan lurex (BBA9E4, 3.0) con peso: 0.05292
# Lua Cardigan colors  (D3D3D3, 3.0) - Pcnellie Pant noos (DEB24C, 1.1) con peso: 0.06173999999999999
# Ihcayce Tshirt stripes  (000000, 2.0) - Onlnew Sweater knit  (ECE9D6, 3.0) con peso: 0.06173999999999999
# Closet Jacket illinois (000000, 3.1) - Senes Shirt sas (0000FF, 3.0) con peso: 0.07408799999999999
# Closet Jacket illinois (000000, 3.1) - Pcbippa Sweater wool  (FFC0CB, 3.0) con peso: 0.07408799999999999
# Closet Jacket illinois (000000, 3.1) - Onlnew Sweater knit  (ECE9D6, 3.0) con peso: 0.07408799999999999
# Dusta Skirt doll  (000000, 1.1) - Bspenelopes Sweater peac (00008b, 3.0) con peso: 0.07408799999999999
# Ihcayce Tshirt stripes  (FFFF00, 2.0) - Majo Top nice (D84936, 3.0) con peso: 0.07408799999999999

# %% [markdown]
# **Análisis del grafo**

# %%
# Obtener nodos aislados
nodos_aislados = list(nx.isolates(G7))

# Imprimir nodos aislados con sus características
if nodos_aislados:
    print("Nodos aislados y sus características:")
    for nodo in nodos_aislados:
        print(f"Nodo: {nodo}")
        print(f"Características: {G7.nodes[nodo]}")
        print("-" * 40)  # Separador para mayor claridad
else:
    print("No hay nodos aislados en el grafo.")
# Out:
# No hay nodos aislados en el grafo.

# %%
import networkx as nx

def analizar_grafo(G):
    analysis = {}

    # Número de nodos y aristas
    analysis['nodos'] = G.number_of_nodes()
    analysis['aristas'] = G.number_of_edges()

    # Densidad del grafo
    analysis['densidad'] = nx.density(G)

    # Componentes conectadas
    componentes = list(nx.connected_components(G))
    analysis['componentes_conectadas'] = len(componentes)
    analysis['tamaño_componentes'] = [len(c) for c in componentes]

    # Tamaño de la componente gigante
    analysis['tamaño_componente_gigante'] = max(analysis['tamaño_componentes']) if componentes else 0

    # Diámetro (solo si el grafo es conexo)
    if nx.is_connected(G):
        analysis['diametro'] = nx.diameter(G)
    else:
        analysis['diametro'] = "No aplica (grafo no conexo)"

    # Coeficiente de agrupamiento promedio
    analysis['coeficiente_agrupamiento'] = nx.average_clustering(G)

    # Grado promedio
    grados = dict(G.degree())
    analysis['grado_promedio'] = sum(grados.values()) / analysis['nodos'] if analysis['nodos'] > 0 else 0

    # Centralidad de grado
    centralidad_grado = nx.degree_centrality(G)
    nodo_max_centralidad_grado = max(centralidad_grado, key=centralidad_grado.get)
    nodo_min_centralidad_grado = min(centralidad_grado, key=centralidad_grado.get)
    analysis['centralidad_grado_max'] = (nodo_max_centralidad_grado, centralidad_grado[nodo_max_centralidad_grado])
    analysis['centralidad_grado_min'] = (nodo_min_centralidad_grado, centralidad_grado[nodo_min_centralidad_grado])
    analysis['centralidad_grado_prom'] = sum(centralidad_grado.values()) / len(centralidad_grado) if len(centralidad_grado) > 0 else 0

    print("\nNodos con mayor centralidad de grado:")
    print(f"Nodo {nodo_max_centralidad_grado} con centralidad {centralidad_grado[nodo_max_centralidad_grado]}")

    print("\nNodos con menor centralidad de grado:")
    print(f"Nodo {nodo_min_centralidad_grado} con centralidad {centralidad_grado[nodo_min_centralidad_grado]}")

    # Centralidad de intermediación
    centralidad_intermediacion = nx.betweenness_centrality(G)
    nodo_max_centralidad_intermediacion = max(centralidad_intermediacion, key=centralidad_intermediacion.get)
    nodo_min_centralidad_intermediacion = min(centralidad_intermediacion, key=centralidad_intermediacion.get)
    analysis['centralidad_intermediacion_max'] = (nodo_max_centralidad_intermediacion, centralidad_intermediacion[nodo_max_centralidad_intermediacion])
    analysis['centralidad_intermediacion_min'] = (nodo_min_centralidad_intermediacion, centralidad_intermediacion[nodo_min_centralidad_intermediacion])
    analysis['centralidad_intermediacion_prom'] = sum(centralidad_intermediacion.values()) / len(centralidad_intermediacion) if len(centralidad_intermediacion) > 0 else 0

    print("\nNodos con mayor centralidad de intermediación:")
    print(f"Nodo {nodo_max_centralidad_intermediacion} con centralidad {centralidad_intermediacion[nodo_max_centralidad_intermediacion]}")

    print("\nNodos con menor centralidad de intermediación:")
    print(f"Nodo {nodo_min_centralidad_intermediacion} con centralidad {centralidad_intermediacion[nodo_min_centralidad_intermediacion]}")

    # Centralidad de cercanía
    centralidad_cercania = nx.closeness_centrality(G)
    nodo_max_centralidad_cercania = max(centralidad_cercania, key=centralidad_cercania.get)
    nodo_min_centralidad_cercania = min(centralidad_cercania, key=centralidad_cercania.get)
    analysis['centralidad_cercania_max'] = (nodo_max_centralidad_cercania, centralidad_cercania[nodo_max_centralidad_cercania])
    analysis['centralidad_cercania_min'] = (nodo_min_centralidad_cercania, centralidad_cercania[nodo_min_centralidad_cercania])
    analysis['centralidad_cercania_prom'] = sum(centralidad_cercania.values()) / len(centralidad_cercania) if len(centralidad_cercania) > 0 else 0

    print("\nNodos con mayor centralidad de cercanía:")
    print(f"Nodo {nodo_max_centralidad_cercania} con centralidad {centralidad_cercania[nodo_max_centralidad_cercania]}")

    print("\nNodos con menor centralidad de cercanía:")
    print(f"Nodo {nodo_max_centralidad_cercania} con cercanía {centralidad_cercania[nodo_min_centralidad_cercania]}")

    # PageRank
    pagerank = nx.pagerank(G)
    nodo_max_pagerank = max(pagerank, key=pagerank.get)
    nodo_min_pagerank = min(pagerank, key=pagerank.get)
    analysis['pagerank_max'] = (nodo_max_pagerank, pagerank[nodo_max_pagerank])
    analysis['pagerank_min'] = (nodo_min_pagerank, pagerank[nodo_min_pagerank])
    analysis['pagerank_prom'] = sum(pagerank.values()) / len(pagerank) if len(pagerank) > 0 else 0

    print("\nNodos con mayor PageRank:")
    print(f"Nodo {nodo_max_pagerank} con PageRank {pagerank[nodo_max_pagerank]}")

    print("\nNodos con menor PageRank:")
    print(f"Nodo {nodo_min_pagerank} con PageRank {pagerank[nodo_min_pagerank]}")

    # Excentricidad
    excentricidad = nx.eccentricity(G)
    nodo_max_excentricidad = max(excentricidad, key=excentricidad.get)
    nodo_min_excentricidad = min(excentricidad, key=excentricidad.get)
    analysis['excentricidad_max'] = (nodo_max_excentricidad, excentricidad[nodo_max_excentricidad])
    analysis['excentricidad_min'] = (nodo_min_excentricidad, excentricidad[nodo_min_excentricidad])
    analysis['excentricidad_prom'] = sum(excentricidad.values()) / len(excentricidad) if len(excentricidad) > 0 else 0

    # Triángulos
    triangulos = nx.triangles(G)
    top_5_triangulos = sorted(triangulos.items(), key=lambda x: x[1], reverse=True)[:5]
    bottom_5_triangulos = sorted(triangulos.items(), key=lambda x: x[1])[:5]

    print("\nTop 5 nodos con más triángulos:")
    for nodo, cantidad in top_5_triangulos:
        print(f"Nodo {nodo}: {cantidad} triángulos")

    print("\nTop 5 nodos con menos triángulos:")
    for nodo, cantidad in bottom_5_triangulos:
        print(f"Nodo {nodo}: {cantidad} triángulos")

    # Imprimir resultados
    print(f"Densidad: {analysis['densidad']}")
    print(f"Centralidad de grado - Max: Nodo {analysis['centralidad_grado_max'][0]} ({analysis['centralidad_grado_max'][1]}), Min: Nodo {analysis['centralidad_grado_min'][0]} ({analysis['centralidad_grado_min'][1]}), Prom: {analysis['centralidad_grado_prom']}")
    print(f"Centralidad de intermediación - Max: Nodo {analysis['centralidad_intermediacion_max'][0]} ({analysis['centralidad_intermediacion_max'][1]}), Min: Nodo {analysis['centralidad_intermediacion_min'][0]} ({analysis['centralidad_intermediacion_min'][1]}), Prom: {analysis['centralidad_intermediacion_prom']}")
    print(f"Centralidad de cercanía - Max: Nodo {analysis['centralidad_cercania_max'][0]} ({analysis['centralidad_cercania_max'][1]}), Min: Nodo {analysis['centralidad_cercania_min'][0]} ({analysis['centralidad_cercania_min'][1]}), Prom: {analysis['centralidad_cercania_prom']}")
    print(f"PageRank - Max: Nodo {analysis['pagerank_max'][0]} ({analysis['pagerank_max'][1]}), Min: Nodo {analysis['pagerank_min'][0]} ({analysis['pagerank_min'][1]}), Prom: {analysis['pagerank_prom']}")
    print(f"Excentricidad - Max: Nodo {analysis['excentricidad_max'][0]} ({analysis['excentricidad_max'][1]}), Min: Nodo {analysis['excentricidad_min'][0]} ({analysis['excentricidad_min'][1]}), Prom: {analysis['excentricidad_prom']}")
    print(f"Número de nodos: {analysis['nodos']}")
    print(f"Número de aristas: {analysis['aristas']}")
    print(f"Componentes conectadas: {analysis['componentes_conectadas']}")
    print(f"Tamaño de componentes: {analysis['tamaño_componentes']}")
    print(f"Tamaño de la componente gigante: {analysis['tamaño_componente_gigante']}")
    print(f"Diámetro: {analysis['diametro']}")
    print(f"Coeficiente de agrupamiento: {analysis['coeficiente_agrupamiento']}")
    print(f"Grado promedio: {analysis['grado_promedio']}")

    return analysis

# %%
import networkx as nx

def contar_nodos_sin_triangulos(G):
    """
    Cuenta el número de nodos en el grafo G que forman 0 triángulos.

    Args:
        G (networkx.Graph): El grafo a analizar.

    Returns:
        int: Número de nodos con 0 triángulos.
    """
    # Calcula los triángulos por nodo
    triangulos = nx.triangles(G)

    # Cuenta los nodos con 0 triángulos
    nodos_sin_triangulos = sum(1 for nodo, cantidad in triangulos.items() if cantidad == 0)

    return nodos_sin_triangulos

# Ejemplo de uso
nodos_sin_triangulos = contar_nodos_sin_triangulos(G7)
print(f"Número de nodos sin triángulos: {nodos_sin_triangulos}")
# Out:
# Número de nodos sin triángulos: 56

# %%
analisis = analizar_grafo(G7)
analisis
# Out:
# Nodos con mayor centralidad de grado:
# Nodo 73 con centralidad 0.3896982310093653
#
# Nodos con menor centralidad de grado:
# Nodo 9 con centralidad 0.0005202913631633715
#
# Nodos con mayor centralidad de intermediación:
# Nodo 17 con centralidad 0.013738082984983394
#
# Nodos con menor centralidad de intermediación:
# Nodo 9 con centralidad 0.0
#
# Nodos con mayor centralidad de cercanía:
# Nodo 73 con centralidad 0.6105463786531131
#
# Nodos con menor centralidad de cercanía:
# Nodo 73 con cercanía 0.23840238154304144
#
# Nodos con mayor PageRank:
# Nodo 73 con PageRank 0.002686595816516337
#
# Nodos con menor PageRank:
# Nodo 9 con PageRank 7.998173703011991e-05
#
# Top 5 nodos con más triángulos:
# Nodo 1651: 21507 triángulos
# Nodo 1901: 19922 triángulos
# Nodo 1661: 18041 triángulos
# Nodo 73: 16445 triángulos
# Nodo 1654: 16404 triángulos
#
# Top 5 nodos con menos triángulos:
# Nodo 2: 0 triángulos
# Nodo 6: 0 triángulos
# Nodo 8: 0 triángulos
# Nodo 9: 0 triángulos
# Nodo 11: 0 triángulos
# Densidad: 0.08118385089201695
# Centralidad de grado - Max: Nodo 73 (0.3896982310093653), Min: Nodo 9 (0.0005202913631633715), Prom: 0.08118385089201703
# Centralidad de intermediación - Max: Nodo 17 (0.013738082984983394), Min: Nodo 9 (0.0), Prom: 0.0005588296644584022
# Centralidad de cercanía - Max: Nodo 73 (0.6105463786531131), Min: Nodo 1381 (0.23840238154304144), Prom: 0.4862724889438275
# PageRank - Max: Nodo 73 (0.002686595816516337), Min: Nodo 9 (7.998173703011991e-05), Prom: 0.0005200208008320337
# Excentricidad - Max: Nodo 0 (5), Min: Nodo 109 (3), Prom: 4.246489859594384
# Número de nodos: 1923
# Número de aristas: 150028
# Componentes conectadas: 1
# Tamaño de componentes: [1923]
# Tamaño de la componente gigante: 1923
# Diámetro: 5
# Coeficiente de agrupamiento: 0.10195715620653223
# Grado promedio: 156.0353614144566
# {'nodos': 1923,
#  'aristas': 150028,
#  'densidad': 0.08118385089201695,
#  'componentes_conectadas': 1,
#  'tamaño_componentes': [1923],
#  'tamaño_componente_gigante': 1923,
#  'diametro': 5,
#  'coeficiente_agrupamiento': 0.10195715620653223,
#  'grado_promedio': 156.0353614144566,
#  'centralidad_grado_max': (73, 0.3896982310093653),
#  'centralidad_grado_min': (9, 0.0005202913631633715),
#  'centralidad_grado_prom': 0.08118385089201703,
#  'centralidad_intermediacion_max': (17, 0.013738082984983394),
#  'centralidad_intermediacion_min': (9, 0.0),
#  'centralidad_intermediacion_prom': 0.0005588296644584022,
#  'centralidad_cercania_max': (73, 0.6105463786531131),
#  'centralidad_cercania_min': (1381, 0.23840238154304144),
#  'centralidad_cercania_prom': 0.4862724889438275,
#  'pagerank_max': (73, 0.002686595816516337),
#  'pagerank_min': (9, 7.998173703011991e-05),
#  'pagerank_prom': 0.0005200208008320337,
#  'excentricidad_max': (0, 5),
#  'excentricidad_min': (109, 3),
#  'excentricidad_prom': 4.246489859594384}

# %%
def obtener_info_nodo(df, id_nodo):
    # Buscar la fila donde el 'id_nodo' coincide
    fila = df[df['id_nodo'] == id_nodo]

    # Si el nodo no se encuentra en el DataFrame, devolver un mensaje
    if fila.empty:
        return f"No se encontró información para el nodo ID {id_nodo}."

    # Devolver la fila completa con la información del nodo
    return fila

# Ejemplo de uso:
id_nodo_input = int(input("Introduce el ID del nodo: "))
info_nodo = obtener_info_nodo(df_limpio, id_nodo_input)

# Mostrar la información del nodo
print(info_nodo)
# Out:
# Introduce el ID del nodo: 73
#                               id_variant  \
# 73  0017140e-63fe-46e0-9680-b7ce6b0defd8
#
#                                       id              title  season  \
# 73  649769c3-e30c-4018-8474-31f750affd84  Akoz Shirt venus        7
#
#    hexadecimal                             family_id weather  nivel  \
# 73      BBE2AD  c59807ac-0362-4078-94b0-37ea3df6cdd0    warm    2.0
#
#    formalidad  adventurous   print    style       fit   application  id_nodo
# 73   Informal            1  smooth  minimal  straight  working_girl       73

# %%
import matplotlib.pyplot as plt

grados = dict(G7.degree())
plt.hist(list(grados.values()), bins=20, edgecolor='black', color='indianred')
plt.title('Distribución de Grados')
plt.xlabel('Grado')
plt.ylabel('Frecuencia')
plt.show()

# %%
num_triangulos = sum(nx.triangles(G7).values()) // 3  # Dividir por 3 porque cada triángulo se cuenta 3 veces
print(f"Número de triángulos: {num_triangulos}")
# Out:
# Número de triángulos: 1172645

# %%
# Función para analizar componentes conectadas
def analizar_componentes_aisladas(G):
    # Obtener las componentes conectadas
    componentes = list(nx.connected_components(G))

    # Filtrar componentes de tamaño 1 (nodos aislados)
    nodos_aislados = [c for c in componentes if len(c) == 1]
    componentes_no_aisladas = [c for c in componentes if len(c) > 1]

    print(f"Total de componentes: {len(componentes)}")
    print(f"Componentes aisladas (tamaño 1): {len(nodos_aislados)}")
    print(f"Componentes no aisladas: {len(componentes_no_aisladas)}")
    print(f"Tamaños de las componentes no aisladas: {[len(c) for c in componentes_no_aisladas]}")

    return nodos_aislados, componentes_no_aisladas

# Aplicar el análisis
if __name__ == "__main__":
    nodos_aislados, componentes_no_aisladas = analizar_componentes_aisladas(G7)
# Out:
# Total de componentes: 1
# Componentes aisladas (tamaño 1): 0
# Componentes no aisladas: 1
# Tamaños de las componentes no aisladas: [1923]

# %% [markdown]
# **TRIÁNGULOS**

# %%
import numpy as np
from itertools import combinations

def media_geometrica(lista):
    """Calcula la media geométrica de una lista de números."""
    return np.exp(np.mean(np.log(lista)))

def obtener_triangulos_y_media_geometrica(G):
    triangulos = []  # Lista para almacenar los triángulos con sus medias geométricas

    # Iteramos sobre todos los nodos
    for nodo in G.nodes():
        # Obtenemos los vecinos del nodo
        vecinos = list(G.neighbors(nodo))

        # Generamos combinaciones de pares de vecinos
        for vecino1, vecino2 in combinations(vecinos, 2):
            # Comprobamos si existe una arista entre los dos vecinos, formando un triángulo
            if G.has_edge(vecino1, vecino2):
                # Si existe un triángulo, guardamos los tres nodos y la media geométrica de las ponderaciones
                ponderaciones = [G[nodo][vecino1].get('weight', 1),
                                 G[nodo][vecino2].get('weight', 1),
                                 G[vecino1][vecino2].get('weight', 1)]
                media = media_geometrica(ponderaciones)
                triangulos.append(((nodo, vecino1, vecino2), media))

    return triangulos

# %%
triangulos = obtener_triangulos_y_media_geometrica(G7)

# %%
def es_valido_triangulo(nodo1, nodo2, nodo3, G):
    """Verifica si el triángulo cumple con las condiciones del 'look' basadas en los niveles de las prendas."""

    # Extraemos los niveles de las prendas del cuarto atributo de cada nodo
    nivel1 = G.nodes[nodo1].get('feature', [])[3]  # El cuarto atributo es el nivel
    nivel2 = G.nodes[nodo2].get('feature', [])[3]  # El cuarto atributo es el nivel
    nivel3 = G.nodes[nodo3].get('feature', [])[3]  # El cuarto atributo es el nivel

    # Si alguno de los nodos no tiene un 'nivel_prenda' válido, el triángulo no es válido
    if nivel1 is None or nivel2 is None or nivel3 is None:
        return False

    # Si hay un nivel 1.2, las otras dos prendas deben ser 3.x y de subniveles distintos
    if nivel1 == 1.2 or nivel2 == 1.2 or nivel3 == 1.2:
        niveles_restantes = [nivel for nivel in [nivel1, nivel2, nivel3] if nivel != 1.2]
        if sorted(niveles_restantes) != [3.0, 3.1]:  # Los niveles restantes deben ser 3.x y distintos
            return False
    else:
        # Si no hay nivel 1.2, debe haber un nodo de cada nivel (1.1, 1.2, 2.x o 3.x)
        niveles = [nivel1, nivel2, nivel3]
        if len(set(niveles)) != 3:  # Todos los niveles deben ser diferentes
            return False
        # Verificar que hay al menos un nivel de cada tipo: 1.x, 2.x, 3.x
        if not any(nivel in [1.1, 1.2] for nivel in niveles) or not any(nivel == 2.0 for nivel in niveles) or not any(nivel >= 3.0 for nivel in niveles):
            return False

    return True

# Filtrar los triángulos que no cumplen con las condiciones de un 'look' válido
triangulos_validos = [triangulo for triangulo in triangulos
                      if es_valido_triangulo(*triangulo[0], G7)]

# Imprimir los triángulos válidos
print(f"Total de looks válidos: {len(triangulos_validos) //3}")
# Out:
# Total de looks válidos: 648619

# %%
# Crear un diccionario que mapea el id_nodo a los nombres de las prendas, colores y niveles
id_a_prenda_color_nivel = dict(zip(df_limpio_s7['id_nodo'], zip(df_limpio_s7['title'], df_limpio_s7['hexadecimal'], df_limpio_s7['nivel'])))

# Ordenar los triángulos en base a la media geométrica (de mayor a menor)
triangulos_ordenados = sorted(triangulos_validos, key=lambda x: x[1], reverse=True)

# Crear una lista para almacenar todos los triángulos ordenados con los IDs de los nodos
resultados_completos = []

# Guardar todos los triángulos ordenados en la lista
for triangulo, media in triangulos_ordenados:
    # Obtener los nombres, colores y niveles de las prendas asociadas a los nodos del triángulo
    prenda1, prenda2, prenda3 = triangulo
    prenda1_nombre, prenda1_color, prenda1_nivel = id_a_prenda_color_nivel.get(prenda1, ('Desconocido', 'Desconocido', 'Desconocido'))
    prenda2_nombre, prenda2_color, prenda2_nivel = id_a_prenda_color_nivel.get(prenda2, ('Desconocido', 'Desconocido', 'Desconocido'))
    prenda3_nombre, prenda3_color, prenda3_nivel = id_a_prenda_color_nivel.get(prenda3, ('Desconocido', 'Desconocido', 'Desconocido'))

    # Guardar el triángulo, su media geométrica, y los IDs de los nodos en la lista de resultados completos
    resultado = (prenda1, prenda1_nombre, prenda1_color, prenda1_nivel,
                 prenda2, prenda2_nombre, prenda2_color, prenda2_nivel,
                 prenda3, prenda3_nombre, prenda3_color, prenda3_nivel,
                 media)
    resultados_completos.append(resultado)

# Ordenar los resultados completos por la media geométrica (de mayor a menor)
resultados_completos_ordenados = sorted(resultados_completos, key=lambda x: x[12], reverse=True)

# Los 10 mejores triángulos (top 10)
top10_triangulos = resultados_completos_ordenados[:10]

# Imprimir los 10 mejores triángulos con IDs, nombres, colores y niveles de prendas
print("Top 10 mejores triángulos con IDs de nodos, nombres, colores y niveles de prendas:")
for resultado in top10_triangulos:
    prenda1_id, prenda1_nombre, prenda1_color, prenda1_nivel, \
    prenda2_id, prenda2_nombre, prenda2_color, prenda2_nivel, \
    prenda3_id, prenda3_nombre, prenda3_color, prenda3_nivel, media = resultado

    # Imprimir el triángulo con la media geométrica y detalles de las prendas, incluyendo los IDs
    print(f"({prenda1_id}: {prenda1_nombre}, {prenda1_color}), "
          f"({prenda2_id}: {prenda2_nombre}, {prenda2_color}), "
          f"({prenda3_id}: {prenda3_nombre}, {prenda3_color}), "
          f"Niveles: [{prenda1_nivel}, {prenda2_nivel}, {prenda3_nivel}] "
          f"Media geométrica de ponderaciones: {media:.4f}")
# Out:
# Top 10 mejores triángulos con IDs de nodos, nombres, colores y niveles de prendas:
# (15: Lunce Top colors , 000000), (21: Aitana Jacket moon, 00008b), (1847: Summ Skirt onado , BBE2AD), Niveles: [2.0, 3.1, 1.1] Media geométrica de ponderaciones: 1.0000
# (15: Lunce Top colors , 000000), (21: Aitana Jacket moon, 00008b), (1849: Summ Skirt onado , E65A5B), Niveles: [2.0, 3.1, 1.1] Media geométrica de ponderaciones: 1.0000
# (15: Lunce Top colors , 000000), (215: Square Sweater grace , DFC8B2), (878: Onlfloria Skirt short , 00008b), Niveles: [2.0, 3.0, 1.1] Media geométrica de ponderaciones: 1.0000
# (15: Lunce Top colors , 000000), (215: Square Sweater grace , DFC8B2), (1060: Nairobi Skirt sage , 40E0D0), Niveles: [2.0, 3.0, 1.1] Media geométrica de ponderaciones: 1.0000
# (15: Lunce Top colors , 000000), (215: Square Sweater grace , DFC8B2), (1356: Vicommit Skirt noos, 000081), Niveles: [2.0, 3.0, 1.1] Media geométrica de ponderaciones: 1.0000
# (15: Lunce Top colors , 000000), (215: Square Sweater grace , DFC8B2), (1420: Dena Skirt solid, 00008b), Niveles: [2.0, 3.0, 1.1] Media geométrica de ponderaciones: 1.0000
# (15: Lunce Top colors , 000000), (215: Square Sweater grace , DFC8B2), (1583: Clean Short pant , 000081), Niveles: [2.0, 3.0, 1.1] Media geométrica de ponderaciones: 1.0000
# (15: Lunce Top colors , 000000), (417: Loret Sweater brille , D3D3D3), (1847: Summ Skirt onado , BBE2AD), Niveles: [2.0, 3.0, 1.1] Media geométrica de ponderaciones: 1.0000
# (15: Lunce Top colors , 000000), (417: Loret Sweater brille , D3D3D3), (1849: Summ Skirt onado , E65A5B), Niveles: [2.0, 3.0, 1.1] Media geométrica de ponderaciones: 1.0000
# (15: Lunce Top colors , 000000), (417: Loret Sweater brille , D3D3D3), (1850: Summ Skirt onado , DEB24C), Niveles: [2.0, 3.0, 1.1] Media geométrica de ponderaciones: 1.0000

# %%
from collections import defaultdict

# Estructura para almacenar resultados únicos
looks_unicos = defaultdict(lambda: {
    "colores": [],
    "media_max": 0,
    "frecuencia": 0,
    "ids_nodos": {"prenda_1": set(), "prenda_2": set(), "prenda_3": set()}
})

# Procesar cada registro en la lista original
for look in resultados_completos_ordenados:
    # Extraer valores del registro
    id_nodo_1, prenda_1, color_1, nivel_1, id_nodo_2, prenda_2, color_2, nivel_2, id_nodo_3, prenda_3, color_3, nivel_3, media_geom = look

    # Definir clave única ordenando las prendas
    prendas = sorted([prenda_1.strip(), prenda_2.strip(), prenda_3.strip()])
    clave = tuple(prendas)

    # Agregar colores al registro correspondiente
    looks_unicos[clave]["colores"].append(sorted([color_1.strip(), color_2.strip(), color_3.strip()]))

    # Agregar los IDs de los nodos a las listas correspondientes
    looks_unicos[clave]["ids_nodos"]["prenda_1"].add(id_nodo_1)
    looks_unicos[clave]["ids_nodos"]["prenda_2"].add(id_nodo_2)
    looks_unicos[clave]["ids_nodos"]["prenda_3"].add(id_nodo_3)

    # Actualizar la media geométrica máxima si es mayor
    looks_unicos[clave]["media_max"] = max(looks_unicos[clave]["media_max"], media_geom)

    # Incrementar frecuencia
    looks_unicos[clave]["frecuencia"] += 1

# Consolidar los resultados
resultados_finales = []

for clave, info in looks_unicos.items():
    # Ajustar la media geométrica según la frecuencia
    media_geom_ajustada = info["media_max"] * (1 + 0.01 * (info["frecuencia"] - 1))

    resultados_finales.append({
        "prendas": clave,
        "colores": info["colores"],
        "media_geom_ajustada": media_geom_ajustada,
        "frecuencia": info["frecuencia"],
        "ids_nodos": info["ids_nodos"]
    })

# Ordenar por media geométrica ajustada (descendente)
resultados_finales_ordenados = sorted(resultados_finales, key=lambda x: -x["media_geom_ajustada"])

# Mostrar los mejores 10 looks
for i, resultado in enumerate(resultados_finales_ordenados[:10], start=1):
    print(f"Look {i}:")
    print(f"  Prendas: {resultado['prendas']}")
    print(f"  Colores: {resultado['colores']}")
    print(f"  Media Geométrica Ajustada: {resultado['media_geom_ajustada']:.4f}")
    print(f"  Frecuencia: {resultado['frecuencia']}")
    print(f"  IDs de Nodos para Prenda 1: {sorted(list(resultado['ids_nodos']['prenda_1']))}")
    print(f"  IDs de Nodos para Prenda 2: {sorted(list(resultado['ids_nodos']['prenda_2']))}")
    print(f"  IDs de Nodos para Prenda 3: {sorted(list(resultado['ids_nodos']['prenda_3']))}")
    print()
# Out:
# Look 1:
#   Prendas: ('Edith Pant beng', 'Hippie Tshirt french', 'Senes Sweater rainbow')
#   Colores: [['000000', 'BBE2AD', 'DFC8B2'], ['000000', 'D3D3D3', 'DFC8B2'], ['000000', '00008b', 'DFC8B2'], ['000000', 'DFC8B2', 'FFA500'], ['000000', '000081', 'DFC8B2'], ['000000', 'B11730', 'DFC8B2'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['00008b', 'DFC8B2', 'FFFFFF'], ['00008b', 'BBE2AD', 'DFC8B2'], ['000000', 'BBE2AD', 'DFC8B2'], ['000000', 'D3D3D3', 'DFC8B2'], ['000000', '00008b', 'DFC8B2'], ['000000', 'DFC8B2', 'FFA500'], ['000000', '000081', 'DFC8B2'], ['000000', 'B11730', 'DFC8B2'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['00008b', 'DFC8B2', 'FFFFFF'], ['00008b', 'BBE2AD', 'DFC8B2'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['00008b', 'DFC8B2', 'FFFFFF'], ['000000', 'BBE2AD', 'DFC8B2'], ['000000', '00008b', 'BBE2AD'], ['00008b', 'BBE2AD', 'DFC8B2'], ['000000', 'D3D3D3', 'DFC8B2'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'DFC8B2'], ['000000', '00008b', 'FFFF00'], ['000000', '00008b', 'E65A5B'], ['000000', 'DFC8B2', 'FFA500'], ['000000', '000081', 'DFC8B2'], ['000000', '000081', 'FFFF00'], ['000000', 'B11730', 'DFC8B2'], ['000000', '87CEFA', 'FFFF00']]
#   Media Geométrica Ajustada: 1.4100
#   Frecuencia: 42
#   IDs de Nodos para Prenda 1: [73, 74, 455, 456, 457, 1016, 1018, 1020, 1021, 1022, 1026, 1027, 1028, 1029]
#   IDs de Nodos para Prenda 2: [73, 74, 455, 456, 457]
#   IDs de Nodos para Prenda 3: [455, 456, 457, 1016, 1018, 1020, 1021, 1022, 1026, 1027, 1028, 1029]
#
# Look 2:
#   Prendas: ('Edith Pant beng', 'Linen Shirt vneck', 'Senes Sweater rainbow')
#   Colores: [['000000', 'B11730', 'D3D3D3'], ['000000', 'B11730', 'FFFF00'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', '000081', 'ECE9D6'], ['000000', '87CEFA', 'ECE9D6'], ['B11730', 'D3D3D3', 'DFC8B2'], ['00008b', 'DFC8B2', 'FFFFFF'], ['00008b', 'BBE2AD', 'DFC8B2'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'B11730', 'FFFF00'], ['B11730', 'D3D3D3', 'DFC8B2'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['00008b', 'DFC8B2', 'FFFFFF'], ['00008b', 'BBE2AD', 'DFC8B2'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', '000081', 'ECE9D6'], ['000000', '87CEFA', 'ECE9D6'], ['00008b', 'DFC8B2', 'FFFFFF'], ['000000', '00008b', 'BBE2AD'], ['00008b', 'BBE2AD', 'DFC8B2'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', 'D3D3D3', 'ECE9D6'], ['B11730', 'D3D3D3', 'DFC8B2'], ['000000', '00008b', 'FFFF00'], ['000000', '00008b', 'E65A5B'], ['000000', 'B11730', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '000081', 'ECE9D6'], ['000000', '87CEFA', 'FFFF00'], ['000000', '87CEFA', 'ECE9D6']]
#   Media Geométrica Ajustada: 1.4100
#   Frecuencia: 42
#   IDs de Nodos para Prenda 1: [73, 74, 573, 574, 575, 576, 1016, 1018, 1020, 1021, 1022, 1024, 1027, 1029]
#   IDs de Nodos para Prenda 2: [73, 74, 573, 574, 575, 576]
#   IDs de Nodos para Prenda 3: [573, 574, 575, 576, 1016, 1018, 1020, 1021, 1022, 1024, 1027, 1029]
#
# Look 3:
#   Prendas: ('Medos Tshirt slub', 'Regular Short fit', 'Senes Sweater rainbow')
#   Colores: [['164A0A', '86BE2D', 'FFFF00'], ['164A0A', 'D3D3D3', 'FFFF00'], ['008000', '164A0A', 'FFFF00'], ['008000', '86BE2D', 'FFFF00'], ['000081', '008000', 'FFFF00'], ['00008b', '86BE2D', 'FFFF00'], ['000000', '164A0A', 'D3D3D3'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['164A0A', '86BE2D', 'ECE9D6'], ['164A0A', 'D3D3D3', 'ECE9D6'], ['008000', '164A0A', 'ECE9D6'], ['008000', '86BE2D', 'ECE9D6'], ['000081', '008000', 'ECE9D6'], ['164A0A', '86BE2D', 'FFFF00'], ['164A0A', 'D3D3D3', 'FFFF00'], ['008000', '164A0A', 'FFFF00'], ['000000', '164A0A', 'D3D3D3'], ['164A0A', '86BE2D', 'ECE9D6'], ['164A0A', 'D3D3D3', 'ECE9D6'], ['008000', '164A0A', 'ECE9D6'], ['008000', '86BE2D', 'FFFF00'], ['000081', '008000', 'FFFF00'], ['008000', '86BE2D', 'ECE9D6'], ['000081', '008000', 'ECE9D6'], ['00008b', '86BE2D', 'FFFF00'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['164A0A', '86BE2D', 'FFFF00'], ['008000', '86BE2D', 'FFFF00'], ['00008b', '86BE2D', 'FFFF00'], ['164A0A', '86BE2D', 'ECE9D6'], ['008000', '86BE2D', 'ECE9D6'], ['000000', '00008b', 'BBE2AD'], ['164A0A', 'D3D3D3', 'FFFF00'], ['000000', '164A0A', 'D3D3D3'], ['164A0A', 'D3D3D3', 'ECE9D6'], ['000000', '00008b', 'E65A5B'], ['008000', '164A0A', 'FFFF00'], ['008000', '164A0A', 'ECE9D6'], ['000081', '008000', 'FFFF00'], ['000081', '008000', 'ECE9D6']]
#   Media Geométrica Ajustada: 1.4100
#   Frecuencia: 42
#   IDs de Nodos para Prenda 1: [288, 290, 292, 346, 349, 350, 1017, 1018, 1020, 1022, 1025, 1027]
#   IDs de Nodos para Prenda 2: [288, 290, 292, 346, 349, 350]
#   IDs de Nodos para Prenda 3: [346, 349, 350, 1017, 1018, 1020, 1022, 1025, 1027]
#
# Look 4:
#   Prendas: ('Linen Shirt vneck', 'Senes Sweater rainbow', 'Zea Short pant')
#   Colores: [['B11730', 'D3D3D3', 'DFC8B2'], ['00008b', 'DFC8B2', 'FFFFFF'], ['00008b', 'BBE2AD', 'DFC8B2'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'B11730', 'FFFF00'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', '000081', 'ECE9D6'], ['000000', '87CEFA', 'ECE9D6'], ['B11730', 'D3D3D3', 'DFC8B2'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'B11730', 'FFFF00'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['00008b', 'DFC8B2', 'FFFFFF'], ['00008b', 'BBE2AD', 'DFC8B2'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', '000081', 'ECE9D6'], ['000000', '87CEFA', 'ECE9D6'], ['00008b', 'DFC8B2', 'FFFFFF'], ['00008b', 'BBE2AD', 'DFC8B2'], ['000000', '00008b', 'BBE2AD'], ['B11730', 'D3D3D3', 'DFC8B2'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', '00008b', 'FFFF00'], ['000000', '00008b', 'E65A5B'], ['000000', 'B11730', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '000081', 'ECE9D6'], ['000000', '87CEFA', 'FFFF00'], ['000000', '87CEFA', 'ECE9D6']]
#   Media Geométrica Ajustada: 1.4100
#   Frecuencia: 42
#   IDs de Nodos para Prenda 1: [527, 528, 573, 574, 575, 576, 1016, 1018, 1020, 1021, 1022, 1024, 1027, 1029]
#   IDs de Nodos para Prenda 2: [527, 528, 573, 574, 575, 576]
#   IDs de Nodos para Prenda 3: [573, 574, 575, 576, 1016, 1018, 1020, 1021, 1022, 1024, 1027, 1029]
#
# Look 5:
#   Prendas: ('Hippie Tshirt french', 'Regular Short fit', 'Senes Sweater rainbow')
#   Colores: [['00008b', '86BE2D', 'FFFF00'], ['000000', 'BBE2AD', 'DFC8B2'], ['000000', 'D3D3D3', 'DFC8B2'], ['000000', '00008b', 'DFC8B2'], ['000000', 'DFC8B2', 'FFA500'], ['000000', '000081', 'DFC8B2'], ['000000', 'B11730', 'DFC8B2'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['000000', 'BBE2AD', 'DFC8B2'], ['000000', 'D3D3D3', 'DFC8B2'], ['000000', '00008b', 'DFC8B2'], ['000000', 'DFC8B2', 'FFA500'], ['000000', '000081', 'DFC8B2'], ['000000', 'B11730', 'DFC8B2'], ['00008b', '86BE2D', 'FFFF00'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['00008b', '86BE2D', 'FFFF00'], ['000000', 'BBE2AD', 'DFC8B2'], ['000000', '00008b', 'BBE2AD'], ['000000', 'D3D3D3', 'DFC8B2'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'DFC8B2'], ['000000', '00008b', 'FFFF00'], ['000000', '00008b', 'E65A5B'], ['000000', 'DFC8B2', 'FFA500'], ['000000', '000081', 'DFC8B2'], ['000000', '000081', 'FFFF00'], ['000000', 'B11730', 'DFC8B2'], ['000000', '87CEFA', 'FFFF00']]
#   Media Geométrica Ajustada: 1.3800
#   Frecuencia: 39
#   IDs de Nodos para Prenda 1: [288, 290, 455, 456, 457, 1017, 1018, 1020, 1021, 1022, 1026, 1027, 1028, 1029]
#   IDs de Nodos para Prenda 2: [288, 290, 455, 456, 457]
#   IDs de Nodos para Prenda 3: [455, 456, 457, 1017, 1018, 1020, 1021, 1022, 1026, 1027, 1028, 1029]
#
# Look 6:
#   Prendas: ('Linen Shirt vneck', 'Regular Short fit', 'Senes Sweater rainbow')
#   Colores: [['00008b', '86BE2D', 'FFFF00'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'B11730', 'FFFF00'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', '000081', 'ECE9D6'], ['000000', '87CEFA', 'ECE9D6'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'B11730', 'FFFF00'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['00008b', '86BE2D', 'FFFF00'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', '000081', 'ECE9D6'], ['000000', '87CEFA', 'ECE9D6'], ['00008b', '86BE2D', 'FFFF00'], ['000000', '00008b', 'BBE2AD'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', '00008b', 'FFFF00'], ['000000', '00008b', 'E65A5B'], ['000000', 'B11730', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '000081', 'ECE9D6'], ['000000', '87CEFA', 'FFFF00'], ['000000', '87CEFA', 'ECE9D6']]
#   Media Geométrica Ajustada: 1.3500
#   Frecuencia: 36
#   IDs de Nodos para Prenda 1: [288, 290, 573, 574, 575, 576, 1017, 1018, 1020, 1021, 1022, 1024, 1027, 1029]
#   IDs de Nodos para Prenda 2: [288, 290, 573, 574, 575, 576]
#   IDs de Nodos para Prenda 3: [573, 574, 575, 576, 1017, 1018, 1020, 1021, 1022, 1024, 1027, 1029]
#
# Look 7:
#   Prendas: ('Hippie Tshirt french', 'Olive Pant solid', 'Senes Sweater rainbow')
#   Colores: [['000000', 'BBE2AD', 'DFC8B2'], ['000000', 'D3D3D3', 'DFC8B2'], ['000000', '00008b', 'DFC8B2'], ['000000', 'DFC8B2', 'FFA500'], ['000000', '000081', 'DFC8B2'], ['000000', 'B11730', 'DFC8B2'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['000000', 'BBE2AD', 'DFC8B2'], ['000000', 'D3D3D3', 'DFC8B2'], ['000000', '00008b', 'DFC8B2'], ['000000', 'DFC8B2', 'FFA500'], ['000000', '000081', 'DFC8B2'], ['000000', 'B11730', 'DFC8B2'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['000000', 'BBE2AD', 'DFC8B2'], ['000000', '00008b', 'BBE2AD'], ['000000', 'D3D3D3', 'DFC8B2'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'DFC8B2'], ['000000', '00008b', 'FFFF00'], ['000000', '00008b', 'E65A5B'], ['000000', 'DFC8B2', 'FFA500'], ['000000', '000081', 'DFC8B2'], ['000000', '000081', 'FFFF00'], ['000000', 'B11730', 'DFC8B2'], ['000000', '87CEFA', 'FFFF00']]
#   Media Geométrica Ajustada: 1.3500
#   Frecuencia: 36
#   IDs de Nodos para Prenda 1: [317, 455, 456, 457, 1018, 1020, 1021, 1022, 1026, 1027, 1028, 1029]
#   IDs de Nodos para Prenda 2: [317, 455, 456, 457]
#   IDs de Nodos para Prenda 3: [455, 456, 457, 1018, 1020, 1021, 1022, 1026, 1027, 1028, 1029]
#
# Look 8:
#   Prendas: ('Loret Sweater brille', 'Medos Tshirt slub', 'Regular Short fit')
#   Colores: [['164A0A', 'D3D3D3', 'FFFF00'], ['008000', '164A0A', 'FFFF00'], ['164A0A', '808080', 'FFFF00'], ['0000FF', '008000', 'FFFF00'], ['00008b', '808080', 'FFFF00'], ['000000', '164A0A', 'D3D3D3'], ['000000', '164A0A', 'DEB24C'], ['000000', '164A0A', '808080'], ['000000', '00008b', '808080'], ['164A0A', 'D3D3D3', 'ECE9D6'], ['008000', '164A0A', 'ECE9D6'], ['164A0A', 'D3D3D3', 'FFFF00'], ['008000', '164A0A', 'FFFF00'], ['164A0A', '808080', 'FFFF00'], ['000000', '164A0A', 'D3D3D3'], ['000000', '164A0A', 'DEB24C'], ['000000', '164A0A', '808080'], ['164A0A', 'D3D3D3', 'ECE9D6'], ['008000', '164A0A', 'ECE9D6'], ['0000FF', '008000', 'FFFF00'], ['00008b', '808080', 'FFFF00'], ['000000', '00008b', '808080'], ['164A0A', 'D3D3D3', 'FFFF00'], ['000000', '164A0A', 'D3D3D3'], ['164A0A', 'D3D3D3', 'ECE9D6'], ['0000FF', '008000', 'FFFF00'], ['000000', '164A0A', 'DEB24C'], ['008000', '164A0A', 'FFFF00'], ['008000', '164A0A', 'ECE9D6'], ['164A0A', '808080', 'FFFF00'], ['00008b', '808080', 'FFFF00'], ['000000', '164A0A', '808080'], ['000000', '00008b', '808080']]
#   Media Geométrica Ajustada: 1.3200
#   Frecuencia: 33
#   IDs de Nodos para Prenda 1: [288, 290, 292, 346, 349, 350, 417, 419, 420, 421, 424]
#   IDs de Nodos para Prenda 2: [288, 290, 292, 346, 349, 350]
#   IDs de Nodos para Prenda 3: [346, 349, 350, 417, 419, 420, 421, 424]
#
# Look 9:
#   Prendas: ('Linen Shirt vneck', 'Olive Pant solid', 'Senes Sweater rainbow')
#   Colores: [['000000', 'B11730', 'D3D3D3'], ['000000', 'B11730', 'FFFF00'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', '000081', 'ECE9D6'], ['000000', '87CEFA', 'ECE9D6'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'B11730', 'FFFF00'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', '000081', 'ECE9D6'], ['000000', '87CEFA', 'ECE9D6'], ['000000', '00008b', 'BBE2AD'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', '00008b', 'FFFF00'], ['000000', '00008b', 'E65A5B'], ['000000', 'B11730', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '000081', 'ECE9D6'], ['000000', '87CEFA', 'FFFF00'], ['000000', '87CEFA', 'ECE9D6']]
#   Media Geométrica Ajustada: 1.3200
#   Frecuencia: 33
#   IDs de Nodos para Prenda 1: [317, 573, 574, 575, 576, 1018, 1020, 1021, 1022, 1024, 1027, 1029]
#   IDs de Nodos para Prenda 2: [317, 573, 574, 575, 576]
#   IDs de Nodos para Prenda 3: [573, 574, 575, 576, 1018, 1020, 1021, 1022, 1024, 1027, 1029]
#
# Look 10:
#   Prendas: ('Buttons Top summ', 'Itta Pant denim', 'Senes Sweater rainbow')
#   Colores: [['D3D3D3', 'DFC8B2', 'FFFFFF'], ['BBE2AD', 'D3D3D3', 'DFC8B2'], ['B11730', 'D3D3D3', 'DFC8B2'], ['000081', 'DFC8B2', 'FFFFFF'], ['B94600', 'D3D3D3', 'FFFFFF'], ['B94600', 'BBE2AD', 'D3D3D3'], ['B94600', 'D3D3D3', 'E65A5B'], ['B11730', 'B94600', 'D3D3D3'], ['462C0E', 'B94600', 'BBE2AD'], ['462C0E', 'B94600', 'E65A5B'], ['D3D3D3', 'DFC8B2', 'FFFFFF'], ['BBE2AD', 'D3D3D3', 'DFC8B2'], ['B94600', 'D3D3D3', 'FFFFFF'], ['B94600', 'BBE2AD', 'D3D3D3'], ['B94600', 'D3D3D3', 'E65A5B'], ['B11730', 'D3D3D3', 'DFC8B2'], ['B11730', 'B94600', 'D3D3D3'], ['462C0E', 'B94600', 'BBE2AD'], ['462C0E', 'B94600', 'E65A5B'], ['000081', 'DFC8B2', 'FFFFFF'], ['D3D3D3', 'DFC8B2', 'FFFFFF'], ['B94600', 'D3D3D3', 'FFFFFF'], ['BBE2AD', 'D3D3D3', 'DFC8B2'], ['B94600', 'BBE2AD', 'D3D3D3'], ['462C0E', 'B94600', 'BBE2AD'], ['B11730', 'D3D3D3', 'DFC8B2'], ['B11730', 'B94600', 'D3D3D3'], ['B94600', 'D3D3D3', 'E65A5B'], ['462C0E', 'B94600', 'E65A5B'], ['000081', 'DFC8B2', 'FFFFFF']]
#   Media Geométrica Ajustada: 1.2900
#   Frecuencia: 30
#   IDs de Nodos para Prenda 1: [127, 128, 394, 395, 396, 398, 1016, 1018, 1020, 1022, 1027]
#   IDs de Nodos para Prenda 2: [127, 128, 394, 395, 396, 398]
#   IDs de Nodos para Prenda 3: [394, 395, 396, 398, 1016, 1018, 1020, 1022, 1027]

# %%
# Diccionario para rastrear el conteo de cada prenda en el top 10
conteo_prendas = defaultdict(int)

# Lista para almacenar los resultados finales filtrados
top_10_filtrados = []

# Iterar sobre los resultados ordenados
for resultado in resultados_finales_ordenados:
    prendas = resultado['prendas']

    # Verificar si alguna prenda excede el límite de 2 apariciones
    if all(conteo_prendas[prenda] < 2 for prenda in prendas):
        # Agregar el resultado a la lista final
        top_10_filtrados.append(resultado)

        # Incrementar el conteo para cada prenda del look
        for prenda in prendas:
            conteo_prendas[prenda] += 1

    # Detener el proceso si ya hemos seleccionado 10 looks
    if len(top_10_filtrados) == 10:
        break

# Mostrar los mejores 10 looks filtrados
for i, resultado in enumerate(top_10_filtrados, start=1):
    print(f"Look {i}:")
    print(f"  Prendas: {resultado['prendas']}")
    print(f"  Colores: {resultado['colores']}")
    print(f"  Media Geométrica Ajustada: {resultado['media_geom_ajustada']:.4f}")
    print(f"  Frecuencia: {resultado['frecuencia']}")
    print(f"  IDs de Nodos para Prenda 1: {sorted(list(resultado['ids_nodos']['prenda_1']))}")
    print(f"  IDs de Nodos para Prenda 2: {sorted(list(resultado['ids_nodos']['prenda_2']))}")
    print(f"  IDs de Nodos para Prenda 3: {sorted(list(resultado['ids_nodos']['prenda_3']))}")
    print()
# Out:
# Look 1:
#   Prendas: ('Edith Pant beng', 'Hippie Tshirt french', 'Senes Sweater rainbow')
#   Colores: [['000000', 'BBE2AD', 'DFC8B2'], ['000000', 'D3D3D3', 'DFC8B2'], ['000000', '00008b', 'DFC8B2'], ['000000', 'DFC8B2', 'FFA500'], ['000000', '000081', 'DFC8B2'], ['000000', 'B11730', 'DFC8B2'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['00008b', 'DFC8B2', 'FFFFFF'], ['00008b', 'BBE2AD', 'DFC8B2'], ['000000', 'BBE2AD', 'DFC8B2'], ['000000', 'D3D3D3', 'DFC8B2'], ['000000', '00008b', 'DFC8B2'], ['000000', 'DFC8B2', 'FFA500'], ['000000', '000081', 'DFC8B2'], ['000000', 'B11730', 'DFC8B2'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['00008b', 'DFC8B2', 'FFFFFF'], ['00008b', 'BBE2AD', 'DFC8B2'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['00008b', 'DFC8B2', 'FFFFFF'], ['000000', 'BBE2AD', 'DFC8B2'], ['000000', '00008b', 'BBE2AD'], ['00008b', 'BBE2AD', 'DFC8B2'], ['000000', 'D3D3D3', 'DFC8B2'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'DFC8B2'], ['000000', '00008b', 'FFFF00'], ['000000', '00008b', 'E65A5B'], ['000000', 'DFC8B2', 'FFA500'], ['000000', '000081', 'DFC8B2'], ['000000', '000081', 'FFFF00'], ['000000', 'B11730', 'DFC8B2'], ['000000', '87CEFA', 'FFFF00']]
#   Media Geométrica Ajustada: 1.4100
#   Frecuencia: 42
#   IDs de Nodos para Prenda 1: [73, 74, 455, 456, 457, 1016, 1018, 1020, 1021, 1022, 1026, 1027, 1028, 1029]
#   IDs de Nodos para Prenda 2: [73, 74, 455, 456, 457]
#   IDs de Nodos para Prenda 3: [455, 456, 457, 1016, 1018, 1020, 1021, 1022, 1026, 1027, 1028, 1029]
#
# Look 2:
#   Prendas: ('Edith Pant beng', 'Linen Shirt vneck', 'Senes Sweater rainbow')
#   Colores: [['000000', 'B11730', 'D3D3D3'], ['000000', 'B11730', 'FFFF00'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', '000081', 'ECE9D6'], ['000000', '87CEFA', 'ECE9D6'], ['B11730', 'D3D3D3', 'DFC8B2'], ['00008b', 'DFC8B2', 'FFFFFF'], ['00008b', 'BBE2AD', 'DFC8B2'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'B11730', 'FFFF00'], ['B11730', 'D3D3D3', 'DFC8B2'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', '00008b', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '87CEFA', 'FFFF00'], ['000000', '00008b', 'BBE2AD'], ['000000', '00008b', 'E65A5B'], ['00008b', 'DFC8B2', 'FFFFFF'], ['00008b', 'BBE2AD', 'DFC8B2'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', '000081', 'ECE9D6'], ['000000', '87CEFA', 'ECE9D6'], ['00008b', 'DFC8B2', 'FFFFFF'], ['000000', '00008b', 'BBE2AD'], ['00008b', 'BBE2AD', 'DFC8B2'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', 'D3D3D3', 'ECE9D6'], ['B11730', 'D3D3D3', 'DFC8B2'], ['000000', '00008b', 'FFFF00'], ['000000', '00008b', 'E65A5B'], ['000000', 'B11730', 'FFFF00'], ['000000', '000081', 'FFFF00'], ['000000', '000081', 'ECE9D6'], ['000000', '87CEFA', 'FFFF00'], ['000000', '87CEFA', 'ECE9D6']]
#   Media Geométrica Ajustada: 1.4100
#   Frecuencia: 42
#   IDs de Nodos para Prenda 1: [73, 74, 573, 574, 575, 576, 1016, 1018, 1020, 1021, 1022, 1024, 1027, 1029]
#   IDs de Nodos para Prenda 2: [73, 74, 573, 574, 575, 576]
#   IDs de Nodos para Prenda 3: [573, 574, 575, 576, 1016, 1018, 1020, 1021, 1022, 1024, 1027, 1029]
#
# Look 3:
#   Prendas: ('Loret Sweater brille', 'Medos Tshirt slub', 'Regular Short fit')
#   Colores: [['164A0A', 'D3D3D3', 'FFFF00'], ['008000', '164A0A', 'FFFF00'], ['164A0A', '808080', 'FFFF00'], ['0000FF', '008000', 'FFFF00'], ['00008b', '808080', 'FFFF00'], ['000000', '164A0A', 'D3D3D3'], ['000000', '164A0A', 'DEB24C'], ['000000', '164A0A', '808080'], ['000000', '00008b', '808080'], ['164A0A', 'D3D3D3', 'ECE9D6'], ['008000', '164A0A', 'ECE9D6'], ['164A0A', 'D3D3D3', 'FFFF00'], ['008000', '164A0A', 'FFFF00'], ['164A0A', '808080', 'FFFF00'], ['000000', '164A0A', 'D3D3D3'], ['000000', '164A0A', 'DEB24C'], ['000000', '164A0A', '808080'], ['164A0A', 'D3D3D3', 'ECE9D6'], ['008000', '164A0A', 'ECE9D6'], ['0000FF', '008000', 'FFFF00'], ['00008b', '808080', 'FFFF00'], ['000000', '00008b', '808080'], ['164A0A', 'D3D3D3', 'FFFF00'], ['000000', '164A0A', 'D3D3D3'], ['164A0A', 'D3D3D3', 'ECE9D6'], ['0000FF', '008000', 'FFFF00'], ['000000', '164A0A', 'DEB24C'], ['008000', '164A0A', 'FFFF00'], ['008000', '164A0A', 'ECE9D6'], ['164A0A', '808080', 'FFFF00'], ['00008b', '808080', 'FFFF00'], ['000000', '164A0A', '808080'], ['000000', '00008b', '808080']]
#   Media Geométrica Ajustada: 1.3200
#   Frecuencia: 33
#   IDs de Nodos para Prenda 1: [288, 290, 292, 346, 349, 350, 417, 419, 420, 421, 424]
#   IDs de Nodos para Prenda 2: [288, 290, 292, 346, 349, 350]
#   IDs de Nodos para Prenda 3: [346, 349, 350, 417, 419, 420, 421, 424]
#
# Look 4:
#   Prendas: ('Flonce Top cerise', 'Lulu Cardigan long', 'Tiel Pant paris')
#   Colores: [['B11730', 'B94600', 'D3D3D3'], ['B94600', 'D3D3D3', 'ECE9D6'], ['B94600', 'C19A6B', 'ECE9D6'], ['164A0A', 'B94600', 'ECE9D6'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', 'C19A6B', 'ECE9D6'], ['000000', '164A0A', 'ECE9D6'], ['B11730', 'B94600', 'D3D3D3'], ['000000', 'B11730', 'D3D3D3'], ['B94600', 'D3D3D3', 'ECE9D6'], ['B94600', 'C19A6B', 'ECE9D6'], ['164A0A', 'B94600', 'ECE9D6'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', 'C19A6B', 'ECE9D6'], ['000000', '164A0A', 'ECE9D6'], ['B11730', 'B94600', 'D3D3D3'], ['B94600', 'D3D3D3', 'ECE9D6'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'D3D3D3', 'ECE9D6'], ['B94600', 'C19A6B', 'ECE9D6'], ['000000', 'C19A6B', 'ECE9D6'], ['164A0A', 'B94600', 'ECE9D6'], ['000000', '164A0A', 'ECE9D6']]
#   Media Geométrica Ajustada: 1.2300
#   Frecuencia: 24
#   IDs de Nodos para Prenda 1: [116, 117, 768, 769, 818, 819, 822]
#   IDs de Nodos para Prenda 2: [116, 117, 768, 769]
#   IDs de Nodos para Prenda 3: [768, 769, 818, 819, 822]
#
# Look 5:
#   Prendas: ('Buttons Top summ', 'Loret Sweater brille', 'Summ Skirt onado')
#   Colores: [['BBE2AD', 'D3D3D3', 'DFC8B2'], ['D3D3D3', 'DFC8B2', 'FFFFFF'], ['00008b', 'BBE2AD', 'DFC8B2'], ['00008b', 'DFC8B2', 'FFFFFF'], ['000081', '008000', 'DFC8B2'], ['B94600', 'BBE2AD', 'D3D3D3'], ['B94600', 'D3D3D3', 'FFFFFF'], ['B94600', 'D3D3D3', 'E65A5B'], ['BBE2AD', 'D3D3D3', 'DFC8B2'], ['D3D3D3', 'DFC8B2', 'FFFFFF'], ['B94600', 'BBE2AD', 'D3D3D3'], ['B94600', 'D3D3D3', 'FFFFFF'], ['B94600', 'D3D3D3', 'E65A5B'], ['00008b', 'BBE2AD', 'DFC8B2'], ['00008b', 'DFC8B2', 'FFFFFF'], ['000081', '008000', 'DFC8B2'], ['BBE2AD', 'D3D3D3', 'DFC8B2'], ['00008b', 'BBE2AD', 'DFC8B2'], ['B94600', 'BBE2AD', 'D3D3D3'], ['D3D3D3', 'DFC8B2', 'FFFFFF'], ['00008b', 'DFC8B2', 'FFFFFF'], ['B94600', 'D3D3D3', 'FFFFFF'], ['B94600', 'D3D3D3', 'E65A5B'], ['000081', '008000', 'DFC8B2']]
#   Media Geométrica Ajustada: 1.2300
#   Frecuencia: 24
#   IDs de Nodos para Prenda 1: [127, 128, 417, 418, 421, 1847, 1848, 1849, 1851]
#   IDs de Nodos para Prenda 2: [127, 128, 417, 418, 421]
#   IDs de Nodos para Prenda 3: [417, 418, 421, 1847, 1848, 1849, 1851]
#
# Look 6:
#   Prendas: ('Flonce Top cerise', 'Lulu Cardigan long', 'Than Pant place')
#   Colores: [['B11730', 'B94600', 'D3D3D3'], ['B94600', 'D3D3D3', 'ECE9D6'], ['B94600', 'C19A6B', 'ECE9D6'], ['164A0A', 'B94600', 'ECE9D6'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', 'C19A6B', 'ECE9D6'], ['000000', '164A0A', 'ECE9D6'], ['B11730', 'B94600', 'D3D3D3'], ['000000', 'B11730', 'D3D3D3'], ['B94600', 'D3D3D3', 'ECE9D6'], ['B94600', 'C19A6B', 'ECE9D6'], ['164A0A', 'B94600', 'ECE9D6'], ['000000', 'D3D3D3', 'ECE9D6'], ['000000', 'C19A6B', 'ECE9D6'], ['000000', '164A0A', 'ECE9D6'], ['B11730', 'B94600', 'D3D3D3'], ['B94600', 'D3D3D3', 'ECE9D6'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'D3D3D3', 'ECE9D6'], ['B94600', 'C19A6B', 'ECE9D6'], ['000000', 'C19A6B', 'ECE9D6'], ['164A0A', 'B94600', 'ECE9D6'], ['000000', '164A0A', 'ECE9D6']]
#   Media Geométrica Ajustada: 1.2300
#   Frecuencia: 24
#   IDs de Nodos para Prenda 1: [553, 554, 768, 769, 818, 819, 822]
#   IDs de Nodos para Prenda 2: [553, 554, 768, 769]
#   IDs de Nodos para Prenda 3: [768, 769, 818, 819, 822]
#
# Look 7:
#   Prendas: ('Buttons Top summ', 'Sandra Cardigan melang', 'Summ Skirt onado')
#   Colores: [['BBE2AD', 'D3D3D3', 'DFC8B2'], ['D3D3D3', 'DFC8B2', 'FFFFFF'], ['00008b', 'BBE2AD', 'DFC8B2'], ['00008b', 'DFC8B2', 'FFFFFF'], ['B94600', 'BBE2AD', 'D3D3D3'], ['B94600', 'D3D3D3', 'FFFFFF'], ['B94600', 'D3D3D3', 'E65A5B'], ['BBE2AD', 'D3D3D3', 'DFC8B2'], ['D3D3D3', 'DFC8B2', 'FFFFFF'], ['B94600', 'BBE2AD', 'D3D3D3'], ['B94600', 'D3D3D3', 'FFFFFF'], ['B94600', 'D3D3D3', 'E65A5B'], ['00008b', 'BBE2AD', 'DFC8B2'], ['00008b', 'DFC8B2', 'FFFFFF'], ['BBE2AD', 'D3D3D3', 'DFC8B2'], ['00008b', 'BBE2AD', 'DFC8B2'], ['B94600', 'BBE2AD', 'D3D3D3'], ['D3D3D3', 'DFC8B2', 'FFFFFF'], ['00008b', 'DFC8B2', 'FFFFFF'], ['B94600', 'D3D3D3', 'FFFFFF'], ['B94600', 'D3D3D3', 'E65A5B']]
#   Media Geométrica Ajustada: 1.2000
#   Frecuencia: 21
#   IDs de Nodos para Prenda 1: [127, 128, 240, 241, 1847, 1848, 1849]
#   IDs de Nodos para Prenda 2: [127, 128, 240, 241]
#   IDs de Nodos para Prenda 3: [240, 241, 1847, 1848, 1849]
#
# Look 8:
#   Prendas: ('Kusi Short pant', 'Lusa Top knit', 'Square Sweater grace')
#   Colores: [['00008b', 'C19A6B', 'D84936'], ['00008b', 'C19A6B', 'FFFFFF'], ['00008b', 'D84936', 'DFC8B2'], ['00008b', 'DFC8B2', 'FFFFFF'], ['B94600', 'C19A6B', 'D84936'], ['B94600', 'C19A6B', 'FFFFFF'], ['00008b', 'D84936', 'DFC8B2'], ['00008b', 'DFC8B2', 'FFFFFF'], ['00008b', 'C19A6B', 'D84936'], ['00008b', 'C19A6B', 'FFFFFF'], ['B94600', 'C19A6B', 'D84936'], ['B94600', 'C19A6B', 'FFFFFF'], ['00008b', 'C19A6B', 'D84936'], ['00008b', 'D84936', 'DFC8B2'], ['B94600', 'C19A6B', 'D84936'], ['00008b', 'C19A6B', 'FFFFFF'], ['00008b', 'DFC8B2', 'FFFFFF'], ['B94600', 'C19A6B', 'FFFFFF']]
#   Media Geométrica Ajustada: 1.1700
#   Frecuencia: 18
#   IDs de Nodos para Prenda 1: [214, 215, 216, 1524, 1526, 1612, 1614]
#   IDs de Nodos para Prenda 2: [214, 215, 216, 1524, 1526]
#   IDs de Nodos para Prenda 3: [1524, 1526, 1612, 1614]
#
# Look 9:
#   Prendas: ('Chic Tshirt beach', 'Kusi Short pant', 'Sandra Cardigan melang')
#   Colores: [['00008b', '5F5E5E', 'C19A6B'], ['00008b', 'BBE2AD', 'C19A6B'], ['000000', '00008b', '5F5E5E'], ['000000', '00008b', 'BBE2AD'], ['000000', '5F5E5E', 'C19A6B'], ['000000', 'BBE2AD', 'C19A6B'], ['000000', '00008b', '5F5E5E'], ['000000', '00008b', 'BBE2AD'], ['00008b', '5F5E5E', 'C19A6B'], ['00008b', 'BBE2AD', 'C19A6B'], ['000000', '5F5E5E', 'C19A6B'], ['000000', 'BBE2AD', 'C19A6B'], ['00008b', '5F5E5E', 'C19A6B'], ['000000', '00008b', '5F5E5E'], ['000000', '5F5E5E', 'C19A6B'], ['00008b', 'BBE2AD', 'C19A6B'], ['000000', '00008b', 'BBE2AD'], ['000000', 'BBE2AD', 'C19A6B']]
#   Media Geométrica Ajustada: 1.1700
#   Frecuencia: 18
#   IDs de Nodos para Prenda 1: [241, 242, 1524, 1526, 1647, 1648]
#   IDs de Nodos para Prenda 2: [241, 242, 1524, 1526]
#   IDs de Nodos para Prenda 3: [1524, 1526, 1647, 1648]
#
# Look 10:
#   Prendas: ('Linen Shirt vneck', 'Piros Cardigan grette', 'Zea Short pant')
#   Colores: [['800000', 'B11730', 'DFC8B2'], ['B11730', 'D3D3D3', 'DFC8B2'], ['00008b', '800000', 'DFC8B2'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', 'D3D3D3', 'ECE9D6'], ['800000', 'B11730', 'DFC8B2'], ['B11730', 'D3D3D3', 'DFC8B2'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'D3D3D3', 'FFFF00'], ['00008b', '800000', 'DFC8B2'], ['000000', 'D3D3D3', 'ECE9D6'], ['800000', 'B11730', 'DFC8B2'], ['00008b', '800000', 'DFC8B2'], ['B11730', 'D3D3D3', 'DFC8B2'], ['000000', 'B11730', 'D3D3D3'], ['000000', 'D3D3D3', 'FFFF00'], ['000000', 'D3D3D3', 'ECE9D6']]
#   Media Geométrica Ajustada: 1.1700
#   Frecuencia: 18
#   IDs de Nodos para Prenda 1: [527, 528, 573, 574, 575, 576, 1275, 1277]
#   IDs de Nodos para Prenda 2: [527, 528, 573, 574, 575, 576]
#   IDs de Nodos para Prenda 3: [573, 574, 575, 576, 1275, 1277]

# %%
import networkx as nx
from networkx.algorithms.community import greedy_modularity_communities


# Detectar comunidades en el grafo completo
comunidades = list(greedy_modularity_communities(G7))

# Análisis numérico de comunidades
num_comunidades = len(comunidades)
tamanos_comunidades = [len(c) for c in comunidades]

# Resultados
num_comunidades, tamanos_comunidades
# Out:
# (3, [1038, 787, 98])

# %%
import random
from networkx.algorithms.community import greedy_modularity_communities

def graficar_grafo_con_nodo73(G, muestra=50, nodo_fijo=73):
    # Obtener una muestra conectada que incluya el nodo 73
    def obtener_muestra_con_nodo(G, muestra, nodo_fijo):
        visitados = {nodo_fijo}
        cola = [nodo_fijo]

        while cola and len(visitados) < muestra:
            nodo = cola.pop(0)
            if nodo not in visitados:
                visitados.add(nodo)
            cola.extend(n for n in G.neighbors(nodo) if n not in visitados)

        return list(visitados)

    nodos_muestra = obtener_muestra_con_nodo(G, muestra, nodo_fijo)
    subgrafo = G.subgraph(nodos_muestra)

    # Detectar comunidades (máximo 3)
    comunidades = list(greedy_modularity_communities(subgrafo))[:3]
    colores = {}
    for idx, comunidad in enumerate(comunidades):
        for nodo in comunidad:
            colores[nodo] = idx

    # Colores rojo, naranja y amarillo
    color_map = ['#FCBBA1', '#FC8D59', '#B30000']
    node_colors = [color_map[colores.get(nodo, -1)] if colores.get(nodo, -1) >= 0 else "#FEE0D2" for nodo in subgrafo.nodes()]
    node_sizes = [subgrafo.degree(nodo) * 100 for nodo in subgrafo.nodes()]  # Escalar el tamaño por el grado

    # Dibujar el grafo
    pos = nx.spring_layout(subgrafo, seed=42)  # Disposición de los nodos
    plt.figure(figsize=(12, 8))
    nx.draw(
        subgrafo,
        pos,
        with_labels=True,
        node_color=node_colors,
        node_size=node_sizes,
        edge_color="gray",
        font_size=8
    )
    plt.title("Muestra de Comunidades del Grafo")
    plt.show()

# Llamar a la función
graficar_grafo_con_nodo73(G7)
